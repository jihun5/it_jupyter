# %%
import pandas as pd
from pandas import DataFrame
from pandas import read_csv, pivot_table
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats
from pandas import read_excel
import os, sys

sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))
from helper import myOls, scalling

# %%
train = pd.read_excel('범죄.xlsx', index_col='Unnamed: 0')
train
# Out:
#           전국  아파트/연립다세대  단독주택     노상  숙박업소  유흥업소   상점  사무실  피씨방  고속도로  ...  \
# 살인기수     275        114    60     28     9     8    1    8    0     0  ...
# 살인미수     427        123    85    105     5    24    4   13    1     0  ...
# 강도       516         62    46    141    48    42   27   13    4     0  ...
# 강간      5467       1616   880    158  1644   196   33   55    3     0  ...
# 유사강간     947        240   147     57   184    55    9   26    1     2  ...
# ...      ...        ...   ...    ...   ...   ...  ...  ...  ...   ...  ...
# 협박      9187       1199  1288   1870    67   417  104  535   12    88  ...
# 약취 유인    190         20    18     66     8     3    1    1    0     0  ...
# 폭력행위   35686       2374  2463  12838   296  3879  207  855   75   129  ...
# 공갈      3596        203   259    773    58   600   92  307   67     2  ...
# 손괴     58977       3050  3004  22143   606  1987  597  798   47    27  ...
#
#        슈퍼마켓  편의점   공장  지하철  유원지   학교  의료기관  종교기관   주차장  화장실
# 살인기수      0    1    1    0    3    1     7     1     5    0
# 살인미수      1    0    2    0    2    0     6     1     5    1
# 강도       12   32    3    1    0    0     0     0    21    4
# 강간        2    3    2    0   20   15    11     7    45    3
# 유사강간      0    0    1    0    8    8    11     2     7    1
# ...     ...  ...  ...  ...  ...  ...   ...   ...   ...  ...
# 협박       18   52   46    2   38   42    79    18   104    0
# 약취 유인     0    0    0    0    3    6     7     2     1    0
# 폭력행위     43  137  182   13  353  246   134   139   486   44
# 공갈        9   43   16    0   26   65    30     6    36    2
# 손괴       79  185  129   13  128  103   107   114  5786   36
#
# [128 rows x 21 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
train = scaler.fit_transform(train)
train = pd.DataFrame(train)
train.columns = ['전국', '아파트/연립다세대','단독주택', '노상', '숙박업소', '유흥업소', '상점', '사무실', '피씨방',
       '고속도로', '백화점', '슈퍼마켓', '편의점', '공장', '지하철', '유원지', '학교', '의료기관', '종교기관',
       '주차장', '화장실']
train.columns
# Out:
# Index(['전국', '아파트/연립다세대', '단독주택', '노상', '숙박업소', '유흥업소', '상점', '사무실', '피씨방',
#        '고속도로', '백화점', '슈퍼마켓', '편의점', '공장', '지하철', '유원지', '학교', '의료기관', '종교기관',
#        '주차장', '화장실'],
#       dtype='object')

# %%
names = train.columns
n = len(names)
pv = 0.05

data = []

for i in range(0, n):
    fields = names[1] + 'vs' + names[i]
    s, p = stats.pearsonr(train[names[1]], train[names[i]])
    result = p < pv

    data.append({'fields': fields, 'statistic':s, 'pvalue': p, 'result': result})

rdf = DataFrame(data)
rdf.set_index('fields', inplace=True)
rdf
# Out:
#                       statistic         pvalue  result
# fields
# 아파트/연립다세대vs전국          0.911766   1.570084e-50    True
# 아파트/연립다세대vs아파트/연립다세대   1.000000   0.000000e+00    True
# 아파트/연립다세대vs단독주택        0.986893  1.105972e-101    True
# 아파트/연립다세대vs노상          0.910150   4.676855e-50    True
# 아파트/연립다세대vs숙박업소        0.710139   6.240115e-21    True
# 아파트/연립다세대vs유흥업소        0.925337   6.511608e-55    True
# 아파트/연립다세대vs상점          0.954894   2.680188e-68    True
# 아파트/연립다세대vs사무실         0.933570   5.368934e-58    True
# 아파트/연립다세대vs피씨방         0.917088   3.690169e-52    True
# 아파트/연립다세대vs고속도로        0.662702   1.590413e-17    True
# 아파트/연립다세대vs백화점         0.841730   1.569375e-35    True
# 아파트/연립다세대vs슈퍼마켓        0.774746   7.472488e-27    True
# 아파트/연립다세대vs편의점         0.818031   4.690673e-32    True
# 아파트/연립다세대vs공장          0.822936   9.879265e-33    True
# 아파트/연립다세대vs지하철         0.334419   1.142736e-04    True
# 아파트/연립다세대vs유원지         0.795474   3.457109e-29    True
# 아파트/연립다세대vs학교          0.732383   8.937237e-23    True
# 아파트/연립다세대vs의료기관        0.816182   8.334742e-32    True
# 아파트/연립다세대vs종교기관        0.767823   3.968083e-26    True
# 아파트/연립다세대vs주차장         0.498580   2.108589e-09    True
# 아파트/연립다세대vs화장실         0.802894   4.331447e-30    True

# %%
x = train.loc[:, ['아파트/연립다세대', '노상', '숙박업소', '유흥업소', '상점', '사무실', '피씨방',
       '고속도로', '백화점', '슈퍼마켓', '편의점', '공장', '지하철', '유원지', '학교', '의료기관', '종교기관',
       '주차장', '화장실']].values
x
# Out:
# array([[-0.45162858, -0.47462155, -0.67993691, ..., -0.57040064,
#         -0.3992083 , -0.60257451],
#        [-0.44978787, -0.46900323, -0.68656716, ..., -0.57040064,
#         -0.3992083 , -0.58438787],
#        [-0.46226378, -0.46637648, -0.61529201, ..., -0.58350389,
#         -0.38984807, -0.52982795],
#        ...,
#        [ 0.01059366,  0.46006271, -0.20421676, ...,  1.23784719,
#         -0.1178164 ,  0.19763762],
#        [-0.43342602, -0.42026247, -0.5987164 , ..., -0.50488442,
#         -0.38107286, -0.56620123],
#        [ 0.14885128,  1.13900393,  0.30962731, ...,  0.91026606,
#          2.98275962,  0.0521445 ]])

# %%
import statsmodels.api as sm
results = sm.OLS(train['전국'], sm.add_constant(x)).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     전국   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                     7116.
# Date:                Tue, 26 Sep 2023   Prob (F-statistic):          4.65e-158
# Time:                        10:25:40   Log-Likelihood:                 274.90
# No. Observations:                 128   AIC:                            -509.8
# Df Residuals:                     108   BIC:                            -452.8
# Df Model:                          19
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.551e-17      0.003   2.04e-14      1.000      -0.005       0.005
# x1            -0.0740      0.020     -3.723      0.000      -0.113      -0.035
# x2             0.9993      0.026     38.501      0.000       0.948       1.051
# x3             0.0579      0.005     10.768      0.000       0.047       0.069
# x4            -0.0735      0.021     -3.527      0.001      -0.115      -0.032
# x5            -0.0251      0.031     -0.820      0.414      -0.086       0.036
# x6             0.2036      0.026      7.900      0.000       0.153       0.255
# x7            -0.0320      0.015     -2.133      0.035      -0.062      -0.002
# x8             0.0034      0.006      0.569      0.570      -0.008       0.015
# x9            -0.0559      0.020     -2.802      0.006      -0.096      -0.016
# x10           -0.0122      0.010     -1.209      0.229      -0.032       0.008
# x11            0.1072      0.027      3.966      0.000       0.054       0.161
# x12           -0.0255      0.019     -1.371      0.173      -0.062       0.011
# x13            0.0264      0.007      4.004      0.000       0.013       0.039
# x14           -0.0557      0.028     -2.020      0.046      -0.110      -0.001
# x15            0.0394      0.015      2.630      0.010       0.010       0.069
# x16            0.0170      0.025      0.680      0.498      -0.033       0.067
# x17           -0.0605      0.012     -4.843      0.000      -0.085      -0.036
# x18           -0.0160      0.015     -1.042      0.300      -0.046       0.014
# x19            0.0014      0.013      0.103      0.918      -0.025       0.028
# ==============================================================================
# Omnibus:                       12.262   Durbin-Watson:                   2.254
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               26.900
# Skew:                          -0.302   Prob(JB):                     1.44e-06
# Kurtosis:                       5.163   Cond. No.                         65.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm
model = sm.OLS(train['전국'], train[['아파트/연립다세대', '노상', '숙박업소', '고속도로',
        '슈퍼마켓', '공장', '지하철', '종교기관', '주차장',]])
result = model.fit()
tbl
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     전국   R-squared (uncentered):                   0.999
# Model:                            OLS   Adj. R-squared (uncentered):              0.999
# Method:                 Least Squares   F-statistic:                          1.072e+04
# Date:                Tue, 26 Sep 2023   Prob (F-statistic):                   3.89e-170
# Time:                        09:45:14   Log-Likelihood:                         -1099.8
# No. Observations:                 128   AIC:                                      2222.
# Df Residuals:                     117   BIC:                                      2253.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 아파트/연립다세대     -0.3302      0.098     -3.382      0.001      -0.524      -0.137
# 노상             2.6631      0.043     61.974      0.000       2.578       2.748
# 숙박업소           3.1472      0.320      9.830      0.000       2.513       3.781
# 유흥업소          -1.0768      0.168     -6.405      0.000      -1.410      -0.744
# 사무실            8.8600      0.955      9.276      0.000       6.968      10.752
# 피씨방          -15.4203      5.553     -2.777      0.006     -26.418      -4.422
# 백화점            2.1778     17.559      0.124      0.902     -32.597      36.953
# 공장             2.3390      3.214      0.728      0.468      -4.026       8.705
# 지하철            8.3862      1.053      7.961      0.000       6.300      10.473
# 학교            -5.2627      2.573     -2.045      0.043     -10.359      -0.166
# 주차장           -0.9325      0.132     -7.090      0.000      -1.193      -0.672
# ==============================================================================
# Omnibus:                       18.384   Durbin-Watson:                   2.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.239
# Skew:                          -0.433   Prob(JB):                     2.75e-12
# Kurtosis:                       6.039   Cond. No.                     2.43e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.43e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import re

my = {}

for k in range(0, 3, 2):
    items = tbl.tables[k].data
    #print(items)

    for item in items:
        #print(item)
        n = len(item)

        for i in range(0, n, 2):
            key = item[i].strip()[:-1]
            value = item[i+1].strip()

            if key and value:
                my[key] = value

my
# Out:
# {'Dep. Variable': '전국',
#  'R-squared (uncentered)': '0.999',
#  'Model': 'OLS',
#  'Adj. R-squared (uncentered)': '0.999',
#  'Method': 'Least Squares',
#  'F-statistic': '1.072e+04',
#  'Date': 'Tue, 26 Sep 2023',
#  'Prob (F-statistic)': '3.89e-170',
#  'Time': '09:45:14',
#  'Log-Likelihood': '-1099.8',
#  'No. Observations': '128',
#  'AIC': '2222.',
#  'Df Residuals': '117',
#  'BIC': '2253.',
#  'Df Model': '11',
#  'Covariance Type': 'nonrobust',
#  'Omnibus': '18.384',
#  'Durbin-Watson': '2.232',
#  'Prob(Omnibus)': '0.000',
#  'Jarque-Bera (JB)': '53.239',
#  'Skew': '-0.433',
#  'Prob(JB)': '2.75e-12',
#  'Kurtosis': '6.039',
#  'Cond. No': '2.43e+03'}

# %%
my['variables'] = []

for i, v in enumerate(tbl.tables[1].data):
    if i == 0:
        continue

    # 변수의 이름
    name = v[0].strip()
    # 변수의 이름 목록
    name_list = list(model.exog_names)
    # 변수의 이름 목록에서 현재 변수가 몇 번째 항목인지 찾기 
    j = name_list.index(name)

    vif = 0

    # 0번째인 Intercept는 제외
    if j >= 0:
        vif = variance_inflation_factor(model.exog, j)

    my['variables'].append({
        "name": name,
        "coef": v[1].strip(),
        "std err": v[2].strip(),
        "t": v[3].strip(),
        "P-value": v[4].strip(),
        "Beta": 0,
        "VIF": vif,
    })

my
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\jihun5\jupyter\04-추론적_데이터_분석\04-5 로지스틱회귀\vif값 낮추기.ipynb 셀 9 line 1
#      <a href='vscode-notebook-cell:/d%3A/jihun5/jupyter/04-%EC%B6%94%EB%A1%A0%EC%A0%81_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D/04-5%20%EB%A1%9C%EC%A7%80%EC%8A%A4%ED%8B%B1%ED%9A%8C%EA%B7%80/vif%EA%B0%92%20%EB%82%AE%EC%B6%94%EA%B8%B0.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a> name_list = list(model.exog_names)
#      <a href='vscode-notebook-cell:/d%3A/jihun5/jupyter/04-%EC%B6%94%EB%A1%A0%EC%A0%81_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D/04-5%20%EB%A1%9C%EC%A7%80%EC%8A%A4%ED%8B%B1%ED%9A%8C%EA%B7%80/vif%EA%B0%92%20%EB%82%AE%EC%B6%94%EA%B8%B0.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a> # 변수의 이름 목록에서 현재 변수가 몇 번째 항목인지 찾기
# ---> <a href='vscode-notebook-cell:/d%3A/jihun5/jupyter/04-%EC%B6%94%EB%A1%A0%EC%A0%81_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D/04-5%20%EB%A1%9C%EC%A7%80%EC%8A%A4%ED%8B%B1%ED%9A%8C%EA%B7%80/vif%EA%B0%92%20%EB%82%AE%EC%B6%94%EA%B8%B0.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a> j = name_list.index(name)
#      <a href='vscode-notebook-cell:/d%3A/jihun5/jupyter/04-%EC%B6%94%EB%A1%A0%EC%A0%81_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D/04-5%20%EB%A1%9C%EC%A7%80%EC%8A%A4%ED%8B%B1%ED%9A%8C%EA%B7%80/vif%EA%B0%92%20%EB%82%AE%EC%B6%94%EA%B8%B0.ipynb#X14sZmlsZQ%3D%3D?line=13'>14</a> vif = 0
#      <a href='vscode-notebook-cell:/d%3A/jihun5/jupyter/04-%EC%B6%94%EB%A1%A0%EC%A0%81_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D/04-5%20%EB%A1%9C%EC%A7%80%EC%8A%A4%ED%8B%B1%ED%9A%8C%EA%B7%80/vif%EA%B0%92%20%EB%82%AE%EC%B6%94%EA%B8%B0.ipynb#X14sZmlsZQ%3D%3D?line=15'>16</a> # 0번째인 Intercept는 제외
#
# ValueError: '유흥업소' is not in list

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
for i in range(0, len(model.exog_names)):
    vif = variance_inflation_factor(model.exog, i)

    if vif < 10:
        print("%s의 VIF: %f (good)" % (model.exog_names[i], vif))
    else:
        print("%s의 VIF: %f (bad)" % (model.exog_names[i], vif))
# Out:
# 아파트/연립다세대의 VIF: 9.323762 (good)
# 노상의 VIF: 11.139293 (bad)
# 숙박업소의 VIF: 2.903052 (good)
# 고속도로의 VIF: 2.637403 (good)
# 슈퍼마켓의 VIF: 5.804303 (good)
# 공장의 VIF: 7.829859 (good)
# 지하철의 VIF: 1.527831 (good)
# 종교기관의 VIF: 7.513935 (good)
# 주차장의 VIF: 2.489107 (good)

# %%
mylist = []

for i in my['variables']:
    if i['name'] == 'Intercept':
        continue

    item = {
        "독립변수": i['name'],
        "B": i['coef'],
        "표준오차": i['std err'],
        "β": i['Beta'],
        "t": "%s*" % i['t'],
        "유의확률" : i['P-value'],
        "VIF": i["VIF"]
    }

    mylist.append(item)

df = DataFrame(mylist, index=['전국','전국','전국','전국','전국','전국','전국','전국','전국','전국'])
df.index.name = '종속변수'
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\jihun5\jupyter\04-추론적_데이터_분석\04-5 로지스틱회귀\vif값 낮추기.ipynb 셀 10 line 3
#       <a href='vscode-notebook-cell:/d%3A/jihun5/jupyter/04-%EC%B6%94%EB%A1%A0%EC%A0%81_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D/04-5%20%EB%A1%9C%EC%A7%80%EC%8A%A4%ED%8B%B1%ED%9A%8C%EA%B7%80/vif%EA%B0%92%20%EB%82%AE%EC%B6%94%EA%B8%B0.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> mylist = []
# ----> <a href='vscode-notebook-cell:/d%3A/jihun5/jupyter/04-%EC%B6%94%EB%A1%A0%EC%A0%81_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D/04-5%20%EB%A1%9C%EC%A7%80%EC%8A%A4%ED%8B%B1%ED%9A%8C%EA%B7%80/vif%EA%B0%92%20%EB%82%AE%EC%B6%94%EA%B8%B0.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> for i in my['variables']:
#       <a href='vscode-notebook-cell:/d%3A/jihun5/jupyter/04-%EC%B6%94%EB%A1%A0%EC%A0%81_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D/04-5%20%EB%A1%9C%EC%A7%80%EC%8A%A4%ED%8B%B1%ED%9A%8C%EA%B7%80/vif%EA%B0%92%20%EB%82%AE%EC%B6%94%EA%B8%B0.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>     if i['name'] == 'Intercept':
#       <a href='vscode-notebook-cell:/d%3A/jihun5/jupyter/04-%EC%B6%94%EB%A1%A0%EC%A0%81_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D/04-5%20%EB%A1%9C%EC%A7%80%EC%8A%A4%ED%8B%B1%ED%9A%8C%EA%B7%80/vif%EA%B0%92%20%EB%82%AE%EC%B6%94%EA%B8%B0.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a>         continue
#
# KeyError: 'variables'

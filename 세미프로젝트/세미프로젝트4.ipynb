# %%
# ppt, word 등 제출 형식은 자유 결정
# 작성이 완료된 파일을 leekh4232@kakao.com
# 6월 29일까지

# %%
# 수집할 데이터에 대한 관심사가 무엇인지 기술

# %%
# 관심사와 관련된 데이터를 수집할 수 있는 웹사이트
url1 = 'https://brunch.co.kr/@gorrajeju/775'
url2 = 'https://menupick.tistory.com/15'
url3 = 'https://welcome8007.com/33'
url4 = 'https://www.maybugs.com/news/articleView.html?idxno=581068'
url5 = 'https://monimoney.tistory.com/entry/%EB%B9%84-%EC%98%A4%EB%8A%94-%EB%82%A0-%EB%A8%B9%EC%9C%BC%EB%A9%B4-%EB%8D%94-%EB%A7%9B%EC%9E%88%EB%8A%94-%EC%9A%94%EB%A6%AC'

# %%
import requests
from bs4 import BeautifulSoup
from pandas import DataFrame

# %%
userAgent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"

# %%
# 접속객체 생성
session = requests.Session()
# 접속객체에 부가정보(header) 삽입하기
session.headers.update({
    "Referer": "",
    "User-Agent": userAgent
})

# %%
# 생성한 접속객체를 활용하여 API에 접속
r = session.get(url4)
if r.status_code != 200:
    msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
    raise Exception(msg)

# %%
# 인코딩 형식 지정하여 beautifulsoup객체를 생성
r.encoding = "euc-kr" # 이 홈페이지는 euc-kr로 해야함
soup = BeautifulSoup(r.text)
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="750c1156efe781af5d64253ebd36556f4ad471d9" name="naver-site-verification"/>
# <meta content="비 올때 먹기좋은 음식 추천 TOP9 - maybugs " property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="http://www.maybugs.com/news/articleView.html?idxno=581068" property="og:url"/>
# <meta content="http://www.maybugs.com/news/photo/201804/581068_413310_4425.jpg" property="og:image"/>
# <meta content="요즘같이 비가 하늘에 구멍 뚤린듯 미친듯이 쏟아질 때에는 집에서 조용히 있는게 제일 좋은데요. 하지만 누구나 비가오면 생각나는 음식이 있기 마련..." property="og:description"/>
# <!-- <meta property="og:article:author" content=""/> -->
# <meta content="maybugs, 언론포털,다양한 정보와 유용한 콘텐츠  " name="description"/>
# <title>비 올때 먹기좋은 음식 추천 TOP9 - maybugs </title>
# <link href="/css/style.css?1203" rel="stylesheet" type="text/css"/>
# <link href="/MenuSkin/Design_02/Menu_Style.css?170110" rel="stylesheet" type="text/css"/>
# <link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="/rss/allArticle.xml" rel="alternate" title="비 올때 먹기좋은 음식 추천 TOP9 - maybugs " type="application/rss+xml"/>
# <link href="/image2006/favicon.ico" rel="shortcut icon"/>
# <script src="/script/user.js?2020301" type="text/javascript"></script>
# <script src="/script/font.js" type="text/javascript"></script>
# <script src="/script/banner.js?0611" type="text/javascript"></script>
# <script src="/script/ad.control.js" type="text/javascript"></script>
# <script src="/script/poll.js?191201" type="text/javascript"></script>
# <script src="/script/vod.js" type="text/javascript"></script>
# <script src="//code.jquery.com/jquery-3.2.1.min.js" type="text/javascript"></script>
# <script src="/script/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script src="/script/jquery.cycle.js" type="text/javascript"></script>
# <script src="/script/jquery-easing-1-3.js" type="text/javascript"></script>
# <script src="/MenuSkin/Design_02/Menu_Bar.js" type="text/javascript"></script>
# <script src="/script/resizePhoto.js" type="text/javascript"></script>
# <script src="/script/floating.banner.js" type="text/javascript"></script>
# <script src="/script/onScroll.js" type="text/javascript"></script>
# <script src="/script/slick.js" type="text/javascript"></script>
# <script language="javascript">
# <!--
# // 현재시간  추가
# var ___currentTime = parseInt("1687855445", 10);
#
# // 즐겨찾기 스크립트
# function bookmark() {
# 	window.external.AddFavorite("http://www.maybugs.com", "maybugs")
# }
#
# /// 통합검색셀렉트
# function viewSchselopt() {
# 	var schselopt = document.getElementById("schselopt_list");
#
# 	if(schselopt.style.display=="block") {
# 		schselopt.style.display="none";
# 	} else {
# 		schselopt.style.display="block";
# 	}
# }
#
# function schChange(code,title) {
# 	var schselopt = document.getElementById("schselopt_list");
# 	var secTitle = document.getElementById("secTitle");
#
# 	schselopt.style.display="none";
#
# 	document.topSearchForm.sc_section_code.value=code;
# 	secTitle.innerHTML = title;
# }
#
# //모바일 체크
# ad_check_mobile = "";
# var adStrUserAgent = window.navigator.userAgent;
#
# if(adStrUserAgent!= null)
# {
# 	 if(
# 		  adStrUserAgent.indexOf("Android") != -1 ||    //Android
# 		  adStrUserAgent.indexOf("SAMSUNG") != -1 ||     //samsung
# 		  adStrUserAgent.indexOf("PSP") != -1 ||         //psp
# 		  adStrUserAgent.indexOf("PLAYSTATION") != -1 || //playstation
# 		  adStrUserAgent.indexOf("lgtelecom") != -1 ||   //LGT
# 		  adStrUserAgent.indexOf("Smartphone") != -1 ||  //스마트폰
# 		  adStrUserAgent.indexOf("Symbian") != -1 ||     //심비안폰
# 		  adStrUserAgent.indexOf("PPC") != -1 ||         //??
# 		  adStrUserAgent.indexOf("Windows CE") != -1 ||  //PDA
# 		  adStrUserAgent.indexOf("iPhone") != -1 ||      //애플폰
# 		  adStrUserAgent.indexOf("iPod") != -1 )         //애플
# 	 {
# 		ad_check_mobile = 1;
# 	 }
# 	 else
# 	 {
# 		ad_check_mobile = 0;
# 	 }
# }
#
# //검색어 입력 확인
# function SearchCheck() {
# 	var flag=0;
#
# 	if(document.topSearchForm.sc_word.value=="") {
# 		alert("검색 할 기사를 입력하세요.");
# 		document.topSearchForm.sc_word.focus();
# 		flag=1;
# 	}
#
# 	if(flag==0) {
# 		document.topSearchForm.submit();
# 	}
#
# 	return;
# }
#
# //검색 창 바꾸기
# function setSearchBox(idx) {
# 	for (i=1;i<=1;i++) {
# 	var objtab = document.getElementById("Search1");
# 	var objtab2 = document.getElementById("Search2");
# 	if (!objtab || !objtab2) { return; }
# 		objtab.style.display = "block";
# 		objtab2.style.display = "none";
# 	if ( i == idx ) {
# 		objtab.style.display = "none";
# 		objtab2.style.display = "block";
# 		document.topSearchForm.sword.focus();
# 		}
# 	}
# }
# //-->
# </script>
# <!-- googleAnalytics 170116 -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-90421116-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-88758930-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-88758930-1');
# </script>
# <script>
#   window.fbAsyncInit = function() {
#     FB.init({
#       appId      : 'maybugs',
#       cookie     : true,
#       xfbml      : true,
#       version    : 'v10.0'
#     });
#
#     FB.AppEvents.logPageView();
#
#   };
#
#   (function(d, s, id){
#      var js, fjs = d.getElementsByTagName(s)[0];
#      if (d.getElementById(id)) {return;}
#      js = d.createElement(s); js.id = id;
#      js.src = "https://connect.facebook.net/en_US/sdk.js";
#      fjs.parentNode.insertBefore(js, fjs);
#    }(document, 'script', 'facebook-jssdk'));
# </script>
# </head>
# <body>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center">
# <!-- 레이어 팝업 : s -->
# <script src="/popupManagerVer2/js/flow.script.js" type="text/javascript"></script>
# <script src="/popupManagerVer2/js/dom.drag.js" type="text/javascript"></script>
# <script language="javascript">
# 	function layerClose(layer) {
# 		document.getElementById(layer).style.display = "none";
# 	}
#
# 	function layerEnd(layer, day) {
# 		document.getElementById(layer).style.display = "none";
# 		setCookieLayer(layer, 'ok', day);
# 	}
#
# 	function layerEndChk(idx) {
# 		document.getElementById('layerPopup_'+idx).style.display = "none";
# 		if(document.getElementById('layerChk_'+idx).checked == true){
# 			var day = parseInt(document.getElementById('expires_time_'+idx).value);
# 			setCookieLayer('layerPopup_'+idx, 'ok', day);
# 		}
# 	}
#
# 	function setCookieLayer( name, value, expiredays ) {
# 		var todayDate = new Date();
# 		todayDate.setDate( todayDate.getDate() + expiredays );
#
# 		todayDate.setHours(0);
# 		todayDate.setMinutes(0);
# 		todayDate.setSeconds(0);
#
# 		document.cookie = name + "=" + escape( value ) + ";DOMAIN=www.maybugs.com; path=/; expires=" + todayDate.toGMTString() + ";"
# 	}
#
# </script>
# <!-- 레이어 팝업 처리 : s -->
# <table border="0" cellpadding="0" cellspacing="0" width="960">
# <tr>
# <td>
# <div style="POSITION: relative; width:100%;z-index:100000;">
# <div id="empty" style="position:absolute; display:block;"></div>
# </div>
# </td>
# </tr>
# </table>
# <!--레이어 팝업 처리 : e--><!-- 레이어 팝업 : e -->
# <!--
# 	윈도우 팝업 : s
# 	client 모니터 사이즈를 넘기기 위해서 iframe으로 처리.
# -->
# <iframe id="windowPopup" style="display:none"></iframe>
# <script language="javascript">
# 	document.getElementById("windowPopup").contentWindow.location.href = "/popupManagerVer2/windowPopup.html?windowWidth=" + screen.width + "&parentPage=/news/articleView.html";
# </script>
# <!-- 윈도우 팝업 : e -->
# <script type="text/javascript">
# <!--
# //메뉴 스타일 불러옴 : 메뉴 /script/menubar.js 와 같이 사용되어야 함
# //submenuStyle	: 서브메뉴 펼침 스타일 (horizon : 가로로, vertical : 세로 슬라이딩)
# var exceptIdx = new Array(); //제외할 메뉴 인덱스번호 (0부터 시작:type integer)
# var submenuStyle="horizon";
#
# //-->
# </script>
# <script type="text/javascript">
# <!--
# (function($) {
# 	$(function() {
#
# 		//rolling
# 		$( '.top-hotpic-list' ).cycle({
# 			fx:     'scrollVert',
# 			timeout: 5000,
# 			pause: 1,
# 			easing: 'easeOutExpo'
# 		});
#
# 	});
# })(jQuery);
# //-->
# </script>
# <!-- 로고영역 -->
# <div id="HeadLogo">
# <div id="Default_Warp">
# <!-- 로고/배너 -->
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td width="250"><a href="http://www.maybugs.com" onfocus="this.blur();" title="maybugs"><img alt="maybugs" border="0" src="/image2006/logo.gif"/></a></td>
# <td align="center">
# <!-- 통합검색 -->
# <div id="SearchForm">
# <!-- <fieldset>
# 							<form action="http://search.maybugs.com" method="get" name="topSearchForm" id="topSearchForm">
# 								<input type="hidden" name="char" value="EUC-KR">
# 								<input maxlength="255" name="" class="inptxt" id="Search1" value="" onclick="setSearchBox(1);">
# 								<input maxlength="255" name="sword" id="Search2" style="display:none;" onkeydown="if(event.keyCode==13){SearchCheck();}">
# 								<button title="기사검색" onClick="setSearchBox(1);">기사검색</button>
# 							</form>
# 						</fieldset>
# 					 -->
# <fieldset>
# <form action="https://www.maybugs.com/news/articleList.html" id="topSearchForm" method="post" name="topSearchForm">
# <input name="sc_sdate" type="hidden" value="2022-12-27"/>
# <input name="sc_edate" type="hidden" value="2023-06-27"/>
# <input name="sc_area" type="hidden" value="A"/>
# <input name="view_type" type="hidden" value="sm"/>
# <input class="inptxt" id="Search1" maxlength="255" name="" onclick="setSearchBox(1);" value="검색 할 키워드를 입력하세요."/>
# <input id="Search2" maxlength="255" name="sc_word" onkeydown="if(event.keyCode==13){SearchCheck();}" style="display:none;"/>
# <button onclick="SearchCheck();setSearchBox(1);" title="기사검색">검색</button>
# </form>
# </fieldset>
# <!--추천검색어 180309삭제 <iframe src="/Autobox/bstRef_1.html" width="415" height="25" frameborder="0" scrolling="no" noresize class="float-left"></iframe>-->
# </div>
# </td>
# <td align="right" width="250">
# <!--170710_재능등록--<script language="javascript" src="/bannerManager/inc/18.html"></script><!--170710_재능등록-->
# <!--180402_포스트등록--<script language="javascript" src="/bannerManager/inc/55.html"></script><!--180402_포스트등록-->
# <!--post_210105--><script language="javascript" src="/bannerManager/inc/160.html"></script><!--post_210105-->
# </td>
# </tr>
# </table>
# </div>
# </div>
# <!-- 최종편집 -->
# <div id="TopMark">
# <div id="Default_Warp">
# <!--<div class="update"><strong>UPDATE</strong> : 2023.6.27 화 17:40</div>-->
# <!-- 로그인/회원가입 -->
# <ul class="btn-login">
# <li class="nobr"><a href="/member/login.html"><strong>log in</strong></a></li><li><a href="/member/memberAgree.html?kind=member">Register</a></li> </ul>
# <!-- <div id="login3"><a href="http://www.maybugs.com/member/myHome.html?user_id=" target="_self">마이채널 바로가기(My Channel Click) </a></div> -->
# <div id="login3"><a href="http://www.maybugs.com/member/myHome.html?user_id=" target="_self">내지갑(My wallet)</a></div>
# <div class="float-right dis-block width-260" id="Bsw_Wrap">
# <div class="Bsw_Wrap_title float-left dis-block width-90" style="background:url('/box/box_news/autobox_design.png') no-repeat 85px -786px;text-align:left;color:rgba(0,0,0, 1)"><strong>popular word</strong></div>
# <div class="width-160 dis-block flow-hide">
# <div class="auto-hotE border-box" id="cron_BestSearchWord_new">
# <div class="rollBox border-box"><div class="posi-re auto-article rollInBox"><div class="auto-hotA rollInBoxA">
# <span class="num point-num">1</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad auto-fontF" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=아이브&amp;encode=Y" target="_top">아이브</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num point-num">2</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad auto-fontF" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=카리나&amp;encode=Y" target="_top">카리나</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num point-num">3</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad auto-fontF" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=킹더랜드&amp;encode=Y" target="_top">킹더랜드</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num">4</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad auto-fontF" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=러시아&amp;encode=Y" target="_top">러시아</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num">5</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad auto-fontF" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=조혜원&amp;encode=Y" target="_top">조혜원</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num">6</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad auto-fontF" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=이강인&amp;encode=Y" target="_top">이강인</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num">7</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad auto-fontF" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=악귀&amp;encode=Y" target="_top">악귀</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num">8</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad auto-fontF" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=아이유&amp;encode=Y" target="_top">아이유</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num">9</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad auto-fontF" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=송혜교&amp;encode=Y" target="_top">송혜교</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num">10</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad auto-fontF" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=황의조&amp;encode=Y" target="_top">황의조</a></div>
# </div></div><i>아이콘</i></div>
# <div class="rollBox2 border-box"><div class="posi-re auto-article rollInBox"><div class="auto-hotA rollInBoxA">
# <span class="num point-num">1</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=아이브&amp;encode=Y" target="_top">아이브</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num point-num">2</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=카리나&amp;encode=Y" target="_top">카리나</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num point-num">3</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=킹더랜드&amp;encode=Y" target="_top">킹더랜드</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num">4</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=러시아&amp;encode=Y" target="_top">러시아</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num">5</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=조혜원&amp;encode=Y" target="_top">조혜원</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num">6</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=이강인&amp;encode=Y" target="_top">이강인</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num">7</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=악귀&amp;encode=Y" target="_top">악귀</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num">8</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=아이유&amp;encode=Y" target="_top">아이유</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num">9</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=송혜교&amp;encode=Y" target="_top">송혜교</a></div>
# </div><div class="auto-hotA rollInBoxA">
# <span class="num">10</span>
# <div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a class="dis-block size-12 OnLoad" href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&amp;sc_order_by=R&amp;sc_word=황의조&amp;encode=Y" target="_top">황의조</a></div>
# </div></div></div>
# </div>
# <script type="text/javascript">
# 	(function($){
# 		rollArticle("#cron_BestSearchWord_new","3000");
# 	})(jQuery);
# 	</script>
# </div>
# </div>
# </div>
# </div>
# <!--// 로그인바 -->
# <!--<div class="mHeight_B">상단여백</div>
# <div id="ND_Warp" style="margin-top">
#
#
#
#
# <!--투표상단 타이틀--
# <!--투표상단 타이틀-->
# <!-- 로그인바 //-->
# <!--// 로그인바 -->
# <script type="text/javascript">resizePhoto.addEvt(window, "load", resizePhoto.init);//이미지 리사이즈+light box</script>
# <!--기사뷰 플로팅배너-->
# <style>/**/
# #floating_banner_body {position:relative; margin:0 auto; width:960px;}
# #floating_banner_left	{position:absolute; width:120px; z-index:100; left:-130px; top:0px;}
# #floating_banner_right {position:absolute; width:120px; z-index:100; right:-130px; top:0px;}
# </style>
# <div id="floating_banner_body">
# <ul class="nd_floating_banner" data-duration="300" data-parent-target="ND_Warp" data-scroll="n" data-top-margin="5" id="floating_banner_left">
# <li>
# </li>
# </ul>
# <ul class="nd_floating_banner" data-duration="300" data-scroll="n" data-top-margin="5" id="floating_banner_right">
# <li>
# </li>
# </ul>
# </div>
# <!--기사뷰 플로팅배너-->
# <!--<table cellpadding="0" cellspacing="0" border="0" width="960" align="center">
# 	<tr>
# 		<td width="690" align="left" valign="top" style="padding:15px 0;">
#
#
#
# <!-- 슈퍼포스팅 20개 더보기 2019-03-28 김지영 사원 S / 827580
# <script>
# jQuery(document).ready(function($){
# 	$("#super_more").click(function(){
# 		var more_display = $(".super_post_more").css("display");
#
# 		if(more_display == "none"){
# 			$(".super_post_more").css("display","block");
# 			$(this).text("접기");
# 		}else{
# 			$(this).text("더보기");
# 			$(".super_post_more").css("display","none");
# 		}
# 	});
# });
# </script>
# <!-- 슈퍼포스팅 20개 더보기 2019-03-28 김지영 사원 S / 827580-->
# <!-- 3인간 많이본포스트 180911 -->
# <!-- S1N18", "S1N12", "S1N17", "S1N19", "S1N29" -->
# <div class="MayWrap">
# <div class="MayContain">
# <div class="MayNewsbox">
# <a class="news-btn" href="https://www.maybugs.com/?mCheck=Y" style="" target="_blank">About</a>
# <a class="news-btn" href="https://www.maybugs.com/news/section.html?section=S1N1&amp;view_type=sm" style="" target="_blank">뉴스(News)</a>
# <a class="news-btn" href="https://www.maybugs.com/news/articleList.html?mode=super_user&amp;view_type=tm" style="" target="_blank">콘텐츠(blogs)</a>
# <a class="news-btn" href="https://www.maybugs.com/poll/pollList.html" style="" target="_blank">설문(polls)</a>
# <a class="news-btn" href="https://www.maybugs.com/news/articleList.html?sc_section_code=S1N45&amp;view_type=sm" style="" target="_blank">미션(missions)</a>
# <a class="news-btn" href="http://maybugsmall.com/" style="" target="_blank">쇼핑몰(shops)</a>
# <a class="news-btn" href="https://www.maybugs.com/bbs/list.html?table=bbs_58   " style="" target="_blank">공지 (Notice)</a>
# <!-- <a href="https://www.maybugs.com/member/myHome.html?user_id=maybugs" style="" class="news-btn" target="_blank">내지갑(my wallet)</a> -->
# <a class="write-btn" href="/news/userArticleWriteForm.html?mode=input§ionCode=S1N17" style="" target="_blank">Life 쓰러가기</a>
# </div>
# <div class="MayTltle">
# <strong>Life</strong>
# </div>
# <div class="MayContants">
# <!--
# -->
# <!--업체등급관련-->
# <!--업체등급관련-->
# <a class="active" href="/news/articleList.html?sc_section_code=S1N17&amp;sc_sub_section_code=S2N489&amp;view_type=sm" target="_top">Baby&amp;Mom</a><a class="active" href="/news/articleList.html?sc_section_code=S1N17&amp;sc_sub_section_code=S2N87&amp;view_type=sm" target="_top">반려동물</a><a class="active" href="/news/articleList.html?sc_section_code=S1N17&amp;sc_sub_section_code=S2N88&amp;view_type=sm" target="_top">패션&amp;미용</a><a class="active" href="/news/articleList.html?sc_section_code=S1N17&amp;sc_sub_section_code=S2N89&amp;view_type=sm" target="_top">요리&amp;레시피</a><a class="active" href="/news/articleList.html?sc_section_code=S1N17&amp;sc_sub_section_code=S2N252&amp;view_type=sm" target="_top">원예&amp;재배</a><a class="active" href="/news/articleList.html?sc_section_code=S1N17&amp;sc_sub_section_code=S2N256&amp;view_type=sm" target="_top">인테리어&amp;DIY</a><a class="active" href="/news/articleList.html?sc_section_code=S1N17&amp;sc_sub_section_code=S2N266&amp;view_type=sm" target="_top">생활정보&amp;TIP</a><a class="active" href="/news/articleList.html?sc_section_code=S1N17&amp;sc_sub_section_code=S2N290&amp;view_type=sm" target="_top">환경</a><a class="active" href="/news/articleList.html?sc_section_code=S1N17&amp;sc_sub_section_code=S2N310&amp;view_type=sm" target="_top">나의 일기(My Diary)</a><a class="active" href="/news/articleList.html?sc_section_code=S1N17&amp;sc_sub_section_code=S2N273&amp;view_type=sm" target="_top">일상생활(자유주제)</a><a class="active" href="/news/articleList.html?sc_section_code=S1N17&amp;sc_sub_section_code=S2N291&amp;view_type=sm" target="_top">종합</a>
# </div>
# <div class="MayP">
# <span></span>
# </div>
# </div>
# </div>
# <div id="article-control">
# <!-- 코인관련 위젯 시작 리스트별 노출 START-->
# <!-- 코인관련 위젯 끝 리스트별 노출 END-->
# <!-- S1N1 상단 박스 -->
# <!-- S1N1 상단 박스 -->
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="960">
# <tr>
# <td align="center" style="padding:0 0 20px 0;" valign="top" width="630">
# <!--190415추가-->
# <!--190415추가 끝-->
# <div id="divLAS" style="visibility:hidden;"></div>
# <script type="text/javascript">
# // 기사면 상단 네비게이션 호출
# articleHeader.setScroll();
# </script>
# <div id="article-header-title" style="display:none;">
# <div class="aht-btn">
# <ul>
# <li class="prev">
# <a href="javascript:articleHeader.move(
# 				'prev',
# 				'embargo_date',
# 				'1524368472_581068',
# 				'S1N17',
# 				'S2N266',
# 				'')">
# 					이전
# 				</a>
# </li>
# <li class="next">
# <a href="javascript:articleHeader.move(
# 				'next',
# 				'embargo_date',
# 				'1524368472_581068',
# 				'S1N17',
# 				'S2N266',
# 				'')">
# 					다음
# 				</a>
# </li>
# </ul>
# </div>
# <div class="aht-defalut">
# <div class="aht-logo"><a href="/" style="width:200px;background:url('http://www.maybugs.com/image2006/print_logo.gif') no-repeat left center;">로고</a></div>
# <div class="aht-title" style="width:616px;left:200px;">비 올때 먹기좋은 음식 추천 TOP9</div>
# <div class="aht-sns">
# <ul>
# <li class="facebook"><a href="http://www.facebook.com/sharer.php?u=http%3A%2F%2Fwww.maybugs.com%2Fnews%2FarticleView.html%3Fidxno%3D581068&amp;t=%EB%B9%84+%EC%98%AC%EB%95%8C+%EB%A8%B9%EA%B8%B0%EC%A2%8B%EC%9D%80+%EC%9D%8C%EC%8B%9D+%EC%B6%94%EC%B2%9C+TOP9" target="_blank" title="페이스북">페이스북</a></li>
# <li class="twitter"><a href="http://twitter.com/home?status=%EB%B9%84+%EC%98%AC%EB%95%8C+%EB%A8%B9%EA%B8%B0%EC%A2%8B%EC%9D%80+%EC%9D%8C%EC%8B%9D+%EC%B6%94%EC%B2%9C+TOP9+http%3A%2F%2Fwww.maybugs.com%2Fnews%2FarticleView.html%3Fidxno%3D581068" target="_blank" title="트위터">트위터</a></li>
# <li class="google"><a href="http://www.google.com/bookmarks/mark?op=add&amp;title=%EB%B9%84+%EC%98%AC%EB%95%8C+%EB%A8%B9%EA%B8%B0%EC%A2%8B%EC%9D%80+%EC%9D%8C%EC%8B%9D+%EC%B6%94%EC%B2%9C+TOP9&amp;bkmk=http://www.maybugs.com/news/articleView.html?idxno=581068" target="_blank" title="구글">구글</a></li>
# <li class="kako"><a href="javascript:window.open('https://story.kakao.com/share?url=http%3A%2F%2Fwww.maybugs.com%2Fnews%2FarticleView.html%3Fidxno%3D581068', 'kakaostory', 'width=800, height=500' );returnfalse;" title="카카오스토리">카카오스토리</a></li>
# <li class="mail"><a href="javascript:articleMail('581068');" title="메일">메일</a></li>
# </ul>
# </div>
# </div>
# </div>
# <table border="0" cellpadding="0" cellspacing="0" width="960">
# <tr>
# <td>
# <div id="article-wrap">
# <!-- 카테고리 -->
# <div class="category border-box" id="article-cate">
# <span class="home border-box"><a href="http://www.maybugs.com">HOME</a></span>
# <span class="sec1"><a href="/news/articleList.html?sc_section_code=S1N17&amp;view_type=sm">Life</a></span> <span class="sec2"><a href="/news/articleList.html?sc_sub_section_code=S2N266&amp;view_type=sm">생활정보&amp;TIP</a></span>
# </div>
# <div class="headline border-box">
# <font class="headline-title"><!--CM_TITLE-->비 올때 먹기좋은 음식 추천 TOP9<!--/CM_TITLE--></font><font class="headline-sub">비올때 먹는 음식</font> </div>
# <div class="headline-info border-box" id="head-info">
# <!-- 180212 원본
# 					<div class="info">
# 						<ul>
# 							<li class="name">김두하</li>
# 							<li class="date">승인 2018.04.22 12:41</li>
# 																					<li class="reply">댓글 <a href="/news/replyView.html?idxno=581068">1</a></li>
# 						</ul>
# 					</div>
# 					 -->
# <div class="info">
# <ul>
# <li class="name">
# <a class="reply-alink" href="http://www.maybugs.com/member/profile.html?user_id=engk130" title="마이홈 가기">
# <p 0="" 0;"="" class="reply-photo" no-repeat="" style="background:url('/member/memImgDown.php?filename=engk130.png');"></p>
# <span>브로콜리(engk130)</span><span style="vertical-align:sub;"><img alt="VIP" src="http://www.maybugs.com/image2006/ico_VIP.png"/></span>
# </a>
# </li>
# <li class="date">승인 2018.04.22 12:41</li>
# <li class="reply">댓글 <a href="/news/replyView.html?idxno=581068">1</a></li>
# <!-- <li class="reply">조회수 7995</li> -->
# </ul>
# </div>
# <div class="option">
# <ul class="type">
# <li class="nobr"><a href="javascript:fontPlus();">글씨키우기</a></li>
# <li><a href="javascript:fontMinus();">글씨줄이기</a></li>
# </ul>
# <ul class="plus">
# <li class="nobr"><a href="javascript:articleMail('581068');">메일보내기</a></li>
# <li><a href="javascript:articlePrint('581068');">인쇄하기</a></li>
# </ul>
# <ul class="sns">
# <li class="facebook"><a href="http://www.facebook.com/sharer.php?u=http%3A%2F%2Fwww.maybugs.com%2Fnews%2FarticleView.html%3Fidxno%3D581068&amp;t=%EB%B9%84+%EC%98%AC%EB%95%8C+%EB%A8%B9%EA%B8%B0%EC%A2%8B%EC%9D%80+%EC%9D%8C%EC%8B%9D+%EC%B6%94%EC%B2%9C+TOP9" target="_blank" title="페이스북">페이스북</a></li>
# <li class="twitter"><a href="http://twitter.com/home?status=%EB%B9%84+%EC%98%AC%EB%95%8C+%EB%A8%B9%EA%B8%B0%EC%A2%8B%EC%9D%80+%EC%9D%8C%EC%8B%9D+%EC%B6%94%EC%B2%9C+TOP9+http%3A%2F%2Fwww.maybugs.com%2Fnews%2FarticleView.html%3Fidxno%3D581068" target="_blank" title="트위터">트위터</a></li>
# <li class="google"><a href="http://www.google.com/bookmarks/mark?op=add&amp;title=%EB%B9%84+%EC%98%AC%EB%95%8C+%EB%A8%B9%EA%B8%B0%EC%A2%8B%EC%9D%80+%EC%9D%8C%EC%8B%9D+%EC%B6%94%EC%B2%9C+TOP9&amp;bkmk=http://www.maybugs.com/news/articleView.html?idxno=581068" target="_blank" title="구글">구글</a></li>
# <li class="kako"><a href="javascript:window.open('https://story.kakao.com/share?url=http%3A%2F%2Fwww.maybugs.com%2Fnews%2FarticleView.html%3Fidxno%3D581068', 'kakaostory', 'width=800, height=500' );returnfalse;" title="카카오스토리">카카오스토리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </td>
# </tr>
# </table>
# <div id="article-control">
# <table border="0" cellpadding="0" cellspacing="0" width="960">
# <tr>
# <td style="padding:0 0 15px" valign="top" width="630">
# <div id="article-wrap">
# <!-- content -->
# <div class="content border-box">
# <div class="cont-body" id="articleBody" style="word-break:break-all;word-wrap:break-word;">
# <table align="center" border="0" cellpadding="0" cellspacing="0" id="photo_413310" style="margin-bottom:20px;">
# <tbody>
# <tr>
# <td align="center"><img border="0" src="/news/photo/201804/581068_413310_4425.jpg" style="display:block;"/></td>
# </tr>
# </tbody>
# </table>
# <p>요즘같이 비가 하늘에 구멍 뚤린듯 미친듯이 쏟아질 때에는 집에서 조용히 있는게 제일 좋은데요. 하지만 누구나 비가오면 생각나는 음식이 있기 마련입니다. 비가올 때 생각나고 먹기좋은 음식 9가지를 소개해드릴텐데요. 배달의민족 우리나라 밖에 나갈필요없이 무엇이든지 시켜먹을 수 있습니다!</p>
# <p><img alt="비 올때 먹기좋은 음식" filemime="image/jpeg" filename="꾸미기_maxresdefault.jpg" height="472" original="yes" src="http://cfile25.uf.tistory.com/image/211A064759747DA70354E6" srcset="//img1.daumcdn.net/thumb/R1920x0/?fname=http%3A%2F%2Fcfile25.uf.tistory.com%2Fimage%2F211A064759747DA70354E6 1920w, //img1.daumcdn.net/thumb/R960x0/?fname=http%3A%2F%2Fcfile25.uf.tistory.com%2Fimage%2F211A064759747DA70354E6 960w, //img1.daumcdn.net/thumb/R720x0/?fname=http%3A%2F%2Fcfile25.uf.tistory.com%2Fimage%2F211A064759747DA70354E6 720w, //img1.daumcdn.net/thumb/R640x0.q70/?fname=http%3A%2F%2Fcfile25.uf.tistory.com%2Fimage%2F211A064759747DA70354E6 640w, //img1.daumcdn.net/thumb/R480x0.q70/?fname=http%3A%2F%2Fcfile25.uf.tistory.com%2Fimage%2F211A064759747DA70354E6 480w" width="840"/></p>
# <p><b>1. 부침개[전] + 막걸리</b></p>
# <p>비올 때 언제나 빠진적없는 부침개와 막걸리!! 아재들 입맛에는 이것보다 더한것이 있으랴~</p>
# <p><img alt="비 올때 먹기좋은 음식" filemime="image/jpeg" filename="꾸미기_d0021441_562d9a57b1383.jpg" height="560" original="yes" src="http://cfile8.uf.tistory.com/image/2205AA4A59747DB91A0AD5" srcset="//img1.daumcdn.net/thumb/R1920x0/?fname=http%3A%2F%2Fcfile8.uf.tistory.com%2Fimage%2F2205AA4A59747DB91A0AD5 1920w, //img1.daumcdn.net/thumb/R960x0/?fname=http%3A%2F%2Fcfile8.uf.tistory.com%2Fimage%2F2205AA4A59747DB91A0AD5 960w, //img1.daumcdn.net/thumb/R720x0/?fname=http%3A%2F%2Fcfile8.uf.tistory.com%2Fimage%2F2205AA4A59747DB91A0AD5 720w, //img1.daumcdn.net/thumb/R640x0.q70/?fname=http%3A%2F%2Fcfile8.uf.tistory.com%2Fimage%2F2205AA4A59747DB91A0AD5 640w, //img1.daumcdn.net/thumb/R480x0.q70/?fname=http%3A%2F%2Fcfile8.uf.tistory.com%2Fimage%2F2205AA4A59747DB91A0AD5 480w" width="840"/></p>
# <p><b>2. 얼큰한 짬뽕</b></p>
# <p>창 밖에 비가 추적추적 내릴땐 얼큰한 짬뽕국물 한번 마시면 속이다 후련해지죠~</p>
# <p><img alt="비 올때 먹기좋은 음식" filemime="image/jpeg" filename="꾸미기_copy(1479815800)-1376638276_4.jpg" height="560" src="http://cfile6.uf.tistory.com/image/23267D4B59747DD42906A6" srcset="//img1.daumcdn.net/thumb/R1920x0/?fname=http%3A%2F%2Fcfile6.uf.tistory.com%2Fimage%2F23267D4B59747DD42906A6 1920w, //img1.daumcdn.net/thumb/R960x0/?fname=http%3A%2F%2Fcfile6.uf.tistory.com%2Fimage%2F23267D4B59747DD42906A6 960w, //img1.daumcdn.net/thumb/R720x0/?fname=http%3A%2F%2Fcfile6.uf.tistory.com%2Fimage%2F23267D4B59747DD42906A6 720w, //img1.daumcdn.net/thumb/R640x0.q70/?fname=http%3A%2F%2Fcfile6.uf.tistory.com%2Fimage%2F23267D4B59747DD42906A6 640w, //img1.daumcdn.net/thumb/R480x0.q70/?fname=http%3A%2F%2Fcfile6.uf.tistory.com%2Fimage%2F23267D4B59747DD42906A6 480w" width="840"/></p>
# <p><b>3. 바지락 칼국수</b></p>
# <p>물놀이 하고 먹어도 맛있는 칼국수! 비오는날에는 더 맛있다죠?</p>
# <p><img alt="비 올때 먹기좋은 음식" filemime="image/jpeg" filename="꾸미기_e308a00da4ef3ee7d8623b2b6a4e9d55.jpg" height="560" src="http://cfile2.uf.tistory.com/image/21077B4E59747DE122C006" srcset="//img1.daumcdn.net/thumb/R1920x0/?fname=http%3A%2F%2Fcfile2.uf.tistory.com%2Fimage%2F21077B4E59747DE122C006 1920w, //img1.daumcdn.net/thumb/R960x0/?fname=http%3A%2F%2Fcfile2.uf.tistory.com%2Fimage%2F21077B4E59747DE122C006 960w, //img1.daumcdn.net/thumb/R720x0/?fname=http%3A%2F%2Fcfile2.uf.tistory.com%2Fimage%2F21077B4E59747DE122C006 720w, //img1.daumcdn.net/thumb/R640x0.q70/?fname=http%3A%2F%2Fcfile2.uf.tistory.com%2Fimage%2F21077B4E59747DE122C006 640w, //img1.daumcdn.net/thumb/R480x0.q70/?fname=http%3A%2F%2Fcfile2.uf.tistory.com%2Fimage%2F21077B4E59747DE122C006 480w" width="840"/></p>
# <p><b>4. 국밥</b></p>
# <p>애들은 모르는 그 맛! 얼큰한 국밥에 밥한공기 넣어 먹으면 크..</p>
# <p><img alt="비 올때 먹기좋은 음식" filemime="image/jpeg" filename="꾸미기_a0100413_4cfc80a29d19f.jpg" height="559" src="http://cfile5.uf.tistory.com/image/2404384A59747DEA1B2AEE" srcset="//img1.daumcdn.net/thumb/R1920x0/?fname=http%3A%2F%2Fcfile5.uf.tistory.com%2Fimage%2F2404384A59747DEA1B2AEE 1920w, //img1.daumcdn.net/thumb/R960x0/?fname=http%3A%2F%2Fcfile5.uf.tistory.com%2Fimage%2F2404384A59747DEA1B2AEE 960w, //img1.daumcdn.net/thumb/R720x0/?fname=http%3A%2F%2Fcfile5.uf.tistory.com%2Fimage%2F2404384A59747DEA1B2AEE 720w, //img1.daumcdn.net/thumb/R640x0.q70/?fname=http%3A%2F%2Fcfile5.uf.tistory.com%2Fimage%2F2404384A59747DEA1B2AEE 640w, //img1.daumcdn.net/thumb/R480x0.q70/?fname=http%3A%2F%2Fcfile5.uf.tistory.com%2Fimage%2F2404384A59747DEA1B2AEE 480w" width="840"/></p>
# <p><b>5. 아구 찜</b></p>
# <p>소주가 생각나는 아구 찜! 비오는날 친구와 같이 먹는 아구 찜은 굉장하죠~</p>
# <p><img alt="비 올때 먹기좋은 음식" filemime="image/jpeg" filename="꾸미기_a89b13cb4e3d562c981b0fb975500926.jpg" height="472" src="http://cfile8.uf.tistory.com/image/277DDE4F59747DF50A93FD" srcset="//img1.daumcdn.net/thumb/R1920x0/?fname=http%3A%2F%2Fcfile8.uf.tistory.com%2Fimage%2F277DDE4F59747DF50A93FD 1920w, //img1.daumcdn.net/thumb/R960x0/?fname=http%3A%2F%2Fcfile8.uf.tistory.com%2Fimage%2F277DDE4F59747DF50A93FD 960w, //img1.daumcdn.net/thumb/R720x0/?fname=http%3A%2F%2Fcfile8.uf.tistory.com%2Fimage%2F277DDE4F59747DF50A93FD 720w, //img1.daumcdn.net/thumb/R640x0.q70/?fname=http%3A%2F%2Fcfile8.uf.tistory.com%2Fimage%2F277DDE4F59747DF50A93FD 640w, //img1.daumcdn.net/thumb/R480x0.q70/?fname=http%3A%2F%2Fcfile8.uf.tistory.com%2Fimage%2F277DDE4F59747DF50A93FD 480w" width="840"/></p>
# <p><b>6. 삼겹살 + 소주</b></p>
# <p>우산을 털고 식당에 들어가 고기를 구우면서 친구와 소주한잔! 분위기에 취한답니다~</p>
# <p><img alt="비 올때 먹기좋은 음식" filemime="image/jpeg" filename="꾸미기_tumblr_mecpyimb851rl4xx4o1_1280.jpg" height="560" src="http://cfile27.uf.tistory.com/image/2634CA4F59747E0038274E" srcset="//img1.daumcdn.net/thumb/R1920x0/?fname=http%3A%2F%2Fcfile27.uf.tistory.com%2Fimage%2F2634CA4F59747E0038274E 1920w, //img1.daumcdn.net/thumb/R960x0/?fname=http%3A%2F%2Fcfile27.uf.tistory.com%2Fimage%2F2634CA4F59747E0038274E 960w, //img1.daumcdn.net/thumb/R720x0/?fname=http%3A%2F%2Fcfile27.uf.tistory.com%2Fimage%2F2634CA4F59747E0038274E 720w, //img1.daumcdn.net/thumb/R640x0.q70/?fname=http%3A%2F%2Fcfile27.uf.tistory.com%2Fimage%2F2634CA4F59747E0038274E 640w, //img1.daumcdn.net/thumb/R480x0.q70/?fname=http%3A%2F%2Fcfile27.uf.tistory.com%2Fimage%2F2634CA4F59747E0038274E 480w" width="840"/></p>
# <p><b>7. 우동</b></p>
# <p>휴게소의 음식 우동! 비오는 날에도 빠짐없이 등장하고 있어요~</p>
# <p><img alt="비 올때 먹기좋은 음식" filemime="image/jpeg" filename="꾸미기_5900424b022bd2738de6.jpg" height="630" src="http://cfile5.uf.tistory.com/image/263DA15059747E1C1D63D9" srcset="//img1.daumcdn.net/thumb/R1920x0/?fname=http%3A%2F%2Fcfile5.uf.tistory.com%2Fimage%2F263DA15059747E1C1D63D9 1920w, //img1.daumcdn.net/thumb/R960x0/?fname=http%3A%2F%2Fcfile5.uf.tistory.com%2Fimage%2F263DA15059747E1C1D63D9 960w, //img1.daumcdn.net/thumb/R720x0/?fname=http%3A%2F%2Fcfile5.uf.tistory.com%2Fimage%2F263DA15059747E1C1D63D9 720w, //img1.daumcdn.net/thumb/R640x0.q70/?fname=http%3A%2F%2Fcfile5.uf.tistory.com%2Fimage%2F263DA15059747E1C1D63D9 640w, //img1.daumcdn.net/thumb/R480x0.q70/?fname=http%3A%2F%2Fcfile5.uf.tistory.com%2Fimage%2F263DA15059747E1C1D63D9 480w" width="840"/></p>
# <p><b>8. 치킨 + 맥주</b></p>
# <p>비가와도 눈이와도 더워도 추워도 대한민국의 최고의 조합 치맥!! 비가올때는 더맛있다는 소문이..</p>
# <p><img alt="비 올때 먹기좋은 음식" filemime="image/jpeg" filename="꾸미기_580229f88e40cab44e857648e06d10c51.jpg" height="472" src="http://cfile22.uf.tistory.com/image/2739584C59747E290863F7" srcset="//img1.daumcdn.net/thumb/R1920x0/?fname=http%3A%2F%2Fcfile22.uf.tistory.com%2Fimage%2F2739584C59747E290863F7 1920w, //img1.daumcdn.net/thumb/R960x0/?fname=http%3A%2F%2Fcfile22.uf.tistory.com%2Fimage%2F2739584C59747E290863F7 960w, //img1.daumcdn.net/thumb/R720x0/?fname=http%3A%2F%2Fcfile22.uf.tistory.com%2Fimage%2F2739584C59747E290863F7 720w, //img1.daumcdn.net/thumb/R640x0.q70/?fname=http%3A%2F%2Fcfile22.uf.tistory.com%2Fimage%2F2739584C59747E290863F7 640w, //img1.daumcdn.net/thumb/R480x0.q70/?fname=http%3A%2F%2Fcfile22.uf.tistory.com%2Fimage%2F2739584C59747E290863F7 480w" width="840"/></p>
# <p><b>9. 김치나베돈까스</b></p>
# <p>요즘 떠오르는 신흥강자 김치나베돈까스! 설명이 필요없다! 먹어보세요~'미소야,한스델리 등'</p>
# <div class="reply-bottom">
# <a class="reply-alink" href="http://www.maybugs.com/member/profile.html?user_id=engk130" title="마이홈 가기">
# <p class="reply-photo" style="background:url('/member/memImgDown.php?filename=engk130.png ') no-repeat 0 0;"></p>
# <span>브로콜리<!-- whatkimbbb@gmail.com--></span><span style="vertical-align:sub;"><img alt="VIP" src="http://www.maybugs.com/image2006/ico_VIP.png"/></span>
# </a>
# </div><a class="keywordView" href="/news/articleList.html?sc_area=A&amp;sc_word=국밥" target="_top">#국밥</a><a class="keywordView" href="/news/articleList.html?sc_area=A&amp;sc_word=김치나베돈까스" target="_top">#김치나베돈까스</a><a class="keywordView" href="/news/articleList.html?sc_area=A&amp;sc_word=부침개" target="_top">#부침개</a><a class="keywordView" href="/news/articleList.html?sc_area=A&amp;sc_word=비 올때 먹기좋은 음식" target="_top">#비 올때 먹기좋은 음식</a><a class="keywordView" href="/news/articleList.html?sc_area=A&amp;sc_word=삼겹살" target="_top">#삼겹살</a><a class="keywordView" href="/news/articleList.html?sc_area=A&amp;sc_word=우동" target="_top">#우동</a><a class="keywordView" href="/news/articleList.html?sc_area=A&amp;sc_word=짬뽕" target="_top">#짬뽕</a><a class="keywordView" href="/news/articleList.html?sc_area=A&amp;sc_word=치맥" target="_top">#치맥</a><a class="keywordView" href="/news/articleList.html?sc_area=A&amp;sc_word=칼국수" target="_top">#칼국수</a><a class="keywordView" href="/news/articleList.html?sc_area=A&amp;sc_word=해물찜" target="_top">#해물찜</a> </div>
# <!--추천위젯시작//-->
# <script language="javascript">
#
#                     var REQ; //요청객체용
#                     var message;
#                     var recommend;
#                     var idxno;
#                     var articleflag;
#
#                     function processMoveItem()
#                     {
#                         if (REQ.readyState == 4) {
#                             // only if "OK"
#                             if (REQ.status == 200) {
#
#                                 try{
#                                     var xmlDoc = REQ.responseText;
#                                     var xmlDoc = (new DOMParser()).parseFromString(xmlDoc, "text/xml");
#
#                                     message = xmlDoc.childNodes.item(0).childNodes.item(1).textContent;
#                                     recommend = xmlDoc.childNodes.item(0).childNodes.item(3).textContent;
#                                     idxno = xmlDoc.childNodes.item(0).childNodes.item(5).textContent;
#                                     articleflag = xmlDoc.childNodes.item(0).childNodes.item(7).textContent;
#
#                                 }catch(e){
#                                     var xmlDoc = REQ.responseXML;
#                                     message = xmlDoc.childNodes.item(0).childNodes.item(0).text;
#                                     recommend = xmlDoc.childNodes.item(0).childNodes.item(1).text;
#                                     idxno = xmlDoc.childNodes.item(0).childNodes.item(2).text;
#                                     articleflag = xmlDoc.childNodes.item(0).childNodes.item(3).text;
#                                 }
#
#                                 document.getElementById("recom_"+idxno+"_"+articleflag).innerHTML=recommend;
#                                 if(message == '0'){
#                                     alert('이미 추천 또는 반대 하셨습니다.');
#                                 }
#
#                             } else {
#                                 alert("작업중 오류가 발생 했습니다.\n다시 시도해 주세요.");
#                             }
#                         }
#                     }
#
#
#                     function dateEdit(query)
#                     {
#                         //alert(query);
#                         try {
#                             REQ = new XMLHttpRequest;
#                         } catch(e) {}
#
#                         if(!REQ)
#                             try {
#                                 REQ = new ActiveXObject("Msxml2.XMLHTTP");
#                             } catch(e) {}
#
#                         if(!REQ)
#                             try {
#                                 REQ = new ActiveXObject("Microsoft.XMLHTTP");
#                             } catch(e) {}
#
#                         if(!REQ) alert("호환되지 않는 브라우저 입니다.\n");
#                         var handlerFunction = processMoveItem;
#                         REQ.onreadystatechange = handlerFunction;
#
#                         REQ.open("POST", "/news/article_recommend.php", true);
#                         REQ.setRequestHeader("Content-Type", "application/x-www-form-urlencoded");
#
#                         REQ.send(query);
#                     }
#
#
#
# 					function recomPlus(idxno, articleflag, recommend){
# 						document.getElementById("recom_"+idxno+"_"+articleflag).innerHTML="<img src='http://www.maybugs.com/image2006/default/indicator.gif' border='0'>";
# 						query="article_idxno="+idxno+"&articleflag="+articleflag+"&recommend="+recommend;
#
# 						dateEdit(query);
# 					}
#
# 				   </script>
# <style>
# 					#recom_small {
# 						width: 52px;
# 						height: 43px;
# 						cursor: pointer;
# 						background: url(http://www.maybugs.com/image2006/default/bt_recommend.gif) no-repeat;
# 						font: bold 11px verdana;
# 						color: #ff751c;
# 						letter-spacing: -1px;
# 						padding-top: 6px;
# 						text-align: center;
# 						margin-right: 5px;
# 						text-indent: 0;
# 					}
# 					#recom_small2 {
# 						display: none; /*반대 버튼 미노출 @ 정에녹 180813 / 761855*/
# 						width: 52px;
# 						height: 43px;
# 						cursor: pointer;
# 						background: url(http://www.maybugs.com/image2006/default/bt_opposition.gif) no-repeat;
# 						font: bold 11px verdana;
# 						color: #ff751c;
# 						letter-spacing: -1px;
# 						padding-top: 6px;
# 						text-align: center;
# 						margin-right: 5px;
# 						text-indent: 0;
# 					}
# 				   </style>
# <div align="center">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="center"><div id="recom_small" onclick="return false" title="추천하기"><span class="recommend" id="recom_581068_r">1</span></div></td>
# <td align="center" style="padding-left:5px;"><div id="recom_small2" onclick="return false" title="반대하기"><span class="recommend" id="recom_581068_o">0</span></div></td>
# </tr>
# </table>
# </div>
# <!--추천위젯끝//-->
# <!-- 후원포인트 -->
# <script src="/script/jquery-1.11.2.min.js" type="text/javascript"></script>
# <div class="height_auto not_print av_support_box">
# <div class="height_auto avsb_box">
# <form action="/member/addUserPoint.php" id="SupportForm_id" method="post" name="SupportForm" onsubmit="return support.SubmitSend(this);" target="_top">
# <!-- <input type="hidden" name="memo" value="http://www.maybugs.com/news/articleView.html?idxno=581068" /> -->
# <input name="memo" type="hidden" value="581068">
# <input name="get_user_id" type="hidden" value="engk130">
# <input name="get_user_name" type="hidden" value="김두하">
# <input name="send_user_id" type="hidden" value="">
# <input name="send_user_name" type="hidden" value="">
# <input id="price" name="price" type="hidden" value="50">
# <h6 class="asb_title" style="color:#ff7b07;"> I love this posting  (Send donation)<!-- 좋은 포스트 후원하기 --></h6>
# <span></span>
# <ul class="height_auto no_type abs_ul">
# <li class="asb_li"><input class="chk_support_type" data-price="10" id="support_type_1" name="support_type" type="radio" value="A"/><label class="asb_label" for="support_type_1"> 10 Token</label></li>
# <li class="asb_li"><input checked="" class="chk_support_type" data-price="50" id="support_type_2" name="support_type" type="radio" value="B"/><label class="asb_label" for="support_type_2"> 50 Token</label></li>
# <li class="asb_li">
# <input class="chk_support_type" data-price="100" id="support_type_3" name="support_type" type="radio" value="C"/><label class="asb_label label_free_payment" for="support_type_3"> 100 Token 이상</label>
# <span class="input_free_payment" style="display:none;">
# <span class="asb_input_won">P</span>
# <input class="asb_input" id="price_free" name="price_free" readonly="readonly" type="text" value="0"/>
# <button class="asb_pbtn btn_click_price" data-price="50" type="button">50 추가</button>
# <button class="asb_pbtn btn_click_price" data-price="100" type="button">100 추가</button>
# <button class="border_box c_tooltip asb_pbtn icon reset btn_click_price" data-price="0" title="초기화" type="button"></button>
# </span>
# </li>
# </ul>
# <a class="asb_sbtn" href="/member/login.html?backUrl=/news/articleView.html?idxno=581068">로그인</a> </input></input></input></input></input></input></form>
# </div>
# </div>
# <script type="text/javascript">
#
# 							var support={
# 								SubmitSend:function(form)
# 								{
#
#
#
# 									// 후원 금액 체크
# 									$j(".chk_support_type").each(function(){
# 										var support_opt = "", price_free = 0;
# 										if ($j(this).prop("checked") == true)
# 										{
#
#
#
# 											support_opt = $j(this).val();
# 											switch (support_opt)
# 											{
# 												case "A":
# 												case "B":
# 													form.price.value = $j(this).attr("data-price");
# 													break;
#
# 												case "C":
# 													if (form.price_free.value <= 0 || form.price_free.value == 'NaN') form.price.value = $j(this).attr("data-price");
# 													else
# 													{
# 														price_free = $j("#price_free").val().replace(/[^0-9]/g, '');
# 														price_free = (parseInt(price_free)>0) ? parseInt(price_free) : 0;
# 														form.price.value = price_free;
# 													}
# 													break;
#
# 												default:
# 													form.price.value = 0;
# 													break;
# 											}
# 										}
# 									});
#
# 									if (parseInt(form.price.value) <= 0 || form.price.value == 'NaN')
# 									{
# 										alert("후원하실 방법을 선택해주세요");
# 										return false;
# 									}
#
# 									if (parseInt(form.price.value) > 1000 )
# 									{
# 										alert("1000Token 이상 후원은 불가합니다. ");
# 										return false;
# 									}
#
# 									var aa = form.price.value;
#
# 									var result = confirm(aa+' 후원 Token을 보낼까요?');
# 										if(result) {
# 											return true;
# 										} else {
# 											return false;
# 										}
#
# 									//return true;
# 								}
#
# 								,evtCheckSupportType:function()
# 								{
#
#
# 									$j(".chk_support_type").on("click",function () {
# 										var $support_type = $j(this).val();
#
# 										switch ($support_type)
# 										{
# 											case 'A':
# 												$j("#price").val(10);
# 												$j(".label_free_payment").show();
# 												$j(".input_free_payment").hide();
# 												break;
#
# 											case 'B':
# 												$j("#price").val(50);
# 												$j(".label_free_payment").show();
# 												$j(".input_free_payment").hide();
# 												break;
#
# 											case 'C':
# 												$j("#price").val(100);
# 												$j("#price_free").val("100");
# 												$j(".label_free_payment").hide();
# 												$j(".input_free_payment").show();
# 												break;
#
# 											case 'D':
# 											case 'E':
# 												$j("#price").val(0);
# 												$j(".label_free_payment").show();
# 												$j(".input_free_payment").hide();
# 												break;
#
# 											default:
# 												break;
# 										}
# 									});
# 								}
#
# 								,evtClickPrice:function()
# 								{
# 									$j(".btn_click_price").on("click",function () {
# 										var click_price = price_free = total_price = 0;
# 										click_price = parseInt($j(this).attr("data-price"));
# 										if (click_price == 0)
# 										{
# 											$j("#price").val(100);
# 											$j("#price_free").val("100");
# 										}
# 										else
# 										{
# 											price_free = $j("#price_free").val().replace(/[^0-9]/g, '');
# 											price_free = (parseInt(price_free)>0) ? parseInt(price_free) : 0;
#
# ...
# 		'/news/articleView.html'	// 리턴URL
# 	);
# </script>
# <script>
# (function($) {
# 	$('#article-reply').on('click', '.reply-photo', function(e){
# 		if($(this).data('userid')) location.href="/member/profile.html?user_id="+$(this).data('userid');
# 	})
# })(jQuery)
# </script>
# <div style="margin-bottom:20px;">
# </div>
# <!--180816_디펙--<script language="javascript" src="/bannerManager/inc/83.html"></script><!--180816_디펙-->
# <!--스마트리_180706--<script language="javascript" src="/bannerManager/inc/68.html"></script><!--스마트리_180706-->
# <!--폰더_180620--<script language="javascript" src="/bannerManager/inc/67.html"></script><!--폰더_180620-->
# <!--비트젯180416--<script language="javascript" src="/bannerManager/inc/59.html"></script><!--비트젯180416-->
# <!--밴티지토큰180531--<script language="javascript" src="/bannerManager/inc/65.html"></script><!--밴티지토큰180531-->
# <!-- 오토박스 -->
# <div class="article-hotnews border-box">
# <strong class="tit"><i class="icon">icon</i>인기 포스트</strong>
# <div class="line-view border-box">
# <li><a href="/news/articleView.html?idxno=1300431" target="_top">비트코인 바닥론 vs 신중론, 비트코인 급등에 또 다시 주목</a></li><li><a href="/news/articleView.html?idxno=1300446" target="_top">주요국가에서 위기에 빠진 바이낸스, 한국시장은 어떨까?</a></li><li><a href="/news/articleView.html?idxno=1300430" target="_top">유상증자</a></li><li><a href="/news/articleView.html?idxno=1300448" target="_top">위치월드, 메타버스 전체 모바일 플레이 오픈 및 기념 이벤트 진행</a></li><li><a href="/news/articleView.html?idxno=1300447" target="_top">KBW2023, 블록체인 산업 미래를 밝히기 위한 웹3.0 글로벌 리더 총출동</a></li> </div>
# <div class="photo-view">
# <a href="/news/articleView.html?idxno=1300395" target="_top"><img alt="신차 출시" border="0" class="ImgWidth_typeJ ImgHeight_typeM" src="/news/photo/202306/1300395_1263093_558.png"/>
# <strong>신차 출시</strong>
# <span class="mask"></span>
# </a>
# </div>
# </div>
# <!-- 오토박스 -->
# </div></td>
# <td valign="top" width="10"></td>
# <td class="side-bg" rowspan="3" valign="top" width="300">
# <div id="side-scroll-start">
# <div id="side-scroll-in">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center"><!--벅스충전190924--><script language="javascript" src="/bannerManager/inc/154.html"></script><!--벅스충전190924--></td>
# </tr>
# </table><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center"><!--메이벅스몰250_190906--><script language="javascript" src="/bannerManager/inc/152.html"></script><!--메이벅스몰250_190906--></td>
# </tr>
# </table><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center"><!--메이벅스몰_191226--><script language="javascript" src="/bannerManager/inc/159.html"></script><!--메이벅스몰_191226--></td>
# </tr>
# </table><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center"><iframe frameborder="0" height="560" noresize="" scrolling="no" src="/Autobox/250_reply_date.html" width="250"></iframe></td>
# </tr>
# </table><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center"><div class="mHeight_sm">여백</div></td>
# </tr>
# </table><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center"><iframe frameborder="0" height="230" noresize="" scrolling="no" src="/Autobox/250_superpost_top10.html" width="250"></iframe></td>
# </tr>
# </table><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center"><div class="mHeight_sm">여백</div></td>
# </tr>
# </table><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center"><iframe frameborder="0" height="830" noresize="" scrolling="no" src="/Autobox/250_reply.html" width="250"></iframe></td>
# </tr>
# </table><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center"><!-- Begin Dable 우_리스트6_EMPTY_스타일2 / For inquiries, visit http://dable.io -->
# <div data-widget_id="57w0LOl8" id="dablewidget_57w0LOl8">
# <script>
# (function(d,a,b,l,e,_) {
# if(d[b]&&d[b].q)return;d[b]=function(){(d[b].q=d[b].q||[]).push(arguments)};e=a.createElement(l);
# e.async=1;e.charset='utf-8';e.src='//static.dable.io/dist/plugin.min.js';
# _=a.getElementsByTagName(l)[0];_.parentNode.insertBefore(e,_);
# })(window,document,'dable','script');
# dable('setService', 'maybugs.com/ndsoft');
# dable('sendLogOnce');
# dable('renderWidget', 'dablewidget_57w0LOl8');
# </script>
# </div>
# <!-- End 우_리스트6_EMPTY_스타일2 / For inquiries, visit http://dable.io --></td>
# </tr>
# </table><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td align="center"><!--데이블 2020-03-03 추가-->
# <!-- Begin Dable EMPTY_EMPTY_300x250 / For inquiries, visit http://dable.io -->
# <!-- <div id="dablewidget_M7NjZR7b" data-widget_id="M7NjZR7b">
# <script>
# (function(d,a,b,l,e,_) {
# if(d[b]&&d[b].q)return;d[b]=function(){(d[b].q=d[b].q||[]).push(arguments)};e=a.createElement(l);
# e.async=1;e.charset='utf-8';e.src='//static.dable.io/dist/plugin.min.js';
# _=a.getElementsByTagName(l)[0];_.parentNode.insertBefore(e,_);
# })(window,document,'dable','script');
# dable('setService', 'maybugs.com/ndsoft');
# dable('sendLogOnce');
# dable('renderWidget', 'dablewidget_M7NjZR7b');
# </script>
# </div> -->
# <!-- End EMPTY_EMPTY_300x250 / For inquiries, visit http://dable.io --></td>
# </tr>
# </table> </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <script type="text/javascript">
# 	jQuery(document).ready
# 	(
# 		function()
# 		{
# 			onScrollDirection();
# 		 	onScrollAdjustEndLine("#side-scroll-start",	"#article-control", "#side-scroll-in");
# 		}
# 	);
# </script>
# </td>
# </tr>
# </table>
# </div></td>
# </tr>
# </table>
# <style type="text/css">
# #dn_banner{padding-top:0px; position:relative;margin:0px auto; height:150px; overflow:hidden;margin-bottom: 10px;}
# .dn_bg { position:absolute;bottom: 0;left:0;right:0;z-index:-1;width:100%;height:100%;}
# #dn_bg {overflow:hidden;height:150px;background: url('/image2006/bottom_back.jpg')no-repeat;background-size: cover;/*background-color:#e9e9e9*/}
# #dn_bg img{text-align: center;display: inherit;margin: auto;}
#
# </style>
# <!-- 로그인바 //-->
# <!-- 최종편집 --
# <div id="TopMark">
# 	<div id="Default_Warp">
# 		<!--<div class="update"><strong>UPDATE</strong> : </div>--
# 		<!-- 로그인/회원가입 --
# 		<ul class="btn-login">
# 			<li class="nobr"><a href="/member/login.html"><strong>log in</strong></a></li><li><a href="/member/memberAgree.html?kind=member">Register</a></li>		</ul>
#
# 		<div id="login3"><a href="http://www.maybugs.com/member/myHome.html?user_id=" target="_self">마이채널 바로가기(My Channel Click) </a></div>
# 		<div id="Bsw_Wrap" class="float-right dis-block width-260">
# 			<div class="Bsw_Wrap_title float-left dis-block width-90" style="background:url('/box/box_news/autobox_design.png') no-repeat 85px -786px;text-align:left;color:rgba(255, 255, 255, 1)"><strong>popular word</strong></div>
# 			<div class="width-160 dis-block flow-hide">
# 				<div id="cron_BestSearchWord_new" class="auto-hotE border-box">
# 	<div class="rollBox border-box"><div class="posi-re auto-article rollInBox"><div class="auto-hotA rollInBoxA">
# 		<span class="num point-num">1</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=아이브&encode=Y" target="_top" class="dis-block size-12 OnLoad auto-fontF">아이브</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num point-num">2</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=카리나&encode=Y" target="_top" class="dis-block size-12 OnLoad auto-fontF">카리나</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num point-num">3</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=킹더랜드&encode=Y" target="_top" class="dis-block size-12 OnLoad auto-fontF">킹더랜드</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num">4</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=러시아&encode=Y" target="_top" class="dis-block size-12 OnLoad auto-fontF">러시아</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num">5</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=조혜원&encode=Y" target="_top" class="dis-block size-12 OnLoad auto-fontF">조혜원</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num">6</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=이강인&encode=Y" target="_top" class="dis-block size-12 OnLoad auto-fontF">이강인</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num">7</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=악귀&encode=Y" target="_top" class="dis-block size-12 OnLoad auto-fontF">악귀</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num">8</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=아이유&encode=Y" target="_top" class="dis-block size-12 OnLoad auto-fontF">아이유</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num">9</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=송혜교&encode=Y" target="_top" class="dis-block size-12 OnLoad auto-fontF">송혜교</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num">10</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=황의조&encode=Y" target="_top" class="dis-block size-12 OnLoad auto-fontF">황의조</a></div>
# 		</div></div><i>아이콘</i></div>
# 	<div class="rollBox2 border-box"><div class="posi-re auto-article rollInBox"><div class="auto-hotA rollInBoxA">
# 		<span class="num point-num">1</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=아이브&encode=Y" target="_top" class="dis-block size-12 OnLoad">아이브</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num point-num">2</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=카리나&encode=Y" target="_top" class="dis-block size-12 OnLoad">카리나</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num point-num">3</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=킹더랜드&encode=Y" target="_top" class="dis-block size-12 OnLoad">킹더랜드</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num">4</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=러시아&encode=Y" target="_top" class="dis-block size-12 OnLoad">러시아</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num">5</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=조혜원&encode=Y" target="_top" class="dis-block size-12 OnLoad">조혜원</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num">6</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=이강인&encode=Y" target="_top" class="dis-block size-12 OnLoad">이강인</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num">7</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=악귀&encode=Y" target="_top" class="dis-block size-12 OnLoad">악귀</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num">8</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=아이유&encode=Y" target="_top" class="dis-block size-12 OnLoad">아이유</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num">9</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=송혜교&encode=Y" target="_top" class="dis-block size-12 OnLoad">송혜교</a></div>
# 		</div><div class="auto-hotA rollInBoxA">
# 		<span class="num">10</span>
# 		<div class="dis-block flow-hide height-17 size-12 auto-marbtm-1"><a href="http://www.maybugs.com/getrss/userArticleList.html?sc_area=A&sc_order_by=R&sc_word=황의조&encode=Y" target="_top" class="dis-block size-12 OnLoad">황의조</a></div>
# 		</div></div></div>
# 	</div>
#
# 	<script type="text/javascript">
# 	(function($){
# 		rollArticle("#cron_BestSearchWord_new","3000");
# 	})(jQuery);
# 	</script>
# 				</div>
# 		</div>
# 	</div>
# </div>
# <!--// 로그인바 -->
# <!-- 하단 배너-->
# <!--<div id="dn_bg">
# <!--하단배너수정191106--<script language="javascript" src="/bannerManager/inc/158.html"></script><!--하단배너수정191106-->
# <!--하단_180514<script language="javascript" src="/bannerManager/inc/63.html"></script>하단_180514-->
# <!--<div class="dn_bg"><img src="http://www.maybugs.com/bannerManager/upload/84.jpg" width="100%" height="100%"></div>
# <img src="http://www.maybugs.com/banner/dn_20200210.png">
# </div>-->
# <div class="border-box" id="footer-wrap" style="padding:20px 0 20px 220px;background:url('/image2006/logo_dn.gif') no-repeat left center;">
# <div class="posi-re dis-inblock">
# <ul class="dncom border-box">
# <li class="nobr"><a href="http://www.maybugs.com/event/event1.html" onfocus="this.blur()">회사소개</a></li>
# <li><a href="http://www.maybugs.com/com/jh.html" onfocus="this.blur()">제휴문의</a></li>
# <li><a href="http://www.maybugs.com/com/ad.html" onfocus="this.blur()">광고문의</a></li>
# <li><a href="http://www.maybugs.com/com/bp.html" onfocus="this.blur()">불편신고</a></li>
# <li><a href="http://www.maybugs.com/com/privacy.html" onfocus="this.blur()">개인정보취급방침</a></li>
# <li><a href="http://www.maybugs.com/com/teen.html" onfocus="this.blur()">청소년보호정책</a></li>
# <li><a href="http://www.maybugs.com/com/emailno.html" onfocus="this.blur()">이메일무단수집거부</a></li>
# </ul>
# <div class="dncopy" style="letter-spacing:-0.3px;">
# <!--메이벅스 서울특별시 서초구 사임당로 39 ｜ 제휴문의 010-3399-2548 <br>-->
#
# 		서울시 서초구 서초동 1364-39 지훈빌딩 4층 ｜ 사업자번호: 214-12-20175 ｜ <!--통신판매업 신고번호: 2011-서울서초-0880 <br>-->
# 		총괄대표: 제임스 영 (James Young. Jr) ㅣ 청소년보호책임자: 장인수 <br/>
# <a href="https://mail.daum.net" target="_blank">C</a><a href="http://www.maybugs.com/admin/adminLoginForm.html">o</a>pyright © 2023 maybugs. All rights reserved.
# 		</div>
# <div class="pblogo"><a href="http://www.ndsoft.co.kr" onfocus="this.blur()" target="_blank"><img border="0" src="/image2006/ndsoft.gif"/></a></div>
# </div>
# </div>
# <!-- 스크롤탑 -->
# <i class="back-to-top"><a href="#top">Back to Top</a></i>
# <script type="text/javascript">
# <!--
# (function($) {
# 	$(function() {
#
# 		/*스크롤 탑*/
# 		var offset = 220;
# 		var duration = 500;
# 		jQuery(window).scroll(function() {
# 			if (jQuery(this).scrollTop() > offset) {
# 				jQuery('.back-to-top').fadeIn(duration);
# 			} else {
# 				jQuery('.back-to-top').fadeOut(duration);
# 			}
# 		});
#
# 		jQuery('.back-to-top').click(function(event) {
# 			event.preventDefault();
# 			jQuery('html, body').animate({scrollTop: 0}, duration);
# 			return false;
# 		})
#
# 	});
#
#
# })(jQuery);
# //-->
# </script>
#
# <!-- 관리자세션유지 //-->
# <script type="text/javascript">
#     setInterval('autoSessReload()', 600000);
# </script>
# <!--// 관리자세션유지 -->
# </body>
# </html>

# %%
# soup객체로부터 원하는 부분 추출하기
test4 = soup.select('#articleBody b')
test4
# Out:
# [<b>1. 부침개[전] + 막걸리</b>,
#  <b>2. 얼큰한 짬뽕</b>,
#  <b>3. 바지락 칼국수</b>,
#  <b>4. 국밥</b>,
#  <b>5. 아구 찜</b>,
#  <b>6. 삼겹살 + 소주</b>,
#  <b>7. 우동</b>,
#  <b>8. 치킨 + 맥주</b>,
#  <b>9. 김치나베돈까스</b>]

# %%
h4 = []
h4_name = []
for item in test4:
    h4 += item.text.strip().split()
print(h4)
for i in range(1, 7):
    if i%2 == 0:
        h4_name.append(h4[i-1])
for i in range(15, 28):
    if i%2 == 0:
        h4_name.append(h4[i])
for i in range(11, 15):
    if (i+1)%2 == 0:
        h4_name.append(h4[i])
print(h4_name)
# Out:
# ['1.', '부침개[전]', '+', '막걸리', '2.', '얼큰한', '짬뽕', '3.', '바지락', '칼국수', '4.', '국밥', '5.', '아구', '찜', '6.', '삼겹살', '+', '소주', '7.', '우동', '8.', '치킨', '+', '맥주', '9.', '김치나베돈까스']
# ['부침개[전]', '막걸리', '얼큰한', '삼겹살', '소주', '우동', '치킨', '맥주', '김치나베돈까스', '국밥', '아구']

# %%
df = DataFrame(h4_name)
df.to_excel("result4.xlsx")
df
# Out:
#           0
# 0    부침개[전]
# 1       막걸리
# 2       얼큰한
# 3       삼겹살
# 4        소주
# 5        우동
# 6        치킨
# 7        맥주
# 8   김치나베돈까스
# 9        국밥
# 10       아구

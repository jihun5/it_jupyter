# %%
# ppt, word 등 제출 형식은 자유 결정
# 작성이 완료된 파일을 leekh4232@kakao.com
# 6월 29일까지

# %%
# 수집할 데이터에 대한 관심사가 무엇인지 기술

# %%
# 관심사와 관련된 데이터를 수집할 수 있는 웹사이트
url1 = 'https://brunch.co.kr/@gorrajeju/775'
url2 = 'https://menupick.tistory.com/15'
url3 = 'https://welcome8007.com/33'
url4 = 'https://www.maybugs.com/news/articleView.html?idxno=581068'
url5 = 'https://monimoney.tistory.com/entry/%EB%B9%84-%EC%98%A4%EB%8A%94-%EB%82%A0-%EB%A8%B9%EC%9C%BC%EB%A9%B4-%EB%8D%94-%EB%A7%9B%EC%9E%88%EB%8A%94-%EC%9A%94%EB%A6%AC'

# %%
import requests
from bs4 import BeautifulSoup
from pandas import DataFrame

# %%
userAgent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"

# %%
# 접속객체 생성
session = requests.Session()
# 접속객체에 부가정보(header) 삽입하기
session.headers.update({
    "Referer": "",
    "User-Agent": userAgent
})

# %%
# 생성한 접속객체를 활용하여 API에 접속
r = session.get(url2)
if r.status_code != 200:
    msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
    raise Exception(msg)

# %%
# 인코딩 형식 지정하여 beautifulsoup객체를 생성
r.encoding = "utf-8"
soup = BeautifulSoup(r.text)
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <script type="text/javascript">if (!window.T) { window.T = {} }
# window.T.config = {"TOP_SSL_URL":"https://www.tistory.com","PREVIEW":false,"ROLE":"guest","PREV_PAGE":"","NEXT_PAGE":"","BLOG":{"id":6250252,"name":"menupick","title":"맛있게 먹고 건강을 지키자","isDormancy":false},"NEED_COMMENT_LOGIN":false,"COMMENT_LOGIN_CONFIRM_MESSAGE":"","LOGIN_URL":"https://www.tistory.com/auth/login/?redirectUrl=https%3A%2F%2Fmenupick.tistory.com%2F15","DEFAULT_URL":"https://menupick.tistory.com","USER":{"name":null,"homepage":null,"id":0,"profileImage":null},"SUBSCRIPTION":{"status":"none","isConnected":false,"isPending":false,"isWait":false,"isProcessing":false,"isNone":true},"IS_LOGIN":false,"HAS_BLOG":false,"TOP_URL":"http://www.tistory.com","JOIN_URL":"https://www.tistory.com/member/join","ROLE_GROUP":"visitor"};
# window.appInfo = {"domain":"tistory.com","topUrl":"https://www.tistory.com","loginUrl":"https://www.tistory.com/auth/login","logoutUrl":"https://www.tistory.com/auth/logout"};
# window.initData = {};
#
# window.TistoryBlog = {
#     basePath: "",
#     url: "https://menupick.tistory.com",
#     tistoryUrl: "https://menupick.tistory.com",
#     manageUrl: "https://menupick.tistory.com/manage",
#     token: "N5l1w/p5NQ2VXmzQalUKC+62shDkQBR3xox1NeJc3zxpQRSTIyHC+3HFQWjDTLwT"
# };
# var servicePath = "";
# var blogURL = "";</script>
# <!-- BusinessLicenseInfo - START -->
# <link href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/plugin/BusinessLicenseInfo/style.css" rel="stylesheet" type="text/css"/>
# <script>function switchFold(entryId) {
#     var businessLayer = document.getElementById("businessInfoLayer_" + entryId);
#
#     if (businessLayer) {
#         if (businessLayer.className.indexOf("unfold_license") > 0) {
#             businessLayer.className = "business_license_layer";
#         } else {
#             businessLayer.className = "business_license_layer unfold_license";
#         }
#     }
# }
# </script>
# <!-- BusinessLicenseInfo - END -->
# <!-- DaumShow - START -->
# <style type="text/css">#daumSearchBox {
#     height: 21px;
#     background-image: url(//i1.daumcdn.net/imgsrc.search/search_all/show/tistory/plugin/bg_search2_2.gif);
#     margin: 5px auto;
#     padding: 0;
# }
#
# #daumSearchBox input {
#     background: none;
#     margin: 0;
#     padding: 0;
#     border: 0;
# }
#
# #daumSearchBox #daumLogo {
#     width: 34px;
#     height: 21px;
#     float: left;
#     margin-right: 5px;
#     background-image: url(//i1.daumcdn.net/img-media/tistory/img/bg_search1_2_2010ci.gif);
# }
#
# #daumSearchBox #show_q {
#     background-color: transparent;
#     border: none;
#     font: 12px Gulim, Sans-serif;
#     color: #555;
#     margin-top: 4px;
#     margin-right: 15px;
#     float: left;
# }
#
# #daumSearchBox #show_btn {
#     background-image: url(//i1.daumcdn.net/imgsrc.search/search_all/show/tistory/plugin/bt_search_2.gif);
#     width: 37px;
#     height: 21px;
#     float: left;
#     margin: 0;
#     cursor: pointer;
#     text-indent: -1000em;
# }
# </style>
# <!-- DaumShow - END -->
# <!-- System - START -->
# <script async="async" data-ad-client="ca-pub-6587134976682849" data-ad-host="ca-host-pub-9691043933427338" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- System - END -->
# <!-- TistoryProfileLayer - START -->
# <link href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/plugin/TistoryProfileLayer/style.css" rel="stylesheet" type="text/css"/>
# <script src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/plugin/TistoryProfileLayer/script.js" type="text/javascript"></script>
# <!-- TistoryProfileLayer - END -->
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <script crossorigin="anonymous" integrity="sha256-9/aliU8dGd2tb6OSsuzixeV4y/faTqgFtohetphbbj0=" src="//t1.daumcdn.net/tistory_admin/lib/jquery/jquery-3.5.1.min.js"></script>
# <script defer="" src="//t1.daumcdn.net/tistory_admin/lib/lightbox/js/lightbox-v2.10.0.min.js"></script>
# <script src="//t1.daumcdn.net/tiara/js/v1/tiara.min.js" type="text/javascript"></script><meta content="always" name="referrer">
# <meta content="ca-host-pub-9691043933427338" name="google-adsense-platform-account">
# <meta content="tistory.com" name="google-adsense-platform-domain"/>
# <meta content="ca-pub-6587134976682849" name="google-adsense-account"/>
# <meta content="비오는 날씨에는 따뜻하고 감성적인 음식이 더욱 맛있게 느껴집니다. 이번에는 한국인이 추천하는 비오는 날 음식 베스트 7가지를 소개합니다. 1. 비오는날 음식 불고기한국인이 가장 좋아하는 음식 중 하나인 불고기는 비오는 날씨에도 먹기 좋은 음식입니다. 불고기는 부드러운 소고기와 달콤한 양념이 조화를 이루어, 따뜻한 밥과 함께 먹으면 굉장히 맛있습니다. 2. 비오는날 음식 김치찌개한국인들의 대표적인 국물 요리인 김치찌개는 비오는 날씨에 먹기 딱 좋은 음식입니다. 김치의 매운 맛과 돼지고기, 두부 등의 부드러운 식재료가 조화를 이루어, 몸 안을 따뜻하게 해주는 효과가 있습니다. 3. 비오는날 음식 떡볶이떡볶이는 바삭하게 구운 어묵과 부드러운 떡이 어우러진 매콤한 음식입니다. 비오는 날씨에는 떡볶이를 먹으면 몸.." name="description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://menupick.tistory.com/15" property="og:url"/>
# <meta content="메뉴픽" property="og.article.author"/>
# <meta content="맛있게 먹고 건강을 지키자" property="og:site_name"/>
# <meta content="비오는날 음식 베스트 7가지" property="og:title"/>
# <meta content="메뉴픽" name="by"/>
# <meta content="비오는 날씨에는 따뜻하고 감성적인 음식이 더욱 맛있게 느껴집니다. 이번에는 한국인이 추천하는 비오는 날 음식 베스트 7가지를 소개합니다. 1. 비오는날 음식 불고기한국인이 가장 좋아하는 음식 중 하나인 불고기는 비오는 날씨에도 먹기 좋은 음식입니다. 불고기는 부드러운 소고기와 달콤한 양념이 조화를 이루어, 따뜻한 밥과 함께 먹으면 굉장히 맛있습니다. 2. 비오는날 음식 김치찌개한국인들의 대표적인 국물 요리인 김치찌개는 비오는 날씨에 먹기 딱 좋은 음식입니다. 김치의 매운 맛과 돼지고기, 두부 등의 부드러운 식재료가 조화를 이루어, 몸 안을 따뜻하게 해주는 효과가 있습니다. 3. 비오는날 음식 떡볶이떡볶이는 바삭하게 구운 어묵과 부드러운 떡이 어우러진 매콤한 음식입니다. 비오는 날씨에는 떡볶이를 먹으면 몸.." property="og:description"/>
# <meta content="https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FcO305i%2Fbtr75taFhNH%2F0xDEMYEnJDINavmKMHnBjK%2Fimg.webp" property="og:image"/>
# <meta content="'건강'" property="article:section"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@TISTORY" name="twitter:site"/>
# <meta content="비오는날 음식 베스트 7가지" name="twitter:title"/>
# <meta content="비오는 날씨에는 따뜻하고 감성적인 음식이 더욱 맛있게 느껴집니다. 이번에는 한국인이 추천하는 비오는 날 음식 베스트 7가지를 소개합니다. 1. 비오는날 음식 불고기한국인이 가장 좋아하는 음식 중 하나인 불고기는 비오는 날씨에도 먹기 좋은 음식입니다. 불고기는 부드러운 소고기와 달콤한 양념이 조화를 이루어, 따뜻한 밥과 함께 먹으면 굉장히 맛있습니다. 2. 비오는날 음식 김치찌개한국인들의 대표적인 국물 요리인 김치찌개는 비오는 날씨에 먹기 딱 좋은 음식입니다. 김치의 매운 맛과 돼지고기, 두부 등의 부드러운 식재료가 조화를 이루어, 몸 안을 따뜻하게 해주는 효과가 있습니다. 3. 비오는날 음식 떡볶이떡볶이는 바삭하게 구운 어묵과 부드러운 떡이 어우러진 매콤한 음식입니다. 비오는 날씨에는 떡볶이를 먹으면 몸.." name="twitter:description"/>
# <meta content="https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FcO305i%2Fbtr75taFhNH%2F0xDEMYEnJDINavmKMHnBjK%2Fimg.webp" property="twitter:image"/>
# <meta content="https://menupick.tistory.com/15" property="dg:plink"/>
# <meta name="plink"/>
# <meta content="비오는날 음식 베스트 7가지" name="title"/>
# <meta content="맛있게 먹고 건강을 지키자" name="article:media_name"/>
# <meta content="https://menupick.tistory.com/m/15" property="article:mobile_url"/>
# <meta content="https://menupick.tistory.com/15" property="article:pc_url"/>
# <meta content="https://menupick.tistory.com/m/15" property="article:mobile_view_url"/>
# <meta content="https://menupick.tistory.com/15" property="article:pc_view_url"/>
# <meta content="https://menupick.tistory.com/m/15" property="article:talk_channel_view_url"/>
# <meta content="https://www.tistory.com" property="article:pc_service_home"/>
# <meta content="https://www.tistory.com/m" property="article:mobile_service_home"/>
# <meta content="6250252_15" property="article:txid"/>
# <meta content="2023-04-05T15:36:00+09:00" property="article:published_time"/>
# <meta content="20230405033600" property="og:regDate"/>
# <meta content="2023-04-05T15:36:00+09:00" property="article:modified_time"/>
# <link href="https://t1.daumcdn.net/tistory_admin/favicon/tistory_favicon_32x32.ico" rel="icon" sizes="any"/>
# <link href="https://t1.daumcdn.net/tistory_admin/top_v2/bi-tistory-favicon.svg" rel="icon" type="image/svg+xml"/>
# <link href="https://t1.daumcdn.net/tistory_admin/top_v2/tistory-apple-touch-favicon.png" rel="apple-touch-icon"/>
# <link href="https://t1.daumcdn.net/tistory_admin/lib/lightbox/css/lightbox.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/style/font.css" rel="stylesheet" type="text/css"/>
# <link href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/style/content.css" rel="stylesheet" type="text/css"/>
# <link href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/style/uselessPMargin.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">(function() {
#     var tjQuery = jQuery.noConflict(true);
#     window.tjQuery = tjQuery;
#     window.orgjQuery = window.jQuery; window.jQuery = tjQuery;
#     window.jQuery = window.orgjQuery; delete window.orgjQuery;
# })()</script>
# <script src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/script/base.js" type="text/javascript"></script>
# <script src="//developers.kakao.com/sdk/js/kakao.min.js" type="text/javascript"></script>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-6587134976682849"></script>
# <meta content="XyhYDdmXZ-1G4xm5NUdIe4fX7-8QRD6sOByJ2O5wSrI" name="google-site-verification"/>
# <meta charset="utf-8"/>
# <meta content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, width=device-width" name="viewport"/>
# <title>비오는날 음식 베스트 7가지</title>
# <link href="https://tistory1.daumcdn.net/tistory/6250252/skin/style.css?_version_=1680089839" rel="stylesheet"/>
# <script src="//t1.daumcdn.net/tistory_admin/lib/jquery/jquery-1.12.4.min.js"></script>
# <style type="text/css">.another_category {
#     border: 1px solid #E5E5E5;
#     padding: 10px 10px 5px;
#     margin: 10px 0;
#     clear: both;
# }
#
# .another_category h4 {
#     font-size: 12px !important;
#     margin: 0 !important;
#     border-bottom: 1px solid #E5E5E5 !important;
#     padding: 2px 0 6px !important;
# }
#
# .another_category h4 a {
#     font-weight: bold !important;
# }
#
# .another_category table {
#     table-layout: fixed;
#     border-collapse: collapse;
#     width: 100% !important;
#     margin-top: 10px !important;
# }
#
# * html .another_category table {
#     width: auto !important;
# }
#
# *:first-child + html .another_category table {
#     width: auto !important;
# }
#
# .another_category th, .another_category td {
#     padding: 0 0 4px !important;
# }
#
# .another_category th {
#     text-align: left;
#     font-size: 12px !important;
#     font-weight: normal;
#     word-break: break-all;
#     overflow: hidden;
#     line-height: 1.5;
# }
#
# .another_category td {
#     text-align: right;
#     width: 80px;
#     font-size: 11px;
# }
#
# .another_category th a {
#     font-weight: normal;
#     text-decoration: none;
#     border: none !important;
# }
#
# .another_category th a.current {
#     font-weight: bold;
#     text-decoration: none !important;
#     border-bottom: 1px solid !important;
# }
#
# .another_category th span {
#     font-weight: normal;
#     text-decoration: none;
#     font: 10px Tahoma, Sans-serif;
#     border: none !important;
# }
#
# .another_category_color_gray, .another_category_color_gray h4 {
#     border-color: #E5E5E5 !important;
# }
#
# .another_category_color_gray * {
#     color: #909090 !important;
# }
#
# .another_category_color_gray th a.current {
#     border-color: #909090 !important;
# }
#
# .another_category_color_gray h4, .another_category_color_gray h4 a {
#     color: #737373 !important;
# }
#
# .another_category_color_red, .another_category_color_red h4 {
#     border-color: #F6D4D3 !important;
# }
#
# .another_category_color_red * {
#     color: #E86869 !important;
# }
#
# .another_category_color_red th a.current {
#     border-color: #E86869 !important;
# }
#
# .another_category_color_red h4, .another_category_color_red h4 a {
#     color: #ED0908 !important;
# }
#
# .another_category_color_green, .another_category_color_green h4 {
#     border-color: #CCE7C8 !important;
# }
#
# .another_category_color_green * {
#     color: #64C05B !important;
# }
#
# .another_category_color_green th a.current {
#     border-color: #64C05B !important;
# }
#
# .another_category_color_green h4, .another_category_color_green h4 a {
#     color: #3EA731 !important;
# }
#
# .another_category_color_blue, .another_category_color_blue h4 {
#     border-color: #C8DAF2 !important;
# }
#
# .another_category_color_blue * {
#     color: #477FD6 !important;
# }
#
# .another_category_color_blue th a.current {
#     border-color: #477FD6 !important;
# }
#
# .another_category_color_blue h4, .another_category_color_blue h4 a {
#     color: #1960CA !important;
# }
#
# .another_category_color_violet, .another_category_color_violet h4 {
#     border-color: #E1CEEC !important;
# }
#
# .another_category_color_violet * {
#     color: #9D64C5 !important;
# }
#
# .another_category_color_violet th a.current {
#     border-color: #9D64C5 !important;
# }
#
# .another_category_color_violet h4, .another_category_color_violet h4 a {
#     color: #7E2CB5 !important;
# }
# </style>
# <link href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/style/dialog.css" rel="stylesheet" type="text/css">
# <link href="//t1.daumcdn.net/tistory_admin/www/style/top/font.css" rel="stylesheet" type="text/css"/>
# <link href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/style/postBtn.css" rel="stylesheet" type="text/css"/>
# <link href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/style/comment.css" rel="stylesheet" type="text/css"/>
# <link href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/style/tistory.css" rel="stylesheet" type="text/css"/>
# <link href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/style/revenue.css" rel="stylesheet" type="text/css"/>
# <link href="https://menupick.tistory.com/15" rel="canonical"/>
# <!-- BEGIN STRUCTURED_DATA -->
# <script type="application/ld+json">
#     {"@context":"http://schema.org","@type":"BlogPosting","mainEntityOfPage":{"@id":"https://menupick.tistory.com/15","name":null},"url":"https://menupick.tistory.com/15","headline":"비오는날 음식 베스트 7가지","description":"비오는 날씨에는 따뜻하고 감성적인 음식이 더욱 맛있게 느껴집니다. 이번에는 한국인이 추천하는 비오는 날 음식 베스트 7가지를 소개합니다. 1. 비오는날 음식 불고기한국인이 가장 좋아하는 음식 중 하나인 불고기는 비오는 날씨에도 먹기 좋은 음식입니다. 불고기는 부드러운 소고기와 달콤한 양념이 조화를 이루어, 따뜻한 밥과 함께 먹으면 굉장히 맛있습니다. 2. 비오는날 음식 김치찌개한국인들의 대표적인 국물 요리인 김치찌개는 비오는 날씨에 먹기 딱 좋은 음식입니다. 김치의 매운 맛과 돼지고기, 두부 등의 부드러운 식재료가 조화를 이루어, 몸 안을 따뜻하게 해주는 효과가 있습니다. 3. 비오는날 음식 떡볶이떡볶이는 바삭하게 구운 어묵과 부드러운 떡이 어우러진 매콤한 음식입니다. 비오는 날씨에는 떡볶이를 먹으면 몸..","author":{"@type":"Person","name":"메뉴픽","logo":null},"image":{"@type":"ImageObject","url":"https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FcO305i%2Fbtr75taFhNH%2F0xDEMYEnJDINavmKMHnBjK%2Fimg.webp","width":"800px","height":"800px"},"datePublished":"20230405T15:36:00","dateModified":"20230405T15:36:00","publisher":{"@type":"Organization","name":"TISTORY","logo":{"@type":"ImageObject","url":"https://t1.daumcdn.net/tistory_admin/static/images/openGraph/opengraph.png","width":"800px","height":"800px"}}}
# </script>
# <!-- END STRUCTURED_DATA -->
# <script src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/script/common.js" type="text/javascript"></script>
# <script defer="" src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/script/comment.js" type="text/javascript"></script>
# </link></meta></meta></head>
# <body class="layout-wide color-bright post-type-text paging-view-more" id="tt-body-page">
# <div id="acc-nav">
# <a href="#content">본문 바로가기</a>
# </div>
# <div id="wrap">
# <header id="header">
# <div class="inner">
# <h1>
# <a href="https://menupick.tistory.com/">
#
#
# 						맛있게 먹고 건강을 지키자
#
# 				</a>
# </h1>
# <button class="mobile-menu" type="button"><span>메뉴</span></button>
# <nav id="gnb">
# <ul>
# <li class="t_menu_home first"><a href="/" target="">홈</a></li>
# <li class="t_menu_tag"><a href="/tag" target="">태그</a></li>
# <li class="t_menu_guestbook last"><a href="/guestbook" target="">방명록</a></li>
# </ul>
# </nav>
# </div>
# </header>
# <hr/>
# <section class="container">
# <article id="content">
# <div class="inner">
# <div class="hgroup">
# <div class="category">레시피</div>
# <h1>비오는날 음식 베스트 7가지 </h1>
# <div class="post-meta">
# <span class="author">메뉴픽</span>
# <span class="date">2023. 4. 5. 15:36</span>
# </div>
# </div>
# <div class="entry-content">
# <!-- System - START -->
# <div class="revenue_unit_wrap">
# <div class="revenue_unit_item adsense responsive">
# <div class="revenue_unit_info">반응형</div>
# <script async="async" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-6587134976682849" data-ad-format="auto" data-ad-host="ca-host-pub-9691043933427338" style="display: block;"></ins>
# <script>(adsbygoogle = window.adsbygoogle || []).push({});</script>
# </div>
# </div>
# <!-- System - END -->
# <div class="tt_article_useless_p_margin contents_style"><p data-ke-size="size16" style="text-align: left;">비오는 날씨에는 따뜻하고 감성적인 음식이 더욱 맛있게 느껴집니다. 이번에는 한국인이 추천하는 비오는 날 음식 베스트 7가지를 소개합니다.<br/><br/></p><h3 data-ke-size="size23" style="text-align: left;">1. 비오는날 음식 불고기</h3><p data-ke-size="size16" style="text-align: left;">한국인이 가장 좋아하는 음식 중 하나인 불고기는 비오는 날씨에도 먹기 좋은 음식입니다. 불고기는 부드러운 소고기와 달콤한 양념이 조화를 이루어, 따뜻한 밥과 함께 먹으면 굉장히 맛있습니다.</p><figure class="imageblock alignCenter" data-ke-mobilestyle="widthOrigin" data-origin-height="360" data-origin-width="540"><span data-lightbox="lightbox" data-url="https://blog.kakaocdn.net/dn/cO305i/btr75taFhNH/0xDEMYEnJDINavmKMHnBjK/img.webp"><img data-origin-height="360" data-origin-width="540" onerror="this.onerror=null; this.src='//t1.daumcdn.net/tistory_admin/static/images/no-image-v1.png'; this.srcset='//t1.daumcdn.net/tistory_admin/static/images/no-image-v1.png';" src="https://blog.kakaocdn.net/dn/cO305i/btr75taFhNH/0xDEMYEnJDINavmKMHnBjK/img.webp" srcset="https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&amp;fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FcO305i%2Fbtr75taFhNH%2F0xDEMYEnJDINavmKMHnBjK%2Fimg.webp"/></span></figure>
# <figure class="imageblock alignCenter" data-ke-mobilestyle="widthOrigin" data-origin-height="360" data-origin-width="540"><span data-lightbox="lightbox" data-url="https://blog.kakaocdn.net/dn/PpjQm/btr76yv18pA/N1e46nWQsQHKWfknXNGsO1/img.webp"><img data-origin-height="360" data-origin-width="540" onerror="this.onerror=null; this.src='//t1.daumcdn.net/tistory_admin/static/images/no-image-v1.
src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-6587134976682849" data-ad-format="auto" data-ad-host="ca-host-pub-9691043933427338" style="display: block;"></ins>
# <script>(adsbygoogle = window.adsbygoogle || []).push({});</script>
# </div>
# </div>
# <!-- System - END -->
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9527582522912841"></script>
# <!-- inventory -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9527582522912841" data-ad-format="auto" data-ad-slot="4947159016" data-ad-type="inventory" data-full-width-responsive="true" style="margin:30px 0; display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <div class="container_postbtn #post_button_group">
# <div class="postbtn_like"><script>window.ReactionButtonType = 'reaction';
# window.ReactionApiUrl = '//menupick.tistory.com/reaction';
# window.ReactionReqBody = {
#     entryId: 15
# }</script>
# <div class="wrap_btn" id="reaction-15"></div>
# <script src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/script/reaction-button-container.min.js"></script><div class="wrap_btn wrap_btn_share"><button aria-expanded="false" class="btn_post sns_btn btn_share" data-blog-title="맛있게 먹고 건강을 지키자" data-description="비오는 날씨에는 따뜻하고 감성적인 음식이 더욱 맛있게 느껴집니다. 이번에는 한국인이 추천하는 비오는 날 음식 베스트 7가지를 소개합니다. 1. 비오는날 음식 불고기한국인이 가장 좋아하는 음식 중 하나인 불고기는 비오는 날씨에도 먹기 좋은 음식입니다. 불고기는 부드러운 소고기와 달콤한 양념이 조화를 이루어, 따뜻한 밥과 함께 먹으면 굉장히 맛있습니다. 2. 비오는날 음식 김치찌개한국인들의 대표적인 국물 요리인 김치찌개는 비오는 날씨에 먹기 딱 좋은 음식입니다. 김치의 매운 맛과 돼지고기, 두부 등의 부드러운 식재료가 조화를 이루어, 몸 안을 따뜻하게 해주는 효과가 있습니다. 3. 비오는날 음식 떡볶이떡볶이는 바삭하게 구운 어묵과 부드러운 떡이 어우러진 매콤한 음식입니다. 비오는 날씨에는 떡볶이를 먹으면 몸.." data-pc-url="https://menupick.tistory.com/15" data-profile-image="https://tistory1.daumcdn.net/tistory/6250252/attach/4717ef9b9a794018a788762eabc5a2d2" data-profile-name="메뉴픽" data-relative-pc-url="/15" data-thumbnail-url="https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FcO305i%2Fbtr75taFhNH%2F0xDEMYEnJDINavmKMHnBjK%2Fimg.webp" data-title="비오는날 음식 베스트 7가지" type="button"><span class="ico_postbtn ico_share">공유하기</span></button>
# <div class="layer_post" id="tistorySnsLayer"></div>
# </div><div class="wrap_btn wrap_btn_etc" data-category-visibility="public" data-entry-id="15" data-entry-visibility="public"><button aria-expanded="false" class="btn_post btn_etc2" type="button"><span class="ico_postbtn ico_etc">게시글 관리</span></button>
# <div class="layer_post" id="tistoryEtcLayer"></div>
# </div></div>
# <button class="btn_menu_toolbar btn_subscription #subscribe" data-blog-id="6250252" data-device="web_pc" data-url="https://menupick.tistory.com/15" type="button"><em class="txt_state">구독하기</em><strong class="txt_tool_id">맛있게 먹고 건강을 지키자</strong><span class="img_common_tistory ico_check_type1"></span></button></div>
# <!-- PostListinCategory - START -->
://img1.daumcdn.net/thumb/R750x0/?scode=mtistory2&amp;fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FbLT5TC%2Fbtr726L0rbm%2FSQoDEQdO8ezm55MooiNz1K%2Fimg.jpg"/>
# </span>
# <span class="title">당뇨 예방에 좋은 음식 메뉴 추천 7가지</span>
# </a>
# </li>
# </ul>
# </div>
# <div id="entry15Comment">
# <div class="comments">
# <div class="comment-list">
# <ul>
# </ul>
# </div>
# <form action="/comment/add/15" method="post" onsubmit="return false" style="margin: 0">
# <div class="comment-form">
# <div class="field">
# <input name="name" placeholder="이름" type="text" value=""/>
# <input name="password" placeholder="암호" type="password" value=""/>
# <div class="secret">
# <input id="secret" name="secret" type="checkbox"/>
# <label for="secret" tabindex="0">Secret</label>
# </div>
# </div>
# <label class="screen_out" for="comment">댓글</label>
# <textarea cols="" id="comment" name="comment" placeholder="여러분의 소중한 댓글을 입력해주세요." rows="4"></textarea>
# <div class="submit">
# <button class="btn" onclick="addComment(this, 15); return false;" type="submit">댓글달기</button>
# </div>
# </div>
# </form>
# </div>
# </div>
# <script type="text/javascript">loadedComments[15]=true;
# findFragmentAndHighlight(15);</script>
# </div>
# </article>
# <aside id="aside">
# <div class="inner">
# <div class="sidebar-1">
# <!-- 공지사항 -->
# <div class="posts">
# <h2>공지사항</h2>
# <ul>
# </ul>
# </div>
# <!-- 최근 포스트 -->
# <div class="posts">
# <h2>최근 포스트</h2>
# <ul>
# <li><a href="/29">부고위로문자 문구 추천!</a></li>
# <li><a href="/28">생일축하 문구 모음 추천!</a></li>
# <li><a href="/27">결혼축하메시지 추천 문구 20가지</a></li>
# <li><a href="/26">생일축하메시지 20가지 추천!</a></li>
# <li><a href="/25">직장인들이 좋아하는 점심 메뉴 Best 7</a></li>
# </ul>
# </div>
# </div>
# <div class="sidebar-2">
# <!-- 태그 -->
# <div class="tags">
# <h2>태그</h2>
# <div class="items">
# <a href="/tag/%EC%95%94%EC%97%90%20%EC%A2%8B%EC%9D%80%EC%9D%8C%EC%8B%9D%20%23%EC%95%94%EC%98%88%EB%B0%A9%20%23%ED%95%AD%EC%95%94%ED%9A%A8%EA%B3%BC">암에 좋은음식 #암예방 #항암효과</a>
# <a href="/tag/%EB%8B%B9%EB%87%A8%EC%97%90%20%EC%A2%8B%EC%9D%80%20%EC%B1%84%EC%86%8C">당뇨에 좋은 채소</a>
# <a href="/tag/%EA%B3%A0%ED%98%88%EC%95%95%20%EC%98%88%EB%B0%A9%20%EC%8B%9D%EC%8A%B5%EA%B4%80">고혈압 예방 식습관</a>
# <a href="/tag/%EB%8B%B9%EB%87%A8%EC%97%90%20%EC%A2%8B%EC%9D%80%EC%9D%8C%EC%8B%9D%20%23%EB%B4%84%20%EC%A0%9C%EC%B2%A0%20%23%EC%83%90%EB%9F%AC%EB%93%9C">당뇨에 좋은음식 #봄 제철 #샐러드</a>
# <a href="/tag/%EB%B6%80%EA%B3%A0%EB%AC%B8%EC%9E%90">부고문자</a>
# <a href="/tag/%ED%98%88%EC%95%95%EC%A1%B0%EC%A0%88">혈압조절</a>
# <a href="/tag/%EB%8B%B9%EB%87%A8%EC%97%90%20%EC%A2%8B%EC%9D%80%20%EC%B0%A8">당뇨에 좋은 차</a>
# <a href="/tag/%EB%8B%B9%EB%87%A8%20%EC%98%88%EB%B0%A9%EC%9D%84%20%EC%9C%84%ED%95%9C%20%EC%A2%8B%EC%9D%80%20%EC%8B%9D%EC%8A%B5%EA%B4%80">당뇨 예방을 위한 좋은 식습관</a>
# <a href="/tag/%EA%B3%A0%ED%98%88%EC%95%95%EC%97%90%20%EC%A2%8B%EC%9D%80%20%EC%9D%8C%EC%8B%9D%20%23%ED%98%88%EB%8B%B9%EC%A1%B0%EC%A0%88%20%23">고혈압에 좋은 음식 #혈당조절 #</a>
# </div>
# <a class="more" href="/tag">더보기</a>
# </div>
# </div>
# <div class="sidebar-3">
# <!-- 검색 -->
# <div class="search">
# <h2>검색</h2>
# <fieldset>
# <label class="screen_out" for="search">블로그 내 검색</label>
# <input id="search" name="search" onkeypress="if (event.keyCode == 13 ) { try {
#     window.location.href = '/search' + '/' + looseURIEncode(document.getElementsByName('search')[0].value);
#     document.getElementsByName('search')[0].value = '';
#     return false;
# } catch (e) {} }" placeholder="검색내용을 입력하세요." type="text" value=""/>
# <button onclick="try {
#     window.location.href = '/search' + '/' + looseURIEncode(document.getElementsByName('search')[0].value);
#     document.getElementsByName('search')[0].value = '';
#     return false;
# } catch (e) {}" type="button">검색</button>
# </fieldset>
# </div>
# <!-- 전체 방문자 -->
# <div class="count">
# <h2>전체 방문자</h2>
# <p class="total">1,710</p>
# <ul>
# <li><strong>오늘</strong>57</li>
# <li><strong>어제</strong>110</li>
# </ul>
# </div>
# </div>
# </div>
# </aside>
# </section>
# <hr/>
# <footer id="footer">
# <p class="copyright">DESIGN BY <a href="#">TISTORY</a> <a class="admin" href="https://menupick.tistory.com/manage">관리자</a></p>
# </footer>
# </div>
# <script src="https://tistory1.daumcdn.net/tistory/6250252/skin/images/script.js?_version_=1680089839"></script>
# <div class="#menubar menu_toolbar">
# <h2 class="screen_out">티스토리툴바</h2>
# </div>
# <div class="#menubar menu_toolbar"></div>
# <iframe id="editEntry" src="//menupick.tistory.com/api" style="position:absolute;width:1px;height:1px;left:-100px;top:-100px"></iframe>
# <!-- DragSearchHandler - START -->
# <script src="//search1.daumcdn.net/search/statics/common/js/g/search_dragselection.min.js"></script>
# <!-- DragSearchHandler - END -->
# <!-- SyntaxHighlight - START -->
# <link href="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/styles/atom-one-light.min.css" rel="stylesheet"/><script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/highlight.min.js"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/delphi.min.js"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/php.min.js"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/python.min.js"></script>
# <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/r.min.js"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/ruby.min.js"></script>
# <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/scala.min.js"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/shell.min.js"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/sql.min.js"></script>
# <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/swift.min.js"></script>
# <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/typescript.min.js"></script>
# <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/highlight.js/10.7.3/languages/vbnet.min.js"></script>
# <script>hljs.initHighlightingOnLoad();</script>
# <!-- SyntaxHighlight - END -->
# <script>window.tiara = {"svcDomain":"user.tistory.com","section":"글뷰","trackPage":"글뷰_보기","page":"글뷰","key":"6250252-15","customProps":{"userId":"0","blogId":"6250252","entryId":"15","role":"guest","trackPage":"글뷰_보기","filterTarget":false},"entry":{"entryId":"15","categoryName":"레시피","categoryId":"1119344","author":"6123598","image":"kage@cO305i/btr75taFhNH/0xDEMYEnJDINavmKMHnBjK","plink":"/15","tags":["불고기","비오는날 오늘뭐먹지","비오는날 음식","비오는날 음식추천","오늘뭐먹지"]},"kakaoAppKey":"3e6ddd834b023f24221217e370daed18","appUserId":"null"}</script>
# <script src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/script/tiara.min.js" type="text/javascript"></script>
# <script type="text/javascript">(function($) {
#     $(document).ready(function() {
#         lightbox.options.fadeDuration = 200;
#         lightbox.options.resizeDuration = 200;
#         lightbox.options.wrapAround = false;
#         lightbox.options.albumLabel = "%1 / %2";
#     })
# })(tjQuery);</script>
# <div style="margin:0; padding:0; border:none; background:none; float:none; clear:none; z-index:0"></div>
# <script src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/script/common.js" type="text/javascript"></script>
# <script type="text/javascript">window.roosevelt_params_queue = window.roosevelt_params_queue || [{channel_id: 'dk', channel_label: '{tistory}'}]</script>
# <script async="async" src="//t1.daumcdn.net/midas/rt/dk_bt/roosevelt_dk_bt.js" type="text/javascript"></script>
# <script src="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-af735b6ec8664af1315823528a00e178e4d15ab8/static/script/menubar.min.js" type="text/javascript"></script>
# <script>            (function (win, doc, src) {
#     win.Wpm = win.Wpm || function (name, param) {
#         win.Wpm.queue = win.Wpm.queue || [];
#         const { queue } = win.Wpm;
#         queue.push([name, param]);
#     };
#     const script = doc.createElement('script');
#     script.src = src;
#     script.async = 1;
#     const [elem] = doc.getElementsByTagName('script');
#     elem.parentNode.insertBefore(script, elem);
# })(window, document, 'https://t1.kakaocdn.net/malibu_prod/wpm.js');
#             const APP_KEY = 'd3cda7e82e6e4144bdc998b8e25f125d';
#             Wpm('appKey', APP_KEY);</script>
# </body>
# </html>

# %%
# soup객체로부터 원하는 부분 추출하기
test2 = soup.select('h3')
test2
# Out:
# [<h3 data-ke-size="size23" style="text-align: left;">1. 비오는날 음식 불고기</h3>,
#  <h3 data-ke-size="size23" style="text-align: left;">2. 비오는날 음식 김치찌개</h3>,
#  <h3 data-ke-size="size23" style="text-align: left;">3. 비오는날 음식 떡볶이</h3>,
#  <h3 data-ke-size="size23" style="text-align: left;"><br/>4. 비오는날 음식 비빔밥</h3>,
#  <h3 data-ke-size="size23" style="text-align: left;"><br/>5. 비오는날 음식 칼국수</h3>,
#  <h3 data-ke-size="size23" style="text-align: left;">6. 비오는날 음식 우동</h3>,
#  <h3 data-ke-size="size23" style="text-align: left;">7. 비오는날 음식 해물파전</h3>]

# %%
h2 = []
h2_name = []
for item in test2:
    h2 += item.text.strip().split()
# print(h2)
for i in range(len(h2)):
    if i%4 == 0:
        h2_name.append(h2[i+3])
print(h2_name)
# Out:
# ['불고기', '김치찌개', '떡볶이', '비빔밥', '칼국수', '우동', '해물파전']

# %%
df = DataFrame(h2_name)
df.to_excel("result2.xlsx")
df
# Out:
#       0
# 0   불고기
# 1  김치찌개
# 2   떡볶이
# 3   비빔밥
# 4   칼국수
# 5    우동
# 6  해물파전

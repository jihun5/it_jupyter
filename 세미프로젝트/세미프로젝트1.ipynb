# %%
# ppt, word 등 제출 형식은 자유 결정
# 작성이 완료된 파일을 leekh4232@kakao.com
# 6월 29일까지

# %%
# 수집할 데이터에 대한 관심사가 무엇인지 기술

# %%
# 관심사와 관련된 데이터를 수집할 수 있는 웹사이트
url1 = 'https://brunch.co.kr/@gorrajeju/775'
url2 = 'https://menupick.tistory.com/15'
url3 = 'https://welcome8007.com/33'
url4 = 'https://www.maybugs.com/news/articleView.html?idxno=581068'
url5 = 'https://monimoney.tistory.com/entry/%EB%B9%84-%EC%98%A4%EB%8A%94-%EB%82%A0-%EB%A8%B9%EC%9C%BC%EB%A9%B4-%EB%8D%94-%EB%A7%9B%EC%9E%88%EB%8A%94-%EC%9A%94%EB%A6%AC'

# %%
import requests
from bs4 import BeautifulSoup
from pandas import DataFrame

# %%
userAgent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"

# %%
# 접속객체 생성
session = requests.Session()
# 접속객체에 부가정보(header) 삽입하기
session.headers.update({
    "Referer": "",
    "User-Agent": userAgent
})

# %%
# 생성한 접속객체를 활용하여 API에 접속
r = session.get(url1)
if r.status_code != 200:
    msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
    raise Exception(msg)

# %%
# 인코딩 형식 지정하여 beautifulsoup객체를 생성
r.encoding = "utf-8"
soup = BeautifulSoup(r.text)
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>투표로 뽑기까지? 비오는날 생각나는 음식 TOP 6! </title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="투표로 뽑기까지? 비오는날 생각나는 음식 TOP 6! " name="title"/>
# <meta content="always" name="referrer"/>
# <meta name="secureToken" value="esq0tePVfy9LDR6LDU1L35VkvMpk2SQ9+C4wZeGkWQ2bG473ox9W7vy2v/xKSyrC"/>
# <meta content="max-image-preview:large" name="robots"/>
# <meta content="#ffffff" media="(prefers-color-scheme: light)" name="theme-color">
# <meta content="#000000" media="(prefers-color-scheme: dark)" name="theme-color">
# <meta content="먹는 것엔 항상 진심인 사람들 | 장마가 시작되었다는데, 비 오는 날에 대한 글만 쓰면 날씨가 좋아지는 신비한 매직. 그럼에도 불구하고 이제 장마철에 들어섰으니 빗소리를 들으며 먹기 좋은 음식 리스트를 소개합니다. 이번 리스트는 후보가 많아 고르라 마케팅팀이 투표까지 한 결과예요.  공동 1위 - 파전 / 수제비  대망의 1위에는 파전, 수제비가 나란히 뽑혔어요. 파전이야 두말하면 입 아픈" name="description"/>
# <meta content="고르라제주" property="article:author"/>
# <meta content="고르라제주" name="og:article:author"/>
# <meta content="고르라제주" name="byl"/>
# <meta content="article" property="og:type"/>
# <meta content="Brunch Story" property="og:site_name"/>
# <meta content="투표로 뽑기까지? 비오는날 생각나는 음식 TOP 6! " property="og:title"/>
# <meta content="먹는 것엔 항상 진심인 사람들 | 장마가 시작되었다는데, 비 오는 날에 대한 글만 쓰면 날씨가 좋아지는 신비한 매직. 그럼에도 불구하고 이제 장마철에 들어섰으니 빗소리를 들으며 먹기 좋은 음식 리스트를 소개합니다. 이번 리스트는 후보가 많아 고르라 마케팅팀이 투표까지 한 결과예요.  공동 1위 - 파전 / 수제비  대망의 1위에는 파전, 수제비가 나란히 뽑혔어요. 파전이야 두말하면 입 아픈" property="og:description"/>
# <meta content="//img1.daumcdn.net/thumb/R1280x0/?fname=http://t1.daumcdn.net/brunch/service/user/40Qx/image/mStvT9L86bULr6NP33Ng25xLeb0.jpg" property="og:image"/>
# <meta content="https://brunch.co.kr/@gorrajeju/775" property="og:url"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="브런치스토리" name="twitter:app:name:iphone"/>
# <meta content="1001388574" name="twitter:app:id:iphone"/>
# <meta content="brunchapp://open" name="twitter:app:url:iphone"/>
# <meta content="https://img1.daumcdn.net/thumb/C500x500/?fname=http://t1.daumcdn.net/brunch/service/user/40Qx/image/mStvT9L86bULr6NP33Ng25xLeb0.jpg" name="twitter:image"/>
# <meta content="투표로 뽑기까지? 비오는날 생각나는 음식 TOP 6! " name="twitter:title"/>
# <meta content="먹는 것엔 항상 진심인 사람들 | 장마가 시작되었다는데, 비 오는 날에 대한 글만 쓰면 날씨가 좋아지는 신비한 매직. 그럼에도 불구하고 이제 장마철에 들어섰으니 빗소리를 들으며 먹기 좋은 음식 리스트를 소개합니다. 이번 리스트는 후보가 많아 고르라 마케팅팀이 투표까지 한 결과예요.  공동 1위 - 파전 / 수제비  대망의 1위에는 파전, 수제비가 나란히 뽑혔어요. 파전이야 두말하면 입 아픈" name="twitter:description"/>
# <meta content="313683402170826" property="fb:app_id"/>
# <link href="//t1.daumcdn.net/brunch/static/icon/favicon/brunchstory/favicon_20230406.ico" rel="SHORTCUT ICON"/>
# <link href="//t1.daumcdn.net/brunch/static/icon/ios/brunchstory/ico_bi_180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
# <link href="//t1.daumcdn.net/brunch/static/icon/ios/brunchstory/ico_bi_152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="//t1.daumcdn.net/brunch/static/icon/ios/brunchstory/ico_bi_120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.min.css" rel="stylesheet" type="text/css"/>
# <link href="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.Message.min.css" rel="stylesheet" type="text/css"/>
# <link href="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.Font.min.css" rel="stylesheet" type="text/css"/>
# <script src="//t1.daumcdn.net/brunch/static/libraries/js/jquery.min-3.6.4.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/libraries/js/jquery.cookie.min-1.4.1.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/libraries/js/jquery.xdomainrequest.min-1.0.4.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/libraries/js/jquery.word-break-keep-all.min-1.3.0.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/libraries/js/handlebars.runtime.min-v3.0.0.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/libraries/js/sentry.min.5.27.4.js?v=20221124" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/libraries/js/clipboard.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/tiara/js/v1/tiara.min.js" type="text/javascript"></script>
# <script>
#     window.Guard = {
#         hasError:  false,
#         excuteFunctionArray: [],
#         loadedJsHistory: [],
#
#         /*
#             kebana에 프론트 로그 발생 오류를 기록 한다.
#          */
#         fetchLog: function(message, extraJson) {
#             if (!window.fetch && !fetch) {
#                 return '';
#             }
#             var csrfToken = document.querySelector('meta[name=secureToken]').attributes['value'].value;
#
#             fetch('https://api.brunch.co.kr/v1/front-log', {
#                 method: 'POST',
#                 headers: {
#                     'Content-Type': 'application/json',
#                     'X-CSRF-TOKEN': csrfToken
#                 },
#                 credentials: 'include',
#                 body : JSON.stringify({
#                     message: message,
#                     extras: extraJson
#                 })
#             })
#         },
#
#         /*
#             js파일의 tenth2 fetch 결과를 Matrix에 기록.
#          */
#         checkTenth2JsStatus: function (jsFileName) {
#             var phase = '/';
#                             phase = '/production/'
#                         var jsUrl = '//t1.daumcdn.net/brunch/static/prod/202306211326' + phase + jsFileName;
#
#             if (!window.fetch && !fetch) {
#                 return '';
#             }
#
#             fetch(jsUrl).then(function(response) {
#                 Sentry.setTag('InitFail', 'FailLoadTenth2js');
#                 Sentry.captureMessage('[BRUNCH] InitFail - Tenth2', {
#                     extra: {
#                         extra: {
#                             status: response.status,
#                             url: response.url,
#                             statusText: response.statusText,
#                         },
#                     },
#                 });
#             }).catch(function(error) {
#                 Sentry.captureMessage('[BRUNCH] InitFail - Tenth2', {
#                     extra: {
#                         extra: {
#                             url: jsUrl,
#                         },
#                     },
#                 });
#             });
#         },
#
#         dynamicAppendJsLibraryTags: function(jsFileNameArray) {
#           for(var i=0; i<jsFileNameArray.length; i++) {
#               this.dynamicAppendJsLibraryTag(jsFileNameArray[i]);
#           }
#         },
#
#         dynamicAppendJsLibraryTag: function(jsFileName) {
#             this.createScriptTag('/static/libraries/js/', jsFileName);
#         },
#
#         /**
#          * 자바스크립트 동적 생성 함수
#          * @param {String} jsPath - 자바스크립트 파일 경로
#          * @param {String} jsFileName - 자바스크립트 파일 이름
#          * @param {Function} onLoadCallback - 스크립트 onLoad 이후 실행될 함수
#          */
#         createScriptTag: function(jsPath, jsFileName, onLoadCallback) {
#             this.loadedJsHistory.push(jsFileName);
#             var script = document.createElement('script');
#             script.type = 'text/javascript';
#             script.src = jsPath + jsFileName;
#             if (onLoadCallback) {
#                 script.onload = function() {
#                     onLoadCallback();
#                 }
#             }
#             script.onerror = function(e) {
#                 this.matrixLogging(e, 'Invalid Script src', jsPath + jsFileName);
#             }.bind(this)
#             script.async = false;
#             this.removeScriptTag(jsFileName);
#             document.getElementsByTagName('head')[0].appendChild(script);
#         },
#
#         /**
#          * dom 내에 존재하는 대상 스크립트를 찾아서 제거 하는 함수
#          * @param {String} targetSrc
#          */
#         removeScriptTag: function(targetSrc) {
#             for (var i=0; i<document.scripts.length; i++) {
#
#                 if (document.scripts[i].src.indexOf(targetSrc) > -1) {
#                     document.scripts[i].remove();
#                 }
#             }
#         },
#
#         /**
#          * 함수를 실행하고, 그 실행 내역을 Array에 저장
#          * @param {Function} func - 실행될 함수
#          */
#         executeAndSaveFunction: function(func) {
#             try {
#                 this.excuteFunctionArray.push(func);
#                 func();
#             } catch(e) {
#                 if(!this.hasError) {
#                     this.fetchLog('script error occur', {});
#                 }
#                 this.hasError = true;
#             }
#         },
#
#         /**
#          * 글뷰 페이지를 복구 하기 위한 함수
#          * 1. libraries 태그 복원
#          * 2. 글뷰 통합 번들 파일 추가
#          * @param {boolean} isPc
#          */
#         restoreArticlePage: function(isPc) {
#             var scripts = [
#                 "sentry.min.5.27.4.js",
#                 "jquery.min-3.6.4.js",
#                 "jquery.cookie.min-1.4.1.js",
#                 "jquery.xdomainrequest.min-1.0.4.js",
#                 "jquery.word-break-keep-all.min-1.3.0.js",
#                 "handlebars.runtime.min-v3.0.0.js"
#             ];
#             this.dynamicAppendJsLibraryTags(scripts);
#             this.excuteFunctionArray.push(function() {
#                 this.loggedIsArticleRestored(isPc);
#             }.bind(this));
#
#             if (isPc) {
#                 this.createScriptTag('/static/production/', 'brunch.article.pc.min.js', this.doExcuteFunctionArray.bind(this));
#             } else {
#                 this.createScriptTag('/static/production/', 'brunch.article.mobile.min.js', this.doExcuteFunctionArray.bind(this));
#             }
#         },
#
#         /**
#          * article 페이지 복구 여부에 대한 기록 함수
#          * PC .wrap_body_frame 존재 유무
#          * Mobile #articleMain display 속성 확인 (not none)
#          * @param isPc
#          */
#         loggedIsArticleRestored: function(isPc) {
#             var isRestored = false;
#
#             if (isPc) {
#                 isRestored = document.querySelector('.wrap_body_frame') !== null
#             } else {
#                 isRestored = window.getComputedStyle(document.querySelector('#articleMain')).display !== 'none';
#             }
#
#             var fetchMsg = 'restorePageFail';
#
#             if (isRestored) {
#                 fetchMsg = 'restorePage';
#             }
#
#             this.fetchLog(fetchMsg, {
#                 isPc: isPc
#             })
#         },
#
#         doExcuteFunctionArray: function() {
#             if (this.excuteFunctionArray.length > 0) {
#                 for (var i = 0; i < this.excuteFunctionArray.length; i++) {
#                     var func = this.excuteFunctionArray[i];
#
#                     if (func && typeof func === 'function') {
#                         try {
#                             func();
#                         } catch(e) {
#                             this.fetchLog('failRestorePage', {
#                                 error: e,
#                             })
#                         }
#                     }
#                 }
#             }
#         },
#
#         matrixLogging: function(error, tagValue, data) {
#             // B.Util 스크립트도 로딩이 안된 경우가 있어 별도의 로깅을 진행 한다.
#             Sentry.addBreadcrumb({
#                 type: 'error',
#                 category: 'error',
#                 level: 'error',
#                 data: { data }
#             });
#             Sentry.setTag('Monitoring', tagValue);
#             Sentry.captureMessage('[BRUNCH] Article View Restore Fail');
#         }
#     };
# </script>
# <script type="text/javascript">
#     window._platform = "pc";
#
#     function sentryInit() {
#         Sentry.init({
#             dsn: 'https://7092d1f177184e73a6cda1ee2d14ecc4@aem-collector.daumkakao.io/3057',
#             release: '202306211326',
#             environment: 'prod',
#                         allowUrls: [
#                 "brunch.co.kr",
#                 "dev.onkakao.net",
#                 "daumcdn.net"
#             ],
#         });
#         Sentry.setTag("ua.platform", window._platform);
#             }
#
#     Guard.executeAndSaveFunction(sentryInit);
# </script>
# <script>
#     if (typeof jQuery === 'undefined') {
#         var scripts = [
#             "sentry.min.5.27.4.js",
#             "jquery.min-3.6.4.js",
#             "jquery.cookie.min-1.4.1.js",
#             "jquery.xdomainrequest.min-1.0.4.js",
#             "jquery.word-break-keep-all.min-1.3.0.js",
#             "handlebars.runtime.min-v3.0.0.js"
#         ]
#         Guard.dynamicAppendJsLibraryTags(scripts);
#         Guard.fetchLog('libraries init', {});
#     }
# </script> <link href="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.Article.min.css" rel="stylesheet" type="text/css"/>
# <link href="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.SubscriptionLayer.min.css" rel="stylesheet" type="text/css"/>
# <!--[if lt ie 9]>
#     <link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/brunch/static/prod/202306211326/css/B.Article.Ie9lt.css"/>
#     <![endif]-->
# <meta content="https://brunch.co.kr/@@40Qx/775" property="dg:plink">
# <meta content="https://brunch.co.kr/@@40Qx/775" name="plink">
# <meta content="https://brunch.co.kr/@@40Qx/775" property="article:mobile_url">
# <meta content="https://brunch.co.kr/@@40Qx/775" property="article:pc_url">
# <meta content="https://brunch.co.kr" property="article:mobile_service_home">
# <meta content="https://brunch.co.kr" property="article:pc_service_home">
# <meta content="https://brunch.co.kr/@@40Qx/775" property="article:mobile_view_url">
# <meta content="https://brunch.co.kr/@@40Qx/775" property="article:pc_view_url">
# <meta content="https://brunch.co.kr/@@40Qx/775" property="article:talk_channel_view_url">
# <meta content="40Qx_775" property="article:txid">
# <meta content="2020-06-26T09:01+0900" property="article:published_time">
# <meta content="2020-06-26T09:01+0900" property="og:regDate">
# <meta content="고르라제주" name="article:media_name">
# <meta content="브런치" name="article:service_name">
# <meta content='{"site_info":{"name":"브런치","image":"https://t1.daumcdn.net/brunch/static/img/help/mw/ico_brunch_kakaostory_richscrap70x70.png","url":"https://brunch.co.kr"},"header":{"category_title":"제주도 맛집 리스트","subtitle":"먹는 것엔 항상 진심인 사람들","title":"투표로 뽑기까지? 비오는날 생각나는 음식 TOP 6! ","image":"https://img1.daumcdn.net/thumb/R1280x0/?fname\u003dhttp://t1.daumcdn.net/brunch/service/user/40Qx/image/mStvT9L86bULr6NP33Ng25xLeb0.jpg","date":"2020.06.26"},"author":{"name":"고르라제주","image":"http://t1.daumcdn.net/brunch/service/user/40Qx/image/YOkFN0oLKRq3HhRViu4kB0Wg9lg.png","url":"https://brunch.co.kr/@gorrajeju"},"cards":[{"type":"image","body":{"content":"","image":"https://img1.daumcdn.net/thumb/R1280x0/?fname\u003dhttp://t1.daumcdn.net/brunch/service/user/40Qx/image/nX8spMFl0tIkyLqZ4LNeEUevLiA.jpg"}},{"type":"text","body":{"content":" ","image":""}},{"type":"text","body":{"content":"장마가 시작되었다는데, 비 오는 날에 대한 글만 쓰면 날씨가 좋아지는 신비한 매직. 그럼에도 불구하고 이제 장마철에 들어섰으니 빗소리를 들으며 먹기 좋은 음식 리스트를 소개합니다. 이번 리스트는 후보가 많아 고르라 마케팅팀이 투표까지 한 결과예요.","image":""}},{"type":"text","body":{"content":" ","image":""}},{"type":"text","body":{"content":"공동 1위 - 파전 / 수제비","image":""}},{"type":"image","body":{"content":"","image":"https://img1.daumcdn.net/thumb/R1280x0/?fname\u003dhttp://t1.daumcdn.net/brunch/service/user/40Qx/image/vW-mcr4inKoPRW387O6NF7HPPsc.jpg"}},{"type":"text","body":{"content":" ","image":""}},{"type":"text","body":{"content":"대망의 1위에는 파전, 수제비가 나란히 뽑혔어요. 파전이야 두말하면 입 아픈 비날씨 대표 메뉴죠. 지글지글 파전 익는 소리는 빗소리와 어쩜 그리 똑같은지. 이젠 비 내리는 소리를 들을 때 반사적으로 파전에 막걸리가 고파집니다.","image":""}},{"type":"text","body":{"content":" ","image":""}},{"type":"image","body":{"content":"","image":"https://img1.daumcdn.net/thumb/R1280x0/?fname\u003dhttp://t1.daumcdn.net/brunch/service/user/40Qx/image/ZT7Ng83KHr7AkbZ1qy4hxGGY238.jpg"}}]}' property="ks:richscrap"/>
# </meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></head>
# <body>
# <tiara-page data-tiara-author="" data-tiara-author_id="@@40Qx" data-tiara-category="고르라제주" data-tiara-category_id="gorrajeju" data-tiara-id="775" data-tiara-image="http://t1.daumcdn.net/brunch/service/user/40Qx/image/mStvT9L86bULr6NP33Ng25xLeb0.jpg" data-tiara-name="투표로 뽑기까지? 비오는날 생각나는 음식 TOP 6! " data-tiara-series="제주도 맛집 리스트" data-tiara-series_id="24114" data-tiara-tags="음식,파전,날씨" data-tiara-type="publish" t-action-kind="ViewContent" t-name="글뷰 &gt; 페이지뷰" t-page="articleview" t-section="article">
# </tiara-page>
# <tiara-usage t-target=".wrap_body.finish_txt"></tiara-usage>
# <tiara-area t-name="cover" t-target=".wrap_cover.cover_type_text"></tiara-area>
# <tiara-area t-name="body" t-target=".wrap_body.finish_txt"></tiara-area>
# <tiara-area t-name="brunchbook_article" t-target=".wrap_body_info"></tiara-area>
# <tiara-area t-name="profile" t-target=".wrap_author"></tiara-area>
# <tiara-area t-name="recommended_article" t-target=".wrap_related_article"></tiara-area>
# <tiara-area t-name="banner" t-target=".wrap_article_footer_banner"></tiara-area>
# <input id="articleShareUrl" type="hidden" value="https://brunch.co.kr/@gorrajeju/775"/>
# <input id="articleShareTitle" type="hidden" value="투표로 뽑기까지? 비오는날 생각나는 음식 TOP 6! "/>
# <input id="articleShareContentSummary" type="hidden" value="장마가 시작되었다는데, 비 오는 날에 대한 글만 쓰면 날씨가 좋아지는 신비한 매직. 그럼에도 불구하고 이제 장마철에 들어섰으니 빗소리를 들으며 먹기 좋은 음식 리스트를 소개합니다. 이번 리스트는 후보가 많아 고르라 마케팅팀이 투표까지 한 결과예요.  공동 1위 - 파전 / 수제비  대망의 1위에는 파전, 수제비가 나란히 뽑혔어요. 파전이야 두말하면 입 아픈"/>
# <input id="articleShareImageUrl" type="hidden" value="http://t1.daumcdn.net/brunch/service/user/40Qx/image/mStvT9L86bULr6NP33Ng25xLeb0.jpg"/>
# <div class="service_header article #post_toolbar" data-tiara-layer="gnb">
# <div class="progress-container">
# <div class="progress-bar" id="progressBar" style="width: 0%;"></div>
# </div>
# <div class="wrap_inner">
# <div class="f_l">
# <button class="f_l text_hide btn_menu img_ico #sidebar" id="btnServiceMenu" type="button">메뉴</button>
# <h1 class="f_l">
# <a class="logo_service text_hide" href="/" title="brunch">brunch</a>
# </h1>
# </div>
# <div class="wrap_cover_type">
# <span class="txt_article">매거진</span>
# <a class="link_type #post_toolbar#p_magazine_title" href="/magazine/gorrafood">
# <span class="tit_type">제주도 맛집 리스트</span>
# </a>
# </div>
# <div class="f_r">
# <div class="wrap_action_article">
# <button class="f_r img_ico text_hide ico_action #more" id="btnToggleArticleMoreAction" type="button">실행</button>
# <div class="more_action_wrap f_r">
# <button class="reportArticle f_l more_action text_hide img_ico img_ico_single ico_report requireLogin #report">신고</button>
# </div>
# <div class="default_action_wrap f_r">
# <a class="default_action headerLikeBtn img_ico_wrap #likeit" href="#likeit" onclick="return B.ArticleLike.like(this)">
# <span class="f_l text_hide img_ico img_ico_with_text ico_likeit_like #like">라이킷</span>
# <span class="f_l text_like_count text_default text_with_img_ico ico_likeit_like #like">6</span>
# </a>
# <a class="default_action img_ico_wrap comment #comment" href="#comments">
# <span class="f_l text_hide img_ico img_ico_with_text ico_comment">댓글</span>
# <span class="f_l text_comment_count text_default text_with_img_ico"></span>
# </a>
# <span class="wrapButtonSocialShare f_l default_action img_ico_wrap #share">
# <span class="f_l text_hide img_ico img_ico_with_text ico_share" style="cursor:pointer">공유</span>
# <span class="wrap_share_gnb wrap_share_common">
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="wrapSideMenu">
# <main>
# <button class="btn_close_side_menu img_side_menu ico_close f_r text_hide" id="btnCloseSideMenu" type="button">닫기</button>
# <div class="wrap_side_profile logout">
# <div class="logo_service"></div>
# <p class="slogan">The Story of<br/>Future Writers</p>
# <a class="#side_request btn_apply_author article" data-tiara-action-name="메뉴 &gt; 시작하기 버튼 클릭" data-tiara-layer="login" href="#" id="brunchSigninButton"><button class="btn_request">브런치스토리 시작하기</button></a>
# </div>
# <div class="wrap_side_service_menu">
# <ul>
# <li>
# <a class="menu_word7 #side_brunch" data-tiara-action-name="메뉴 &gt; 브런치 홈 버튼 클릭" data-tiara-layer="top" href="/"><span class="bar_left"></span>브런치스토리 홈<span class="bar_right"></span></a>
# </li>
# <li>
# <a class="menu_word8 #side_now brunchNowLink" data-tiara-action-name="메뉴 &gt; 브런치 나우 버튼 클릭" data-tiara-layer="now" href="/now"><span class="bar_left"></span>브런치스토리 나우<span class="bar_right"></span></a>
# </li>
# <li>
# <a class="menu_word8 #side_publish brunchPublishLink" data-tiara-action-name="메뉴 &gt; 브런치 책방 버튼 클릭" data-tiara-layer="bookshop" href="/publish"><span class="bar_left"></span>브런치스토리 책방<span class="bar_right"></span></a>
# </li>
# </ul>
# <div class="wrap_side_setting wrap_find_user">
# <div class="menu_side_banner" style="padding-bottom: 40px;">
# <a class="#side_project" data-tiara-action-name="메뉴 &gt; 작가 지원 프로젝트 버튼 클릭" data-tiara-layer="projectlist" href="/special/list">
# <img alt="프로젝트 리스트 바로가기" src="//i1.daumcdn.net/thumb/R336x0/?fname=http://t1.daumcdn.net/brunch/static/img/help/pc/top/side_banner_20221221.png" style="width:168px"/>
# </a>
# </div> <a class="find_user" data-tiara-action-name="메뉴 &gt; 계정 찾기 버튼 클릭" data-tiara-layer="find_accounts" href="/signin/find_account">계정을 잊어버리셨나요?</a>
# </div>
# </div>
# </main>
# </div>
# <div class="service_contents article_contents #post_view">
# <input id="articleProfileId" type="hidden" value="gorrajeju"/>
# <input id="articleUserId" type="hidden" value="40Qx"/>
# <input id="articleNo" type="hidden" value="775"/>
# <input id="articleStatus" type="hidden" value="publish"/>
# <input id="articleMagazineNo" type="hidden" value="24114"/>
# <input id="articleCommentWritable" type="hidden" value="true"/>
# <input id="blockedUser" type="hidden" value="false"/>
# <input id="blockingUser" type="hidden" value="false"/>
# <input data-article-no="775" data-title="투표로 뽑기까지? 비오는날 생각나는 음식 TOP 6! " data-user-id="40Qx" data-user-name="고르라제주" id="tiaraEventMeta" type="hidden"/>
# <div class="wrap_view_article wrap_article article_view_disable_selection">
# <!-- 키워드, 댓글 버튼 시작 -->
# <div class="wrap_body_info" style="display: none;">
# <!-- 브런치북 글 목록 PC -->
# <div class="inner_body_info">
# <!-- 키워드 -->
# <!-- 키워드 -->
# <div class="info_article wrap_keyword" data-ctr-expose="keyword" data-ctr-referrer="true">
# <strong class="screen_out">keyword</strong>
# <ul class="list_keyword">
# <li>
# <a class="link_keyword #keyword" data-ctr-click="keyword_click" data-ctr-referrer="true" data-tiara-action-name="글뷰 &gt; 본문 하단 &gt; 키워드 클릭" data-tiara-layer="bottom more_contents keyword" href="/keyword/음식">음식
#                             </a>
# </li>
# <li>
# <a class="link_keyword #keyword" data-ctr-click="keyword_click" data-ctr-referrer="true" data-tiara-action-name="글뷰 &gt; 본문 하단 &gt; 키워드 클릭" data-tiara-layer="bottom more_contents keyword" href="/keyword/파전">파전
#                             </a>
# </li>
# <li>
# <a class="link_keyword #keyword" data-ctr-click="keyword_click" data-ctr-referrer="true" data-tiara-action-name="글뷰 &gt; 본문 하단 &gt; 키워드 클릭" data-tiara-layer="bottom more_contents keyword" href="/keyword/날씨">날씨
#                             </a>
# </li>
# </ul>
# </div>
# <span class="wrap_comment_btn">
# <button class="btn_comment #p_comment_open" type="button">
# <span class="ico_article ico_comment"></span>
# <span>댓글</span>
# <span class="num_comment"></span>
# </button>
# </span>
# </div>
# </div>
# <!-- 키워드, 댓글 버튼 끝 -->
# <!-- by 작가명 -->
# <div id="wrapArticleInfo" t-area="Writer">
# <span class="f_l ico_by">by</span>
# <span class="f_l text_author #author">
# <a data-tiara-action-name="글뷰 &gt; 커버 &gt; 작가명 클릭" data-tiara-layer="cover profile" href="https://brunch.co.kr/@gorrajeju">고르라제주</a>
# </span>
# <span class="f_l ico_dot_middle"></span>
# <span class="f_l date">Jun 26. 2020</span>
# </div>
# <div class="wrap_cover"><div class="cover_item cover_full cover_direction_center" data-app='{"type":"cover","kind":"cover_full","align":"center","style":{"background-image":"http://t1.daumcdn.net/brunch/service/user/40Qx/image/mStvT9L86bULr6NP33Ng25xLeb0.jpg"},"title":{"text":"투표로 뽑기까지? 비오는날 생각나는 음식 TOP 6! ","style":{},"data":[{"type":"text","text":"투표로 뽑기까지?"},{"type":"br"},{"type":"text","text":"비오는날 생각나는 음식 TOP 6! "}]},"title-sub":{"text":"먹는 것엔 항상 진심인 사람들","style":{},"data":[{"type":"text","text":"먹는 것엔 항상 진심인 사람들"}]},"width":"933","height":"676"}'><div class="cover_image" style="background-image:url(//t1.daumcdn.net/thumb/R1280x0.fjpg/?fname=http://t1.daumcdn.net/brunch/service/user/40Qx/image/mStvT9L86bULr6NP33Ng25xLeb0.jpg);"></div><div class="cover_inner" style=""></div><div class="cover_cell cover_direction_center"><h1 class="cover_title" style="">투표로 뽑기까지?<br>비오는날 생각나는 음식 TOP 6! </br></h1><p class="cover_sub_title">먹는 것엔 항상 진심인 사람들</p></div></div></div><div class="wrap_body text_align_justify"><div class="wrap_item item_type_hr hr_type_4" data-app='{"type":"hr","kind":"hr_type_4"}'><div class="inner_wrap"><hr/></div></div><div class="wrap_item item_type_img" data-app='{"type":"img","align":"outer-full","mobileAlign":"full","url":"http://t1.daumcdn.net/brunch/service/user/40Qx/image/nX8spMFl0tIkyLqZ4LNeEUevLiA.jpg","caption":"","width":"900","height":"601","originalName":""}'><div class="wrap_outer mobile_align_full"><div class="wrap_img_float"><img src="//t1.daumcdn.net/thumb/R1280x0.fjpg/?fname=http://t1.daumcdn.net/brunch/service/user/40Qx/image/nX8spMFl0tIkyLqZ4LNeEUevLiA.jpg"/><span class="text_caption"></span></div></div></div><p class="wrap_item item_type_text" data-app='{"type":"text","data":[{"type":"br"}]}'><br/></p><h3 class="wrap_item item_type_text" data-app='{"type":"text","data":[{"type":"text","text":"장마가 시작되었다는데, 비 오는 날에 대한 글만 쓰면 날씨가 좋아지는 신비한 매직. 그럼에도 불구하고 이제 장마철에 들어섰으니 빗소리를 들으며 먹기 좋은 음식 리스트를 소개합니다. 이번 리스트는 후보가 많아 고르라 마케팅팀이 투표까지 한 결과예요."}],"size":"h3"}'>장마가 시작되었다는데, 비 오는 날에 대한 글만 쓰면 날씨가 좋아지는 신비한 매직. 그럼에도 불구하고 이제 장마철에 들어섰으니 빗소리를 들으며 먹기 좋은 음식 리스트를 소개합니다. 이번 리스트는 후보가 많아 고르라 마케팅팀이 투표까지 한 결과예요.</h3><p class="wrap_item item_type_text" data-app='{"type":"text","data":[{"type":"br"}]}'><br/></p><div class="wrap_item item_type_hr hr_type_1" data-app='{"type":"hr","kind":"hr_type_1"}'><div class="inner_wrap"><hr/></div></div><h1 class="wrap_item item_type_text" data-app='{"type":"text","data":[{"type":"text","text":"공동 1위 - "},{"type":"text","data":[{"type":"text","text":"파전 / 수제비"}],"styleType":"bold"}],"size":"h1"}'>공동 1위 - <b>파전 / 수제비</b></h1><div class="wrap_item item_type_img" data-app='{"type":"img","align":"outer-full","mobileAlign":"full","url":"http://t1.daumcdn.net/brunch/service/user/40Qx/image/vW-mcr4inKoPRW387O6NF7HPPsc.jpg","caption":"","width":"933","height":"622","originalName":""}'><div class="wrap_outer mobile_align_full"><div class="wrap_img_float"><img src="//t1.daumcdn.net/thumb/R1280x0.fjpg/?fname=http://t1.daumcdn.net/brunch/service/user/40Qx/image/vW-mcr4inKoPRW387O6NF7HPPsc.jpg"/><span class="text_caption"></span></div></div></div><p class="wrap_item item_type_text" data-app='{"type":"text","data":[{"type":"br"}]}'><br/></p><h3 class="wrap_item item_type_text" data-app='{"type":"text","data":[{"type":"text","text":"대망의 1위에는 파전, 수제비가 나란히 뽑혔어요. 파전이야 두말하면 입 아픈 비날씨 대표 메뉴죠. 지글지글 파전 익는 소리는 빗소리와 어쩜 그리 똑같은지. 이젠 비 내리는 소리를 들을 때 반사적으로 파전에 막걸리가 고파집니다."}],"size":"h3"}'>대망의 1위에는 파전, 수제비가 나란히 뽑혔어요. 파전이야 두말하면 입 아픈 비날씨 대표 메뉴죠. 지글지글 파전 익는 소리는 빗소리와 어쩜 그리 똑같은지. 이젠 비 내리는 소리를 들을 때 반사적으로 파전에 막걸리가 고파집니다.</h3><p class="wrap_item item_type_text" data-app='{"type":"text","data":[{"type":"br"}]}'><br/></p><div class="wrap_item item_type_img" data-app='{"type":"img","align":"outer-full","mobileAlign":"full","url":"http://t1.daumcdn.net/brunch/service/user/40Qx/image/ZT7Ng83KHr7AkbZ1qy4hxGGY238.jpg","caption":"","width":"933","height":"622","originalName":""}'><div class="wrap_outer mobile_align_full"><div class="wr ...
# </div>
# <!-- 댓글 -->
# <div class="brunch_comment #comment open_comment" style="display: none;">
# <a class="screen_out" name="comments">댓글</a>
# <div class="comment_head">
# <strong class="tit_comment">댓글<span class="txt_num"></span></strong>
# </div>
# <div class="comment_content">
# <div class="list_comment_more" style="display: block;">
# <button class="btn_preview" data-action="moreList" type="button">이전 댓글 보기</button>
# </div>
# <ul class="list_comment">
# </ul>
# </div>
# <div class="wrap_comment_write"></div>
# </div>
# <!-- 프로필 -->
# <div class="wrap_author" data-ctr-expose="profile" data-ctr-referrer="true">
# <!-- pc 프로필 시작. -->
# <div class="inner_author">
# <div class="author_profile">
# <strong class="author_name">
# <a class="link_author_name" data-ctr-click="profile_click" data-ctr-referrer="true" data-tiara-action-name="글뷰 &gt; 본문 하단 &gt; 작가 프로필 클릭" data-tiara-layer="bottom writer profile" href="https://brunch.co.kr/@gorrajeju">고르라제주</a>
# </strong>
# <span class="author_belong">
# <em class="screen_out">소속</em>
# <span class="">고르라제주</span>
# <em class="screen_out">직업</em>
# <span class="">마케터</span>
# </span>
# <a class="link_author_image #profile" data-ctr-click="profile_click" data-ctr-referrer="true" data-tiara-action-name="글뷰 &gt; 본문 하단 &gt; 작가 프로필 클릭" data-tiara-copy="고르라제주" data-tiara-layer="bottom writer profile" href="https://brunch.co.kr/@gorrajeju">
# <img alt="" class="img_author" height="100" src="//img1.daumcdn.net/thumb/C200x200/?fname=http://t1.daumcdn.net/brunch/service/user/40Qx/image/YOkFN0oLKRq3HhRViu4kB0Wg9lg.png" width="100"/>
# </a>
# </div>
# <div class="author_desc">
# <a data-tiara-action-name="글뷰 &gt; 본문 하단 &gt; 작가 프로필 클릭" data-tiara-copy="고르라제주" data-tiara-layer="bottom writer profile" href="https://brunch.co.kr/@gorrajeju">
# <p class="txt_desc">제주를 말하다 '고르라' 제주 구석구석을 돌아다니며, 제주도 여행, 제주도 맛집, 제주도 카페, 제주도 숙소를 소개합니다. 제주 지역의 다양한 이야기들도 함께 모아 전합니다.</p>
# </a>
# </div>
# <div class="wrap_subscription">
# <a href="https://brunch.co.kr/@gorrajeju">
# <span class="info_subscription">
# <span>구독자</span>
# <span class="num_subscription">1,522</span>
# </span>
# </a>
# <span class="wrap_subscription_btn">
# <button class="btn_type btn_new_type btn_default btn_profile btnFollow #p_follow" type="button">
# <span class="ico_brunch" style="display:none;"></span>
# <span class="txt_default"><img class="ico_plus" src="https://u1.daumcdn.net/brunch/static/img/icon/ico-plus.png">구독</img></span>
# </button>
# </span>
# </div>
# </div>
# </div>
# <div class="wrap_related_article"></div>
# <div class="wrap_article_footer_banner" data-tiara-action-name="글뷰 &gt; 하단 프로모션 배너 클릭" data-tiara-click_url="https://table.cafe.daum.net/" data-tiara-id="banner" data-tiara-layer="bottom banner" style="background-color:#63b3ff">
# <a class="link_bnr #banner" href="https://table.cafe.daum.net/" target="_blank">
# <img alt="" class="img_bnr" src="https://t1.daumcdn.net/section/oc/577a5f0ef71e4bfd97ac5785da1bec62" style="width:700px;"/>
# </a>
# </div>
# <div class="wrap_page_article" data-ctr-expose="writers_post" data-ctr-referrer="true" data-tiara-action-kind="ClickContent" data-tiara-action-name="글뷰 &gt; 하단 고정 영역 &gt; 매거진 다른글 클릭">
# <a class="link_page #p_bottom#prev_post" data-ctr-click="writers_post_click" data-ctr-referrer="true" data-tiara-author="" data-tiara-author_id="@@40Qx" data-tiara-copy="하루의 마무리를 완벽하게 에디터의 &lt;저녁을 고르라&gt;" data-tiara-id="775" data-tiara-layer="bottom_bar magazine_article" data-tiara-name="투표로 뽑기까지? 비오는날 생각나는 음식 TOP 6! " data-tiara-type="magazine_article" href="/@gorrajeju/772">
# <span class="txt_page">
#                                                                      매거진의 이전글
#                                                                                                 </span>
# <strong class="tit_page">하루의 마무리를 완벽하게 에디터의 &lt;저녁을 고르라&gt;</strong>
# </a>
# <a class="link_page link_next #p_bottom#next_post" data-ctr-click="writers_post_click" data-ctr-referrer="true" data-tiara-author="" data-tiara-author_id="@@40Qx" data-tiara-copy="옥돔뭇국이 열어준 맛의 신세계 &lt;한라식당&gt;" data-tiara-id="775" data-tiara-layer="bottom_bar magazine_article" data-tiara-name="투표로 뽑기까지? 비오는날 생각나는 음식 TOP 6! " data-tiara-type="magazine_article" href="/@gorrajeju/776">
# <strong class="tit_page">옥돔뭇국이 열어준 맛의 신세계 &lt;한라식당&gt;</strong>
# <span class="txt_page next_page">
#                                                                      매거진의 다음글                                                             </span>
# </a>
# </div>
# </div>
# <input id="userStatusInput" type="hidden" value="">
# <input id="articleKeywordsInput" type="hidden" value='[{"no":2573,"keywordNo":0,"keyword":"음식","keywordCount":0,"rank":0,"userId":"40Qx","articleNo":775,"sequence":1,"count":0,"type":"white","hideView":false,"hideEditor":false,"publishTimestamp":0},{"no":46451,"keywordNo":0,"keyword":"파전","keywordCount":0,"rank":0,"userId":"40Qx","articleNo":775,"sequence":2,"count":0,"type":"suggest","hideView":false,"hideEditor":false,"publishTimestamp":0},{"no":887,"keywordNo":0,"keyword":"날씨","keywordCount":0,"rank":0,"userId":"40Qx","articleNo":775,"sequence":3,"count":0,"type":"white","hideView":false,"hideEditor":false,"publishTimestamp":0}]'>
# <input id="articleStatusInput" type="hidden" value="publish">
# <input id="articleMagazineNoInput" type="hidden" value="24114">
# <input id="articleMagazineTypeInput" type="hidden" value="">
# <input id="commentWritableInput" type="hidden" value="true">
# <div id="layerDimEditorForPublishSideMenu">
# <div class="spinner"></div>
# </div>
# <div id="wrapPublishSideMenu">
# <div class="wrap_inner_publish wrap_save_btn wrap_btn_side_publish" id="wrapBtnSidePublish">
# <button class="cancel button" type="button">취소</button>
# <button class="save button mint" type="button">완료</button>
# </div>
# <div class="wrap_publish_magazine wrap_inner_publish">
# <div class="wrap_label_magazine"><h3 class="label_magazine_selection">매거진 선택</h3></div>
# <div class="wrap_publish_magazine_list" id="wrapPublishMagazineList"></div>
# </div>
# <div class="wrap_publish_keyword wrap_inner_publish">
# <div class="wrap_keyword_title">
# <span class="label_keyword_select">키워드 선택<span id="guideKeywordLayer"></span></span>
# <span class="wrap_keyword_count">
# <span class="wrap_count_selected_keyword" id="wrapCountSelectedKeyword">0</span>
# <span class="wrap_count_keyword_slash">/</span>
# <span class="wrap_count_keyword_total">3</span>
# </span>
# <span class="wrap_promotion_keyword_count">
# <span class="wrap_count_selected_keyword" id="wrapCountSelectedPromotionKeyword">0</span>
# </span>
# <button class="ico_publish_keyword" id="btnKeywordSearch" type="button">검색</button>
# <div id="wrapKeywordSearchSlide">
# <div class="wrap_inner_publish">
# <span id="wrapInputKeywordSearch">
# <span class="ico_publish_keyword ico_search_input"></span>
# <input id="inputKeywordSearch" placeholder="키워드를 입력해 주세요" type="text">
# </input></span>
# <span class="ico_publish_keyword ico_search_close" id="btnKeywordSearchClose"></span>
# <div class="wrap_keyword_search_list" id="wrapKeywordSearchList"></div>
# </div>
# </div>
# </div>
# <div class="wrap_keyword_selected" id="wrapKeywordSelected">
# <div class="inner_keyword_selected"></div>
# </div>
# </div>
# <div class="wrap_cmt_confirm">
# <h3 class="screen_out">댓글여부</h3>
# <div class="chk_editor">
# <label class="lab_g" for="cmtConfirm">댓글 쓰기 허용</label>
# <input class="inp_chk" id="cmtConfirm" type="checkbox"/>
# <span class="ico_publish_keyword_v1 ico_check_type1">afliean</span>
# </div>
# </div>
# </div>
# <script src="//developers.kakao.com/sdk/js/kakao.min.js?v=2" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.Message.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#         function BrunchConfigInit() {
#             B.Config = {"createMagazineConfirm":"로그인이 필요합니다.","downloadDomain":"t1.daumcdn.net","channelPublicId":"_YYcYV","KakaoTvIframeHost":"https://play-tv.kakao.com","brunchbookArticleMinCount":10,"serviceUrl":"https://brunch.co.kr","active":"real","isInnerNetwork":false,"kakaoJSKey":"7577e1f674fc3bc73963db5bf15e03df","facebookApiVersion":"v11.0","serviceDomain":"brunch.co.kr","webpackJsUrl":null,"templateUrl":"/template/","isCbtHome":false,"matrixFtDsn":"https://7092d1f177184e73a6cda1ee2d14ecc4@aem-collector.daumkakao.io/3057","webpackCssUrl":null,"apiUrl":"https://api.brunch.co.kr","servicecode":"7eF1DYRbLy8LCLcy","brunchbookArticleMaxCount":30,"thumbnailDomain":"img1.daumcdn.net","viteJsUrl":null};
#             B.User = {
#                             };
#         }
#         Guard.executeAndSaveFunction(BrunchConfigInit)
#     </script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/purify.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/tiaraEventHandler.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.Util.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.Login.min.js" type="text/javascript"></script>
# <div class="compatible-info">
# <em class="text_noti">브런치는 최신 브라우저에 최적화 되어있습니다.</em>
# <a class="ico_browser ico_ie text_hide" href="http://windows.microsoft.com/ko-kr/internet-explorer/download-ie" target="_blank">IE</a>
# <a class="ico_browser ico_chrome text_hide" href="http://www.google.co.kr/chrome/" target="_blank">chrome</a>
# <a class="ico_browser ico_safari text_hide" href="http://www.apple.com/kr/safari/" target="_blank">safari</a>
# </div>
# <script type="text/javascript">
#         try {
#                             if(B.UserAgent.isIE11Under) {
#                     jQuery('body').addClass('no-compatible');
#                 }
#                     } catch(e) {
#         }
#     </script>
# <script type="text/javascript">
#
#     function messageInit() {
#         try {
#             B.Message.init();
#         } catch (e) {
#             Sentry.setTag('InitFail', 'Message')
#             Sentry.captureMessage('[BRUNCH] InitFail')
#         }
#     }
#
#     (function() {
#         Guard.executeAndSaveFunction(messageInit);
#     })();
# </script>
# <script type="text/javascript">
#         function loginInit() {
#             try {
#                 // pc , mobile, tablet, unknown
#                 var isPcOrTablet = !B.UserAgent.isMobile;
#                                                         B.Login.init(isPcOrTablet, 'https%3A%2F%2Fbrunch.co.kr%2Fsignin%2Ffinish%3Furl%3D%252F%2540gorrajeju%252F775');
#                             } catch(e) {
#                 Sentry.setTag('InitFail', 'Login')
#                 Sentry.captureMessage('[BRUNCH] InitFail')
#             }
#         }
#         (function() {
#             Guard.executeAndSaveFunction(loginInit);
#         })();
#     </script>
# <script type="application/ld+json">
# {
#     "@context": "http://schema.org",
#     "@type": "Organization",
#     "name": "브런치스토리",
#     "url": "https://brunch.co.kr",
#     "sameAs": [
#         "https://play.google.com/store/apps/details?id=com.daumkakao.android.brunchapp",
#         "https://apps.apple.com/kr/app/id1001388574"
#     ]
# }
# </script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.PublishSideMenu.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.Report.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.Comment.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.SubscriptionLayer.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.Article.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.ArticleLike.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.PostMessage.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/comment-editor-1.0.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/jquery.autolink-1.0.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/intersection-observer.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.ReadHelper.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/B.Related.Article.min.js" type="text/javascript"></script>
# <script>
#     function commentInit() {
#
#             var article = {
#                 articleNo: '775',
#                 authorUserId: '40Qx',
#                 authorUserImage: 'http://t1.daumcdn.net/brunch/service/user/40Qx/image/YOkFN0oLKRq3HhRViu4kB0Wg9lg.png',
#                 authorUserName: '고르라제주',
#             }
#
#             var authUser = {};
#             var options = {};
#
#                                 authUser = {
#                         userId: '',
#                         userStatus: '',
#                         userImage: '',
#                         userName: '',
#                         userConnection: '',
#                                                     profileAuthority: false
#                                             },
#                             options = {
#                                             writeComment: true,
#                                                                 floatMention: true
#                                     }
#             B.Comment.init(article, authUser, options);
#             }
#
#     function readHelperInit() {
#         B.ReadHelper.init({
#             articleUserId: "40Qx",
#             articleNo: 775,
#             staticSeconds: 94
#         });
#     }
#
#     function readSecondsHelperInit() {
#         B.ReadSecondsHelper.init({
#             staticSeconds: 94
#         });
#     }
#
#     function ctrCheckerInit() {
#         B.ctrChecker = B.CtrChecker.init({
#             eventType: 'post_view',
#             eventReferrerType: 'post_referrer',
#             os: 'pc',
#             isChannel:  false ,
#             authorUserId: '40Qx'
#         });
#     }
#
#     function notMobileRelatedAritcleInit() {
#         B.Related.Article.init({
#             isMobile:false,
#             authorProfileId:'gorrajeju',
#             authorUserId: '40Qx',
#             userId: ''
#         }, B.ctrChecker);
#     }
#
#     function mobileRelatedArticleInit() {
#         B.Related.Article.init({
#             isMobile:true,
#             authorProfileId:'gorrajeju',
#             authorUserId: '40Qx',
#         }, B.ctrChecker);
#     }
#
#     function articleLikeInit() {
#         B.ArticleLike.init(
#                 {
#                     articleNo: '775',
#                     authorUserId: '40Qx'
#                 },
#                 {
#                     userId: '',
#                 },
#                 {
#                     isLike: false,
#                     isOwner: false
#                 }
#         );
#     }
#
#     function articleInit() {
#         B.Article.init(B.ctrChecker);
#     }
#
#     function mobileArticleInit() {
#         B.M.Article.init(B.ctrChecker);
#     }
#
#     function completeReadRateHelperInit() {
#         B.CompleteReadRateHelper.init({
#             articleUserId: "40Qx",
#             articleNo: 775,
#             isBrunchbook: "false"
#         });
#     }
#
#     function goToLastTopVisibleBlock() {
#         B.CompleteReadRateHelper.goToLastTopVisibleBlock("40Qx", 775);
#     }
#
#     (function() {
#         Guard.executeAndSaveFunction(commentInit);
#
#                     Guard.executeAndSaveFunction(readHelperInit);
#             Guard.executeAndSaveFunction(readSecondsHelperInit);
#             Guard.executeAndSaveFunction(ctrCheckerInit);
#                             Guard.executeAndSaveFunction(notMobileRelatedAritcleInit);
#
#         Guard.executeAndSaveFunction(articleLikeInit);
#
#                     Guard.executeAndSaveFunction(articleInit);
#
#
#             Guard.executeAndSaveFunction(completeReadRateHelperInit);
#
#                         })();
# </script>
# <script src="//t1.daumcdn.net/brunch/static/prod/202306211326/production/jennifer.min.js" type="text/javascript"></script>
# <script>
# 		try {
#
# 			extras['sv'] = B.Config.servicecode;
#
# 							extras["ci"] = '40Qx';
#
# 							extras["mi"] = '775';
#
# 							extras["bi"] = '24114';
#
#
# 			ja.pageview();
# 		} catch(e) {
# 			if (typeof Sentry !== 'undefined') {
# 				Sentry.setTag('InitFail', 'jennifer')
# 				Sentry.captureMessage('[BRUNCH] InitFail')
# 			}
# 		}
# 	</script>
# <script>
#         window.onload = function () {
#             if (!window.B || Guard.hasError) {
#                 try {
#                     Guard.restoreArticlePage(true);
#                 } catch(e) {
#                     Guard.matrixLogging(e, 'Article View Restore Fail')
#                 }
#             }
#         }
#     </script>
# </input></input></input></input></input></input></body>
# </html>

# %%
# soup객체로부터 원하는 부분 추출하기
test1 = soup.select('h1 > b')
test1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # soup객체로부터 원하는 부분 추출하기
# ----> 2 test1 = soup.select('script')
#       3 test1
#
# NameError: name 'soup' is not defined

# %%
h1 = []
h1_name = []
for item in test1:
    h1 += item.text.strip().split()
result1 = "".join(h1).replace("/", "").strip()
print(result1)
h1_name.append(result1[0:2])
h1_name.append(result1[2:5])
h1_name.append(result1[5:8])
h1_name.append(result1[8:12])
h1_name.append(result1[12:14])
h1_name.append(result1[14:])
print(h1_name)
# Out:
# 파전수제비삼겹살잔치국수라면곱창&막창
# ['파전', '수제비', '삼겹살', '잔치국수', '라면', '곱창&막창']

# %%
df = DataFrame(h1_name)
df.to_excel("result1.xlsx")
df
# Out:
#        0
# 0     파전
# 1    수제비
# 2    삼겹살
# 3   잔치국수
# 4     라면
# 5  곱창&막창

# %% [markdown]
# # 연습문제 02 풀이
#
# #### #01. 패키지 준비하기

# %%
import sys
sys.path.append('../../')
import helper

from pandas import read_excel, DataFrame
from matplotlib import pyplot as plt
import seaborn as sb
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# #### #02. 데이터셋 준비하기

# %%
origin = read_excel("https://data.hossam.kr/F03/pima-indians.xlsx")

print(origin.info())

origin.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# #### #03. 데이터 전처리
#
# 결측치 확인

# %%
origin.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# 명목형 변수 형변환

# %%
origin['Outcome'] = origin['Outcome'].astype('category')
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    category
# dtypes: category(1), float64(2), int64(6)
# memory usage: 49.0 KB

# %% [markdown]
# #### #04. 탐색적 데이터 분석
#
# 기본통계 확인

# %%
origin.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  768.000000                768.000000  768.000000
# mean    31.992578                  0.471876   33.240885
# std      7.884160                  0.331329   11.760232
# min      0.000000                  0.078000   21.000000
# 25%     27.300000                  0.243750   24.000000
# 50%     32.000000                  0.372500   29.000000
# 75%     36.600000                  0.626250   41.000000
# max     67.100000                  2.420000   81.000000

# %% [markdown]
# 상자그림

# %%
plt.figure(figsize=(20, 5))
sb.boxplot(data=origin)
plt.show()
plt.close()

# %% [markdown]
# > ###### 데이터 분포가 서로 상이하므로 표준화가 필요하다고 판단
#
# #### #05. 데이터셋 분할하기
#
# 랜덤시드 고정

# %%
np.random.seed(777)

# %% [markdown]
# 훈련 데이터(독립변수)와 레이블(종속변수) 구분하기

# %%
x = origin.drop('Outcome', axis=1)
y = origin[['Outcome']]
print(x.shape, y.shape)
y
# Out:
# (768, 8) (768, 1)
#     Outcome
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1
# ..      ...
# 763       0
# 764       0
# 765       0
# 766       1
# 767       0
#
# [768 rows x 1 columns]

# %% [markdown]
# 데이터 표준화

# %%
x_scaller = StandardScaler()
x_scale = x_scaller.fit_transform(x)
x_scale_df = DataFrame(x_scale, columns=x.columns, index=x.index)
x_scale_df.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.639947  0.848324       0.149641       0.907270 -0.692891  0.204013
# 1    -0.844885 -1.123396      -0.160546       0.530902 -0.692891 -0.684422
# 2     1.233880  1.943724      -0.263941      -1.288212 -0.692891 -1.103255
# 3    -0.844885 -0.998208      -0.160546       0.154533  0.123302 -0.494043
# 4    -1.141852  0.504055      -1.504687       0.907270  0.765836  1.409746
#
#    DiabetesPedigreeFunction       Age
# 0                  0.468492  1.425995
# 1                 -0.365061 -0.190672
# 2                  0.604397 -0.105584
# 3                 -0.920763 -1.041549
# 4                  5.484909 -0.020496

# %% [markdown]
# 훈련 데이터와 검증 데이터로 분할

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scale_df, y, test_size=0.3, random_state=777)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
x_train
# Out:
# (537, 8) (231, 8) (537, 1) (231, 1)
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 335    -1.141852  1.380375       0.356432       1.409094  1.521248  2.018958
# 130     0.046014  1.630752       0.046245      -0.410019  0.765836 -0.290972
# 255    -0.844885 -0.247076      -0.263941       0.907270 -0.692891  0.204013
# 573    -0.547919 -0.716533      -0.470732      -0.221835  0.349057  0.343624
# 764    -0.547919  0.034598       0.046245       0.405445 -0.692891  0.610154
# ..           ...       ...            ...            ...       ...       ...
# 669     1.530847  1.036107       0.459827       0.593630  0.175399 -0.138669
# 71      0.342981  0.566649      -0.263941       0.907270  0.522715 -0.430583
# 599    -0.844885 -0.372265      -1.608083      -0.159107  0.349057 -1.128639
# 571    -0.547919  0.284975       1.390387      -1.288212 -0.692891 -1.192099
# 103    -0.844885 -1.248585       0.149641      -0.159107 -0.345575 -0.684422
#
#      DiabetesPedigreeFunction       Age
# 335                 -0.642912 -0.616111
# 130                 -0.334860 -0.020496
# 255                  0.214802 -1.041549
# 573                 -0.827139 -0.956462
# 764                 -0.398282 -0.531023
# ..                        ...       ...
# 669                 -0.929823  1.000557
# 71                  -0.183854 -0.616111
# 599                 -0.195934 -0.616111
# 571                 -0.615731 -1.041549
# 103                 -0.570429 -0.786286
#
# [537 rows x 8 columns]

# %% [markdown]
# #### #06. 모델 개발
#
# 모델 정의

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(len(x_train.columns), )))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss = 'binary_crossentropy', metrics = ['acc'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                288
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 321 (1.25 KB)
# Trainable params: 321 (1.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# 학습하기

# %%
result = model.fit(x_train, y_train, epochs = 500, validation_data = (x_test, y_test), callbacks = [
    EarlyStopping(monitor = 'val_loss', patience=5, verbose = 1),
    ReduceLROnPlateau(monitor= "val_loss", patience=3, factor = 0.5, min_lr=0.0001, verbose=1)
])
# Out:
# Epoch 1/500
# 17/17 [==============================] - 1s 11ms/step - loss: 0.6856 - acc: 0.5624 - val_loss: 0.6321 - val_acc: 0.6797 - lr: 0.0010
# Epoch 2/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6387 - acc: 0.6890 - val_loss: 0.5978 - val_acc: 0.7403 - lr: 0.0010
# Epoch 3/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6074 - acc: 0.7151 - val_loss: 0.5714 - val_acc: 0.7489 - lr: 0.0010
# Epoch 4/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5813 - acc: 0.7374 - val_loss: 0.5490 - val_acc: 0.7749 - lr: 0.0010
# Epoch 5/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5598 - acc: 0.7393 - val_loss: 0.5318 - val_acc: 0.7706 - lr: 0.0010
# Epoch 6/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5418 - acc: 0.7430 - val_loss: 0.5176 - val_acc: 0.7792 - lr: 0.0010
# Epoch 7/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5266 - acc: 0.7505 - val_loss: 0.5062 - val_acc: 0.7922 - lr: 0.0010
# Epoch 8/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5140 - acc: 0.7635 - val_loss: 0.4970 - val_acc: 0.7922 - lr: 0.0010
# Epoch 9/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5030 - acc: 0.7691 - val_loss: 0.4898 - val_acc: 0.7835 - lr: 0.0010
# Epoch 10/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4939 - acc: 0.7672 - val_loss: 0.4838 - val_acc: 0.7835 - lr: 0.0010
# Epoch 11/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4863 - acc: 0.7672 - val_loss: 0.4794 - val_acc: 0.7835 - lr: 0.0010
# Epoch 12/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4794 - acc: 0.7728 - val_loss: 0.4761 - val_acc: 0.7792 - lr: 0.0010
# Epoch 13/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4737 - acc: 0.7747 - val_loss: 0.4739 - val_acc: 0.7792 - lr: 0.0010
# Epoch 14/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4687 - acc: 0.7803 - val_loss: 0.4719 - val_acc: 0.7835 - lr: 0.0010
# Epoch 15/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4643 - acc: 0.7821 - val_loss: 0.4710 - val_acc: 0.7835 - lr: 0.0010
# Epoch 16/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4604 - acc: 0.7821 - val_loss: 0.4691 - val_acc: 0.7835 - lr: 0.0010
# Epoch 17/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4576 - acc: 0.7803 - val_loss: 0.4681 - val_acc: 0.7835 - lr: 0.0010
# Epoch 18/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4545 - acc: 0.7877 - val_loss: 0.4676 - val_acc: 0.7835 - lr: 0.0010
# Epoch 19/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4518 - acc: 0.7858 - val_loss: 0.4675 - val_acc: 0.7879 - lr: 0.0010
# Epoch 20/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4498 - acc: 0.7858 - val_loss: 0.4673 - val_acc: 0.7879 - lr: 0.0010
# Epoch 21/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4475 - acc: 0.7858 - val_loss: 0.4678 - val_acc: 0.7835 - lr: 0.0010
# Epoch 22/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4461 - acc: 0.7858 - val_loss: 0.4680 - val_acc: 0.7792 - lr: 0.0010
# Epoch 23/500
#  1/17 [>.............................] - ETA: 0s - loss: 0.5038 - acc: 0.7500
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4442 - acc: 0.7877 - val_loss: 0.4674 - val_acc: 0.7792 - lr: 0.0010
# Epoch 24/500
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4419 - acc: 0.7840 - val_loss: 0.4674 - val_acc: 0.7792 - lr: 5.0000e-04
# Epoch 25/500
# 17/17 [==============================] - 0s 4ms/step - loss: 0.4413 - acc: 0.7840 - val_loss: 0.4676 - val_acc: 0.7792 - lr: 5.0000e-04
# Epoch 25: early stopping

# %% [markdown]
# #### #07. 학습결과 평가

# %%
helper.tf_result_plot(result)

evaluate1 = model.evaluate(x_train, y_train)
print("최종 훈련 손실률: %f, 최종 훈련 정확도: %f" % (evaluate1[0], evaluate1[1]))

evaluate2 = model.evaluate(x_test, y_test)
print("최종 검증 손실률: %f, 최종 검증 정확도: %f" % (evaluate2[0], evaluate2[1]))
# Out:
# 17/17 [==============================] - 0s 1ms/step - loss: 0.4398 - acc: 0.7840
# 최종 훈련 손실률: 0.439814, 최종 훈련 정확도: 0.783985
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4676 - acc: 0.7792
# 최종 검증 손실률: 0.467599, 최종 검증 정확도: 0.779221

# %% [markdown]
# #### #08. 학습 결과 적용
#
# 테스트 데이터에 대한 예측결과 산정

# %%
train_pred = model.predict(x_train)
data_count, case_count = train_pred.shape
print("%d개의 훈련 데이터가 %d개의 경우의 수를 갖는다." % (data_count, case_count))
print(train_pred)
# Out:
# 17/17 [==============================] - 0s 814us/step
# 537개의 훈련 데이터가 1개의 경우의 수를 갖는다.
# [[0.7058447 ]
#  [0.754179  ]
#  [0.1486324 ]
#  [0.09330074]
#  [0.31063786]
#  [0.04823772]
#  [0.20389089]
#  [0.37412158]
#  [0.62979615]
#  [0.23984581]
#  [0.4928594 ]
#  [0.32657897]
#  [0.42849112]
#  [0.00388205]
#  [0.64256966]
#  [0.50896376]
#  [0.09926425]
#  [0.5351521 ]
#  [0.06311706]
#  [0.11819077]
#  [0.0839058 ]
#  [0.20003904]
#  [0.399821  ]
#  [0.2697044 ]
#  [0.14154537]
#  [0.13877556]
#  [0.26155737]
#  [0.01144864]
#  [0.3758011 ]
#  [0.04753971]
#  [0.18399316]
#  [0.15693665]
#  [0.15220557]
#  [0.5952579 ]
#  [0.7946587 ]
#  [0.63767034]
#  [0.04201459]
#  [0.2895148 ]
#  [0.54942364]
#  [0.16428041]
#  [0.2755885 ]
#  [0.14240636]
#  [0.02827484]
#  [0.3257764 ]
#  [0.03297186]
#  [0.46257147]
#  [0.6047003 ]
#  [0.6962614 ]
#  [0.11681126]
#  [0.46409434]
#  [0.04804928]
#  [0.02715344]
#  [0.18658042]
#  [0.5661127 ]
#  [0.20509405]
#  [0.8015006 ]
#  [0.1534738 ]
#  [0.77805024]
#  [0.31798452]
#  [0.32627907]
#  [0.08351568]
#  [0.89112586]
#  [0.18384582]
#  [0.77011824]
#  [0.11934034]
#  [0.54273856]
#  [0.86248386]
#  [0.61743903]
#  [0.95117897]
#  [0.24477763]
#  [0.49541745]
#  [0.33778876]
#  [0.6637424 ]
#  [0.15086094]
#  [0.64464176]
#  [0.01501146]
#  [0.6245857 ]
#  [0.9616063 ]
#  [0.05385296]
#  [0.8822455 ]
#  [0.04091141]
#  [0.29785103]
#  [0.21392147]
#  [0.7905488 ]
#  [0.23800181]
#  [0.522758  ]
#  [0.5124049 ]
#  [0.5330341 ]
#  [0.81984067]
#  [0.49599457]
#  [0.58183765]
#  [0.16141547]
#  [0.5475268 ]
#  [0.11440226]
#  [0.00791536]
#  [0.03896499]
#  [0.05105498]
#  [0.22888531]
#  [0.03853748]
#  [0.91096264]
#  [0.21864155]
#  [0.17634344]
#  [0.6512497 ]
#  [0.28220588]
#  [0.8394917 ]
#  [0.12832415]
#  [0.4200431 ]
#  [0.86697215]
#  [0.23050389]
#  [0.32792363]
#  [0.742748  ]
#  [0.11541672]
#  [0.60707223]
#  [0.34361085]
#  [0.39882886]
#  [0.12782486]
#  [0.87654227]
#  [0.18543293]
#  [0.62029153]
#  [0.5232811 ]
#  [0.4208902 ]
#  [0.1011784 ]
#  [0.86615187]
#  [0.55305624]
#  [0.38027006]
#  [0.2125755 ]
#  [0.13325506]
#  [0.07073142]
#  [0.13597797]
#  [0.2058427 ]
#  [0.04564755]
#  [0.23822425]
#  [0.50816154]
#  [0.05534682]
#  [0.12630785]
#  [0.5443801 ]
#  [0.19259909]
#  [0.36248055]
#  [0.47948328]
#  [0.2889632 ]
#  [0.06686954]
#  [0.2868958 ]
#  [0.08404016]
#  [0.71142304]
#  [0.35612863]
#  [0.08590358]
#  [0.23236173]
#  [0.16733126]
#  [0.0431405 ]
#  [0.7892068 ]
#  [0.92240244]
#  [0.6830414 ]
#  [0.06745981]
#  [0.1302497 ]
#  [0.2379543 ]
#  [0.03295339]
#  [0.11295059]
#  [0.14985825]
#  [0.01349051]
#  [0.02786793]
#  [0.71519494]
#  [0.04220994]
#  [0.409121  ]
#  [0.21135044]
#  [0.14043477]
#  [0.24239759]
#  [0.13971984]
#  [0.02592955]
#  [0.59607685]
#  [0.65401685]
#  [0.83044344]
#  [0.03290732]
#  [0.17301849]
#  [0.9411764 ]
#  [0.35864908]
#  [0.03362997]
#  [0.07383289]
#  [0.8332193 ]
#  [0.06502208]
#  [0.30604678]
#  [0.3211628 ]
#  [0.3416157 ]
#  [0.168696  ]
#  [0.5371521 ]
#  [0.9730313 ]
#  [0.59117925]
#  [0.607633  ]
#  [0.30286422]
#  [0.05107776]
#  [0.39756092]
#  [0.11891665]
#  [0.03804522]
#  [0.19301821]
#  [0.82473457]
#  [0.2645242 ]
#  [0.91867346]
#  [0.10118806]
#  [0.07810767]
#  [0.05288623]
#  [0.075332  ]
#  [0.27513605]
#  [0.11223741]
#  [0.15304989]
#  [0.875267  ]
#  [0.6345239 ]
#  [0.34147248]
#  [0.09771628]
#  [0.82408553]
#  [0.22484584]
#  [0.28180557]
#  [0.87607574]
#  [0.16380252]
#  [0.28793103]
#  [0.1744606 ]
#  [0.84150356]
#  [0.2951379 ]
#  [0.8073711 ]
#  [0.3274939 ]
#  [0.17144865]
#  [0.20254564]
#  [0.07605951]
#  [0.53864586]
#  [0.7715966 ]
#  [0.14492474]
#  [0.82749206]
#  [0.5966575 ]
#  [0.7619016 ]
#  [0.76757765]
#  [0.05907386]
#  [0.0947101 ]
#  [0.46332484]
#  [0.21598488]
#  [0.15781166]
#  [0.11656342]
#  [0.8752015 ]
#  [0.28013256]
#  [0.36237878]
#  [0.79282737]
#  [0.7458473 ]
#  [0.8809656 ]
#  [0.1565228 ]
#  [0.12547798]
#  [0.6798636 ]
#  [0.78593934]
#  [0.8493402 ]
#  [0.89875185]
#  [0.01852871]
#  [0.19213668]
#  [0.13073881]
#  [0.9368755 ]
#  [0.7883861 ]
#  [0.3846677 ]
#  [0.8456673 ]
#  [0.4831467 ]
#  [0.11639335]
#  [0.3009985 ]
#  [0.7397605 ]
#  [0.5123232 ]
#  [0.28666767]
#  [0.32695243]
#  [0.27418134]
#  [0.02082166]
#  [0.3728474 ]
#  [0.6017368 ]
#  [0.09680353]
#  [0.13280585]
#  [0.20801073]
#  [0.08135468]
#  [0.28681248]
#  [0.8725464 ]
#  [0.3109606 ]
#  [0.03642839]
#  [0.08397365]
#  [0.7662258 ]
#  [0.17249107]
#  [0.10192046]
#  [0.15199365]
#  [0.31347924]
#  [0.8636908 ]
#  [0.47727776]
#  [0.5533688 ]
#  [0.02814542]
#  [0.02399789]
#  [0.0299529 ]
#  [0.00528606]
#  [0.4282701 ]
#  [0.03429853]
#  [0.01015899]
#  [0.6411476 ]
#  [0.03930061]
#  [0.11797681]
#  [0.03434659]
#  [0.4345571 ]
#  [0.86935   ]
#  [0.3533202 ]
#  [0.14295757]
#  [0.40832007]
#  [0.4789573 ]
#  [0.20328295]
#  [0.7060369 ]
#  [0.1472275 ]
#  [0.4429365 ]
#  [0.43904722]
#  [0.37072054]
#  [0.97686696]
#  [0.42857996]
#  [0.65973175]
#  [0.18841888]
#  [0.78198785]
#  [0.5965626 ]
#  [0.21120438]
#  [0.27657336]
#  [0.14170627]
#  [0.23699257]
#  [0.10791855]
#  [0.9139465 ]
#  [0.25273088]
#  [0.5069395 ]
#  [0.0324978 ]
#  [0.06181398]
#  [0.04271633]
#  [0.6060665 ]
#  [0.1580094 ]
#  [0.09630869]
#  [0.43567303]
#  [0.21547176]
#  [0.03074567]
#  [0.2316516 ]
#  [0.02823193]
#  [0.25879836]
#  [0.8248875 ]
#  [0.01218574]
#  [0.59747946]
#  [0.96318144]
#  [0.1795393 ]
#  [0.4634383 ]
#  [0.6997599 ]
#  [0.02155686]
#  [0.7913337 ]
#  [0.11120924]
#  [0.3785136 ]
#  [0.4522265 ]
#  [0.5501646 ]
#  [0.08972657]
#  [0.20021951]
#  [0.08376253]
#  [0.96834433]
#  [0.03072016]
#  [0.53278744]
#  [0.6936029 ]
#  [0.09610248]
#  [0.06847407]
#  [0.80654186]
#  [0.88445693]
#  [0.28425086]
#  [0.17340112]
#  [0.03557219]
#  [0.10111986]
#  [0.12075998]
#  [0.34172174]
#  [0.7279729 ]
#  [0.25192028]
#  [0.02099298]
#  [0.16877064]
#  [0.73455596]
#  [0.0798615 ]
#  [0.20669815]
#  [0.46137482]
#  [0.17761396]
#  [0.34826225]
#  [0.15338928]
#  [0.26016814]
#  [0.31087458]
#  [0.17515749]
#  [0.07744949]
#  [0.3587548 ]
#  [0.9097663 ]
#  [0.19595365]
#  [0.4788164 ]
#  [0.91505253]
#  [0.7001778 ]
#  [0.7807798 ]
#  [0.0989565 ]
#  [0.35640398]
#  [0.5222908 ]
#  [0.6003008 ]
#  [0.0221619 ]
#  [0.0029398 ]
#  [0.38419282]
#  [0.03026085]
#  [0.6345318 ]
#  [0.38064948]
#  [0.0467397 ]
#  [0.8851083 ]
#  [0.43396848]
#  [0.08412582]
#  [0.07079139]
#  [0.3660237 ]
#  [0.02096242]
#  [0.6269856 ]
#  [0.67774594]
#  [0.37048876]
#  [0.503499  ]
#  [0.56173193]
#  [0.80512816]
#  [0.07124954]
#  [0.51585376]
#  [0.29531667]
#  [0.02345067]
#  [0.18509099]
#  [0.43229797]
#  [0.6988791 ]
#  [0.26705113]
#  [0.21494476]
#  [0.20127061]
#  [0.05007299]
#  [0.11287596]
#  [0.7933513 ]
#  [0.8658613 ]
#  [0.8783166 ]
#  [0.14363013]
#  [0.53971195]
#  [0.4435492 ]
#  [0.47444722]
#  [0.38339755]
#  [0.83937025]
#  [0.48395035]
#  [0.2473417 ]
#  [0.5509179 ]
#  [0.59753543]
#  [0.44851264]
#  [0.7210669 ]
#  [0.04359568]
#  [0.19218759]
#  [0.15492429]
#  [0.50281644]
#  [0.68475854]
#  [0.87663597]
#  [0.11971366]
#  [0.2887579 ]
#  [0.09967554]
#  [0.35845193]
#  [0.77316403]
#  [0.07795992]
#  [0.49055174]
#  [0.5428708 ]
#  [0.0063196 ]
#  [0.93600285]
#  [0.5545437 ]
#  [0.50740325]
#  [0.39764372]
#  [0.43839914]
#  [0.30177513]
#  [0.7066607 ]
#  [0.27434692]
#  [0.05919584]
#  [0.38707083]
#  [0.67285436]
#  [0.39320087]
#  [0.77259725]
#  [0.717321  ]
#  [0.44986302]
#  [0.7712231 ]
#  [0.34584767]
#  [0.4367796 ]
#  [0.0288892 ]
#  [0.03535638]
#  [0.05559927]
#  [0.2374258 ]
#  [0.14790237]
#  [0.105356  ]
#  [0.42273363]
#  [0.414507  ]
#  [0.20855656]
#  [0.45537123]
#  [0.3537149 ]
#  [0.52448803]
#  [0.4413    ]
#  [0.6889504 ]
#  [0.8662987 ]
#  [0.11780004]
#  [0.08240921]
#  [0.11719911]
#  [0.45529073]
#  [0.5283521 ]
#  [0.0773655 ]
#  [0.67273504]
#  [0.921307  ]
#  [0.26612234]
#  [0.03029878]
#  [0.2153985 ]
#  [0.03631583]
#  [0.6241795 ]
#  [0.31399387]
#  [0.8898383 ]
#  [0.35144195]
#  [0.69854724]
#  [0.08184544]
#  [0.05662908]
#  [0.07780612]
#  [0.09700217]
#  [0.62891334]
#  [0.19657601]
#  [0.8925039 ]
#  [0.70983726]
#  [0.49475673]
#  [0.49160522]
#  [0.81497085]
#  [0.09366398]
#  [0.00771966]
#  [0.1424776 ]
#  [0.15422808]
#  [0.39951113]
#  [0.31191128]
#  [0.24575391]
#  [0.08598299]
#  [0.04106635]
#  [0.05445356]
#  [0.6446825 ]
#  [0.08331975]
#  [0.40550482]
#  [0.2458747 ]
#  [0.12577982]
#  [0.11517795]
#  [0.03868409]
#  [0.0797863 ]
#  [0.14366454]
#  [0.7877576 ]
#  [0.7817259 ]
#  [0.12114934]
#  [0.43453795]
#  [0.02557402]
#  [0.60708255]
#  [0.37805998]
#  [0.10078064]
#  [0.05044749]
#  [0.02775819]]

# %%
train_df = DataFrame({
    '관측치': y_train['Outcome'],
    '예측치': np.round(train_pred.flatten())
})

train_df
# Out:
#     관측치  예측치
# 335   0  1.0
# 130   1  1.0
# 255   1  0.0
# 573   0  0.0
# 764   0  0.0
# ..   ..  ...
# 669   0  1.0
# 71    0  0.0
# 599   0  0.0
# 571   0  0.0
# 103   0  0.0
#
# [537 rows x 2 columns]

# %% [markdown]
# 검증 데이터에 대한 예측 결과 산정

# %%
test_pred = model.predict(x_test)
data_count, case_count = test_pred.shape
print("%d개의 검증 데이터가 %d개의 경우의 수를 갖는다." % (data_count, case_count))
print(test_pred)
# Out:
# 8/8 [==============================] - 0s 1ms/step
# 231개의 검증 데이터가 1개의 경우의 수를 갖는다.
# [[0.41951242]
#  [0.92018723]
#  [0.90500915]
#  [0.19200411]
#  [0.24186972]
#  [0.7077427 ]
#  [0.50364137]
#  [0.09934887]
#  [0.955943  ]
#  [0.14695302]
#  [0.06708139]
#  [0.14813451]
#  [0.03310102]
#  [0.08964204]
#  [0.24954814]
#  [0.07848303]
#  [0.0954599 ]
#  [0.29310524]
#  [0.7637799 ]
#  [0.13485146]
#  [0.09368978]
#  [0.43289566]
#  [0.8892959 ]
#  [0.78944933]
#  [0.20306616]
#  [0.17865016]
#  [0.08616752]
#  [0.6228028 ]
#  [0.06993554]
#  [0.54820967]
#  [0.09892272]
#  [0.12310946]
#  [0.14962125]
#  [0.04013661]
#  [0.22842258]
#  [0.0425369 ]
#  [0.16527231]
#  [0.18913539]
#  [0.7737925 ]
#  [0.01445663]
#  [0.12348018]
#  [0.25599253]
#  [0.07117998]
#  [0.84531844]
#  [0.63700503]
#  [0.02512119]
#  [0.12764858]
#  [0.12738444]
#  [0.05777382]
#  [0.09890535]
#  [0.74516207]
#  [0.07058229]
#  [0.03380574]
#  [0.37521526]
#  [0.23978005]
#  [0.10274867]
#  [0.07009523]
#  [0.9268118 ]
#  [0.49252903]
#  [0.7177234 ]
#  [0.3128572 ]
#  [0.77023005]
#  [0.88525087]
#  [0.7771031 ]
#  [0.35585582]
#  [0.07569833]
#  [0.03840376]
#  [0.12253217]
#  [0.0024919 ]
#  [0.15336762]
#  [0.54534703]
#  [0.19034788]
#  [0.14525978]
#  [0.6588635 ]
#  [0.2100201 ]
#  [0.6209976 ]
#  [0.7045266 ]
#  [0.02983979]
#  [0.4342705 ]
#  [0.04300292]
#  [0.12252062]
#  [0.142033  ]
#  [0.24522793]
#  [0.680086  ]
#  [0.8116409 ]
#  [0.0302706 ]
#  [0.7332572 ]
#  [0.32616392]
#  [0.3160771 ]
#  [0.7857697 ]
#  [0.11514043]
#  [0.44004133]
#  [0.8645106 ]
#  [0.383228  ]
#  [0.41004345]
#  [0.21052085]
#  [0.3648532 ]
#  [0.18218139]
#  [0.23977311]
#  [0.17444703]
#  [0.3208144 ]
#  [0.04699318]
#  [0.06823196]
#  [0.92574096]
#  [0.07106269]
#  [0.67271507]
#  [0.80870545]
#  [0.19777095]
#  [0.39747295]
#  [0.48004937]
#  [0.0476225 ]
#  [0.31269747]
#  [0.28663057]
#  [0.33042645]
#  [0.5710237 ]
#  [0.43224913]
#  [0.14461932]
#  [0.8754093 ]
#  [0.7467892 ]
#  [0.7344595 ]
#  [0.392229  ]
#  [0.1825483 ]
#  [0.5261098 ]
#  [0.06034696]
#  [0.6406597 ]
#  [0.99443424]
#  [0.48158714]
#  [0.03992688]
#  [0.153853  ]
#  [0.30060592]
#  [0.2550673 ]
#  [0.49201545]
#  [0.13768612]
#  [0.1292135 ]
#  [0.25040537]
#  [0.12406265]
#  [0.8367401 ]
#  [0.06755674]
#  [0.26160398]
#  [0.8463848 ]
#  [0.11352096]
#  [0.27832448]
#  [0.16670136]
#  [0.04381204]
#  [0.841696  ]
#  [0.7712764 ]
#  [0.9389463 ]
#  [0.08578353]
#  [0.49412924]
#  [0.41902855]
#  [0.06221001]
#  [0.6809619 ]
#  [0.0780984 ]
#  [0.4877196 ]
#  [0.19558   ]
#  [0.896428  ]
#  [0.10536587]
#  [0.8731625 ]
#  [0.05106103]
#  [0.4205624 ]
#  [0.04484953]
#  [0.05758705]
#  [0.32949266]
#  [0.116947  ]
#  [0.3133638 ]
#  [0.05919777]
#  [0.9297293 ]
#  [0.23488235]
#  [0.9184378 ]
#  [0.0975301 ]
#  [0.15546264]
#  [0.04361909]
#  [0.15742476]
#  [0.22619769]
#  [0.15447523]
#  [0.9292326 ]
#  [0.01095418]
#  [0.09018741]
#  [0.20648898]
#  [0.5437504 ]
#  [0.06075398]
#  [0.5161456 ]
#  [0.3376124 ]
#  [0.10043981]
#  [0.52332824]
#  [0.05387035]
#  [0.11500625]
#  [0.126839  ]
#  [0.2858533 ]
#  [0.1927544 ]
#  [0.22790627]
#  [0.37778172]
#  [0.14258465]
#  [0.7893614 ]
#  [0.18070313]
#  [0.11495673]
#  [0.2582407 ]
#  [0.28191182]
#  [0.32461545]
#  [0.3598021 ]
#  [0.32986367]
#  [0.06479768]
#  [0.9019997 ]
#  [0.29182187]
#  [0.94295007]
#  [0.07088274]
#  [0.3185849 ]
#  [0.20058909]
#  [0.31544748]
#  [0.16076486]
#  [0.41921163]
#  [0.05307664]
#  [0.23970798]
#  [0.49413416]
#  [0.01704559]
#  [0.29278854]
#  [0.81750375]
#  [0.18350033]
#  [0.4559834 ]
#  [0.11731043]
#  [0.14141658]
#  [0.7320026 ]
#  [0.9631975 ]
#  [0.6456681 ]
#  [0.08187189]
#  [0.0957934 ]
#  [0.52239966]
#  [0.03461381]
#  [0.01857934]
#  [0.11771883]
#  [0.7344909 ]]

# %% [markdown]
# 결과 데이터 셋 구성

# %%
test_df = DataFrame({
    '관측치': y_test['Outcome'],
    '예측치': np.round(test_pred.flatten())
})

test_df
# Out:
#     관측치  예측치
# 387   1  0.0
# 43    1  1.0
# 408   1  1.0
# 262   0  0.0
# 533   0  0.0
# ..   ..  ...
# 46    0  1.0
# 290   0  0.0
# 418   0  0.0
# 434   0  0.0
# 267   0  1.0
#
# [231 rows x 2 columns]

# %% [markdown]
# 결과확인

# %%
logit = helper.tf_logit_result(model, result, x_train, y_train)
logit
# Out:
# 17/17 [==============================] - 0s 875us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                288
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 321 (1.25 KB)
# Trainable params: 321 (1.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
logit.cmdf
# Out:
#        Negative  Positive
# True        297        72
# False        44       124

# %%
logit.result_df.T
# Out:
#                               0
# 정확도(Accuracy)          0.783985
# 정밀도(Precision)         0.738095
# 재현율(Recall, TPR)       0.632653
# 위양성율(Fallout, FPR)     0.129032
# 특이성(Specificity, TNR)  0.870968
# RAS                    0.751810
# f1_score               0.681319

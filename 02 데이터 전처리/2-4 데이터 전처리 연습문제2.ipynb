# %%
from pandas import DataFrame

# %%
### 풀이 1) 리스트를 원소를 갖는 딕셔너리 활용
# 딕셔너리의 key가 컬럼이름이 된다.

# %%
data = {"class":["A1","A1","A1","A1","A1"
                 "A2","A2","A2","A2","A2","A2"
                 'A3','A3','A3','A3','A3','A3','A3'
                 'A4','A4','A4','A4','A4','A4','A4'],
        "time":[60,52,63,59,61,
                62,67,71,64,65,66,
                68,66,71,67,68,69,70,
                58,62,60,59,61,63,64]
}
df = DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 10
#       1 data = {"class":["A1","A1","A1","A1","A1"
#       2                  "A2","A2","A2","A2","A2","A2"
#       3                  'A3','A3','A3','A3','A3','A3','A3'
#    (...)
#       8                 58,62,60,59,61,63,64]
#       9 }
# ---> 10 df = DataFrame(data)
#      11 df
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
# ...

# %%
### 풀이 2) 딕셔너리를 원소를 갖는 리스트 활용

# %%
data = [
    {"class": "A1", "time":62},
    {"class": "A1", "time":60},
    {"class": "A1", "time":63},
    {"class": "A1", "time":59},
    {"class": "A1", "time":61},
    {"class": "A2", "time":62},
    {"class": "A2", "time":67},
    {"class": "A2", "time":71},
    {"class": "A2", "time":64},
    {"class": "A2", "time":65},
    {"class": "A2", "time":66},
    {"class": "A3", "time":68},
    {"class": "A3", "time":66},
    {"class": "A3", "time":71},
    {"class": "A3", "time":67},
    {"class": "A3", "time":68},
    {"class": "A3", "time":69},
    {"class": "A3", "time":70},
    {"class": "A4", "time":58},
    {"class": "A4", "time":62},
    {"class": "A4", "time":60},
    {"class": "A4", "time":59},
    {"class": "A4", "time":61},
    {"class": "A4", "time":63},
    {"class": "A4", "time":64},
]
df = DataFrame(data)
df
# Out:
#    class  time
# 0     A1    62
# 1     A1    60
# 2     A1    63
# 3     A1    59
# 4     A1    61
# 5     A2    62
# 6     A2    67
# 7     A2    71
# 8     A2    64
# 9     A2    65
# 10    A2    66
# 11    A3    68
# 12    A3    66
# 13    A3    71
# 14    A3    67
# 15    A3    68
# 16    A3    69
# 17    A3    70
# 18    A4    58
# 19    A4    62
# 20    A4    60
# 21    A4    59
# 22    A4    61
# 23    A4    63
# 24    A4    64

# %%
# 생성된 데이터 프레임에 대한 각 변수의 데이터 타입확인

# %%
df.dtypes
# Out:
# class    object
# time      int64
# dtype: object

# %%
df2 = df.astype({'class': 'category'})
df2.dtypes
# Out:
# class    category
# time        int64
# dtype: object

# %%
df['class'] = df['class'].astype('category')
df.dtypes
# Out:
# class    category
# time        int64
# dtype: object

# %%
# 서열척도로 변경해야 하는경우

# %%
from pandas import CategoricalDtype
df['class'] = df['class'].astype(CategoricalDtype(categories=['A1','A2','A3','A4'], ordered=True))
df.dtypes
# Out:
# class    category
# time        int64
# dtype: object

# %%
## 문제2

# %%
df1 = DataFrame([
    {"ID":25, 'READ':350, "MATH":425, "GRADE" :7},
    {"ID":25, 'READ':350, "MATH":425, "GRADE" :7},
    {"ID":25, 'READ':350, "MATH":425, "GRADE" :7},
    {"ID":25, 'READ':350, "MATH":425, "GRADE" :7}
])
df1
# Out:
#    ID  READ  MATH  GRADE
# 0  25   350   425      7
# 1  25   350   425      7
# 2  25   350   425      7
# 3  25   350   425      7

# %%
df2 = DataFrame([
    {"ID":20, 'READ':350, "MATH":425, "GRADE" :7},
    {"ID":33, 'READ':350, "MATH":425, "GRADE" :9},
    {"ID":37, 'READ':300, "MATH":325, "GRADE" :9},
])
df2
# Out:
#    ID  READ  MATH  GRADE
# 0  20   350   425      7
# 1  33   350   425      9
# 2  37   300   325      9

# %%
from pandas import concat

# %%
df = concat([df1, df2], ignore_index=True)
df
# Out:
#    ID  READ  MATH  GRADE
# 0  25   350   425      7
# 1  25   350   425      7
# 2  25   350   425      7
# 3  25   350   425      7
# 4  20   350   425      7
# 5  33   350   425      9
# 6  37   300   325      9

# %%
## 문제 3

# %%
from pandas import read_excel, pivot_table

# %%
df = read_excel("https://data.hossam.kr/test/q3.xlsx")
df
# Out:
#     지역  구성   흡연율
# 0   도시   남  0.64
# 1   도시   여  0.45
# 2   농촌  공학  0.70
# 3   도시   남  0.85
# 4   농촌   남  0.72
# 5   도시   남  0.78
# 6   도시   여  0.62
# 7   도시   남  0.79
# 8   농촌   남  0.75
# 9   농촌  공학  0.81
# 10  농촌   여  0.56
# 11  도시   여  0.48
# 12  농촌   남  0.72
# 13  도시  공학  0.68
# 14  농촌   남  0.79
# 15  도시   남  0.90
# 16  농촌   여  0.34
# 17  도시   여  0.48
# 18  농촌   여  0.49
# 19  농촌  공학  0.76

# %%
pivot_table(df, 
            index="구성",
            columns="지역",
            values="흡연율",
            aggfunc="mean")
# Out:
# 지역        농촌      도시
# 구성
# 공학  0.756667  0.6800
# 남   0.745000  0.7920
# 여   0.463333  0.5075

# %%
## 문제4

# %%
df = read_excel("https://data.hossam.kr/test/q4.xlsx")
df
# Out:
#     학생ID 성별  메모종류
# 0      1  남     3
# 1      2  여     2
# 2      3  여     2
# 3      4  여     1
# 4      5  여     2
# 5      6  여     3
# 6      7  남     2
# 7      8  여     2
# 8      9  여     1
# 9     10  남     1
# 10    11  남     2
# 11    12  남     3
# 12    13  남     2
# 13    14  남     1
# 14    15  남     2
# 15    16  여     2
# 16    17  여     1
# 17    18  여     2
# 18    19  여     3
# 19    20  여     2
# 20    21  여     2
# 21    22  여     2
# 22    23  여     2
# 23    24  여     2
# 24    25  여     2
# 25    26  여     2
# 26    27  여     2
# 27    28  여     2
# 28    29  여     1
# 29    30  여     2

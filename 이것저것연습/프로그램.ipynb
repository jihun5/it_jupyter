# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
# %matplotlib inline
from pandas import read_excel

# %%
train_data = pd.read_excel('프로그램.xlsx')
train_data.head()
# Out:
#    Unnamed: 0      프로그램명    유형  \
# 0         NaN      직장인요가  생활체육
# 1         NaN       밴드체조  생활체육
# 2         NaN       탁구교실  생활체육
# 3         NaN  스마트폰 사진편집  IT관련
# 4         NaN   명상과 스트레칭  생활체육
#
#                                                   내용  강좌개설정보   구청
# 0  바쁜 일상 속 신체 벨런스가 무너진 직장인을 위한 몸의 바른 정렬을 중시, 정확한 ...       1  관악구
# 1  밴드를 이용하여 진행하는 체조, 강사님을 따라하는 체조로 밴드에 가하는 힘에 의하여...       0  관악구
# 2  직사각형 나무 탁자에 네트를 걸고 양 사이드에 선수들이 서서 탁구채로 속이 빈 작은...       0  관악구
# 3  스마트폰 갤러리에 있는 사진으로 나만의 사진 편집하기, 라인 카메라 시작하기, 갤러...       1  관악구
# 4  고요히 눈을 감고 차분한 마음으로 깊이 생각하는 것이다. 명상은 일체의 '잡생각'을...       0  관악구

# %%
print("전체 학습 데이터의 개수: {}".format(len(train_data)))
# Out:
# 전체 학습 데이터의 개수: 1079

# %%
train_length = train_data['내용'].astype(str).apply(len)
train_length.head()
# Out:
# 0     88
# 1    123
# 2    215
# 3     95
# 4    112
# Name: 내용, dtype: int64

# %%
# 전체 데이터에 대해 길이에 대한 히스토그램을 그린다.
plt.figure(figsize=(12,5))
plt.hist(train_length, bins=200, alpha=0.5, color='r', label='word')
plt.yscale('log', nonpositive='clip')
plt.title('log-hist of length of review')
plt.xlabel('Length of review')
plt.ylabel('Number of review')
# Out:
# Text(0, 0.5, 'Number of review')

# %%
import numpy as np
print("문장 최대 길이 :{}".format(np.max(train_length)))
print("문장 최소 길이 :{}".format(np.min(train_length)))
print("문장 평균 길이 :{:.2f}".format(np.mean(train_length)))
print("문장 길이 표준편차 : {:.2f}".format(np.std(train_length)))
print("문장 중간 길이: {}".format(np.median(train_length)))
print('제1사분위 길이:{}'.format(np.percentile(train_length, 25)))
print('제3사분위 길이:{}'.format(np.percentile(train_length, 75)))
# Out:
# 문장 최대 길이 :373
# 문장 최소 길이 :14
# 문장 평균 길이 :112.37
# 문장 길이 표준편차 : 41.16
# 문장 중간 길이: 109.0
# 제1사분위 길이:88.0
# 제3사분위 길이:130.0

# %%
plt.figure(figsize=(12,5))
plt.boxplot(train_length, labels=['counts'], showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x218942ae940>,
#   <matplotlib.lines.Line2D at 0x218942aebe0>],
#  'caps': [<matplotlib.lines.Line2D at 0x218942aee80>,
#   <matplotlib.lines.Line2D at 0x218942bf160>],
#  'boxes': [<matplotlib.lines.Line2D at 0x218942ae6a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x218942bf400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x218942bf940>],
#  'means': [<matplotlib.lines.Line2D at 0x218942bf6a0>]}

# %%
# 문자열이 아닌 데이터는 모두 제거한다. 
train_review = [review for review in train_data['내용'] if type(review) is str]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = "Malgun Gothic"

# WordCloud 객체 생성
wordcloud = WordCloud().generate(' '.join(train_review))

# WordCloud를 이미지로 표시
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
fig, axe = plt.subplots(ncols=1)
fig.set_size_inches(6,3)
sns.countplot(train_data['강좌개설정보'])
# Out:
# <Axes: ylabel='count'>

# %%
# 각 문장의 단어 수를 확인해보자
train_word_counts = train_data['내용'].astype(str).apply(lambda x : len(x.split(' ')))
plt.figure(figsize=(15,10))
plt.hist(train_word_counts, bins=50, facecolor='r', label='train')
plt.title('log-hist of word count in review', fontsize=15)
plt.yscale('log', nonpositive='clip')
plt.legend()
plt.xlabel('Number of words', fontsize=15)
plt.ylabel('Number of reviews', fontsize=15)
# Out:
# Text(0, 0.5, 'Number of reviews')

# %%
print("문장 최대 길이 :{}".format(np.max(train_word_counts)))
print("문장 최소 길이 :{}".format(np.min(train_word_counts)))
print("문장 평균 길이 :{:.2f}".format(np.mean(train_word_counts)))
print("문장 길이 표준편차 : {:.2f}".format(np.std(train_word_counts)))
print("문장 중간 길이: {}".format(np.median(train_word_counts)))
print('제1사분위 길이:{}'.format(np.percentile(train_word_counts, 25)))
print('제3사분위 길이:{}'.format(np.percentile(train_word_counts, 75)))
# Out:
# 문장 최대 길이 :89
# 문장 최소 길이 :3
# 문장 평균 길이 :27.77
# 문장 길이 표준편차 : 10.10
# 문장 중간 길이: 27.0
# 제1사분위 길이:22.0
# 제3사분위 길이:32.0

# %%
train_word_counts
# Out:
# 0       24
# 1       30
# 2       57
# 3       21
# 4       26
#         ..
# 1074    15
# 1075    31
# 1076    37
# 1077    20
# 1078    11
# Name: 내용, Length: 1079, dtype: int64

# %%
# 각 단어에 대해 특수문자 유무를 확인 특별한 특수문자는 없으므로 마침표 물음표 확인
qmarks = np.mean(train_data['내용'].astype(str).apply(lambda x : "?" in x)) # 물음표가 구두점으로 쓰임
fullstop = np.mean(train_data['내용'].astype(str).apply(lambda x : "." in x))
reststop = np.mean(train_data['내용'].astype(str).apply(lambda x : "," in x))
print('물음표가 있는 질문 : {:.2f}%'.format(qmarks * 100))
print("마침표가 있는 질문 : {:.2f}%".format(fullstop * 100))
print('쉼표가 있는 질문 : {:.2f}%'.format(reststop *100))
# Out:
# 물음표가 있는 질문 : 3.71%
# 마침표가 있는 질문 : 64.69%
# 쉼표가 있는 질문 : 74.70%

# %%
train_data['내용'][:5]
# Out:
# 0    바쁜 일상 속 신체 벨런스가 무너진 직장인을 위한 몸의 바른 정렬을 중시, 정확한 ...
# 1    밴드를 이용하여 진행하는 체조, 강사님을 따라하는 체조로 밴드에 가하는 힘에 의하여...
# 2    직사각형 나무 탁자에 네트를 걸고 양 사이드에 선수들이 서서 탁구채로 속이 빈 작은...
# 3    스마트폰 갤러리에 있는 사진으로 나만의 사진 편집하기, 라인 카메라 시작하기, 갤러...
# 4    고요히 눈을 감고 차분한 마음으로 깊이 생각하는 것이다. 명상은 일체의 '잡생각'을...
# Name: 내용, dtype: object

# %%
# 한글 문자가 아닌 것들을 모두 제거
import re
review_text = re.sub("[^가-힣ㄱ-ㅎㅏ\\s|]", "", train_data['내용'][0])
print(review_text)
# Out:
# 바쁜 일상 속 신체 벨런스가 무너진 직장인을 위한 몸의 바른 정렬을 중시 정확한 자세와 호흡법 연결 순서의 완성도 행위 속의 명상추구 보조 도구의 활동

# %%
def preprocessing(review, okt, remove_stopwords = False, stop_words =[]):
  # 1. 한글 및 공백을 제외한 문자를 모두 제거
  review_text = re.sub("[^가-힣ㄱ-ㅎㅏ\\s|]", "", review)
  # 2. okt 객체를 활용해 형태소 단위로 나눈다.
  word_review = okt.morphs(review_text, stem=True)

  if remove_stopwords:
    # 불용어 제거(선택)
    word_review = [token for token in word_review if not token in stop_words]
  return word_review

# %%
# pip install konlpy
import numpy as np
import pandas as pd
import re
import json
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
stop_words = ['에','및','은','을','와', '는', '이', '가', '아', '것', '들', '의', '있', '되', '수', '보', '주', '등', '한', '도']
okt = Okt()
clean_train_review = []

for review in train_data['내용']:
  # 비어있는 데이터에서 멈추지 않도록 문자열인 경우에만 진행
  if type(review) == str:
    clean_train_review.append(preprocessing(review, okt, remove_stopwords=True, stop_words=stop_words))
  else:
    clean_train_review.append([]) # string이 아니면 비어있는 값 추가

clean_train_review[:4]
# Out:
# [['바쁘다',
#   '일상',
#   '속',
#   '신체',
#   '벨런스',
#   '무너지다',
#   '직장인',
#   '위',
#   '몸',
#   '바르다',
#   '정렬',
#   '중시',
#   '정확하다',
#   '자세',
#   '호흡',
#   '법',
#   '연결',
#   '순서',
#   '완성',
#   '행위',
#   '속',
#   '명상',
#   '추구',
#   '보조',
#   '도구',
#   '활동'],
#  ['밴드',
#   '를',
#   '이용',
#   '하다',
#   '진행',
#   '하다',
#   '체조',
#   '강사',
#   '님',
#   '따르다',
#   '체조',
#   '로',
#   '밴드',
#   '가하다',
#   '힘',
#   '의하다',
#   '운동',
#   '효과',
#   '나타나다',
#   '가해',
#   '지는',
#   '힘',
#   '따르다',
#   '체조',
#   '모양',
#   '이나',
#   '형태',
#   '달라지다',
#   '어린이',
#   '부터',
#   '어르신',
#   '까지',
#   '모두',
#   '함께',
#   '하다',
#   '있다',
#   '간단하다',
#   '체조',
#   '다'],
#  ['직사각형',
#   '나무',
#   '탁자',
#   '네트',
#   '를',
#   '걸다',
#   '양',
#   '사이드',
#   '선수',
#   '서서',
#   '탁구',
#   '채',
#   '로',
#   '속이다',
#   '빈',
#   '작다',
#   '플라스틱',
#   '재질',
#   '공',
#   '치다',
#   '넘기다',
#   '하다',
#   '운동',
#   '이다',
#   '얼핏',
#   '보다',
#   '사람',
#   '둘이서',
#   '탁자',
#   '하나',
#   '놓다',
#   '이리저리',
#   '움직이다',
#   '공',
#   '치다',
#   '게',
#   '탁구',
#   '를',
#   '하다',
#   '번',
#   '안',
#   '해보다',
#   '혹은',
#   '눈',
#   '앞',
#   '에서만',
#   '보다',
#   '온',
#   '사람',
#   '에게는',
#   '쉬다',
#   '간단하다',
#   '보이다',
#   '실상',
#   '뛰어나다',
#   '반',
#   '사',
#   '신경',
#   '과',
#   '구질',
#   '파악',
#   '하다',
#   '대응',
#   '하다',
#   '감각',
#   '요구',
#   '하다',
#   '고도',
#   '스포츠',
#   '다'],
#  ['스마트폰',
#   '갤러리',
#   '있다',
#   '사진',
#   '으로',
#   '나',
#   '만의',
#   '사진',
#   '편집',
#   '하다',
#   '라인',
#   '카메라',
#   '시작',
#   '하다',
#   '갤러리',
#   '사진',
#   '편집',
#   '하다',
#   '콜라주',
#   '를',
#   '이용',
#   '하다',
#   '사진',
#   '꾸미다',
#   '인물',
#   '보정',
#   '하다',
#   '사진',
#   '다양하다',
#   '효과',
#   '주기']]

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(clean_train_review)
train_sequences = tokenizer.texts_to_sequences(clean_train_review)

word_vocab = tokenizer.word_index # 단어 사전 형태

MAX_SEQUENCE_LENGTH = 30 # 문장 최대 길이

train_inputs = pad_sequences(train_sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post')
# 학습 데이터를 벡터화
train_labels = np.array(train_data['강좌개설정보']) # 학습 데이터 라벨

# %%
def flatten_list(nested_list):
    flattened = []
    for item in nested_list:
        if isinstance(item, list):
            flattened.extend(flatten_list(item))
        else:
            flattened.append(item)
    return flattened

flat_list = flatten_list(clean_train_review)

print(flat_list)
prepro_configs = {word: index + 1 for index, word in enumerate(flat_list)}

print(prepro_configs)
from collections import Counter

flat_list = flatten_list(clean_train_review)
word_counts = Counter(flat_list)

print(word_counts)
# Out:
# ['바쁘다', '일상', '속', '신체', '벨런스', '무너지다', '직장인', '위', '몸', '바르다', '정렬', '중시', '정확하다', '자세', '호흡', '법', '연결', '순서', '완성', '행위', '속', '명상', '추구', '보조', '도구', '활동', '밴드', '를', '이용', '하다', '진행', '하다', '체조', '강사', '님', '따르다', '체조', '로', '밴드', '가하다', '힘', '의하다', '운동', '효과', '나타나다', '가해', '지는', '힘', '따르다', '체조', '모양', '이나', '형태', '달라지다', '어린이', '부터', '어르신', '까지', '모두', '함께', '하다', '있다', '간단하다', '체조', '다', '직사각형', '나무', '탁자', '네트', '를', '걸다', '양', '사이드', '선수', '서서', '탁구', '채', '로', '속이다', '빈', '작다', '플라스틱', '재질', '공', '치다', '넘기다', '하다', '운동', '이다', '얼핏', '보다', '사람', '둘이서', '탁자', '하나', '놓다', '이리저리', '움직이다', '공', '치다', '게', '탁구', '를', '하다', '번', '안', '해보다', '혹은', '눈', '앞', '에서만', '보다', '온', '사람', '에게는', '쉬다', '간단하다', '보이다', '실상', '뛰어나다', '반', '사', '신경', '과', '구질', '파악', '하다', '대응', '하다', '감각', '요구', '하다', '고도', '스포츠', '다', '스마트폰', '갤러리', '있다', '사진', '으로', '나', '만의', '사진', '편집', '하다', '라인', '카메라', '시작', '하다', '갤러리', '사진', '편집', '하다', '콜라주', '를', '이용', '하다', '사진', '꾸미다', '인물', '보정', '하다', '사진', '다양하다', '효과', '주기', '고요하다', '눈', '감고', '차분하다', '마음', '으로', '깊이', '생각', '하다', '이다', '명상', '일체', '잡', '생각', '하다', '않다', '으로', '종종', '마음', '깨끗이', '하다', '스트레스', '를', '줄', '이며', '휴식', '촉진', '시키다', '마음', '훈련', '시키다', '데', '사용', '되다', '손', '으로', '그린', '그림', '문자', '라는', '뜻', '으로', '글씨', '를', '아름답다', '쓰다', '기술', '뜻', '하다', '아날로그', '적', '느낌', '과', '밋밋하다', '글자', '가지', '고', '있다', '평범하다', '넘어서다', '독특하다', '창조', '적', '인', '표현', '하다', '있다', '필기체', '모양', '이다', '누구', '나', '쉬다', '글', '모양', '창조', '하다', '있다', '매력', '있다', '옷', '수선', '필요하다', '의복', '구성', '원리', '이해', '를', '돕다', '헌', '옷', '으로', '유행', '트랜드', '맞다', '디자인', '하다', '리폼', '수선하다', '재료', '비', '월', '만원', '재료', '선택', '따르다', '상이', '함', '개인', '별', '구입', '재', '봉기', '사용', '익히다', '의복', '구성', '원리', '를', '바탕', '으로', '의류', '수선', '하다', '다양하다', '옷', '으로', '재생', '하다', '부업', '이나', '창업', '도움', '주다', '일반', '적', '으로', '채색', '쓰다', '않다', '주로', '연필', '이나', '콩테', '목판', '파스텔', '사용', '하다', '선', '으로', '그린', '그림', '또는', '회화', '표현', '말', '하다', '기본', '그림', '과', '그라데이션', '자유', '화', '그', '린다', '스마트폰', '사진', '편집', '과', '동영상', '전문', '프로그램', '으로', '영상', '편집', '희망', '하다', '분들', '쉬다', '들다', '동영상', '미디어', '분할', '디자이너', '사운드', '학습', '하다', '컴퓨터', '기초', '부터', '인터넷', '기초', '까지', '스마트폰', '앱', '사용', '미숙', '하다', '분', '대상', '으로', '카메라', '앱', '갤러리', '앱', '음악', '과', '동영상', '즐기다', '일상', '생활', '스마트폰', '활용', '하다', '건강', '관련', '앱', '받다', '주로', '다루다', '여러', '사람', '줄', '지다', '동일하다', '동작', '하다', '스포츠', '댄스', '처럼', '파트너', '짝', '짓다', '아니다', '앞뒤', '양옆', '서서', '대열', '맞추다', '춤', '추다', '요즘', '에는', '동작', '코믹', '요소', '를', '가하다', '색다르다', '춤', '으로', '만들다', '경우', '많다', '전통무용', '으로', '궁', '중', '무용', '민속무용', '가면', '무용', '의식', '무용', '창작', '무용', '있다', '장단', '가락', '과', '박자', '맞추다', '온몸', '으로', '퍼지다', '춤', '사위', '를', '한국', '적', '인', '멋', '으로', '승화', '으로', '집약', '하다', '있다', '애견', '의류', '소품', '봉제', '하다', '계절', '별로', '아이템', '제작', '다', '창업', '가능하다', '전', '문', '인력', '으로', '성장하다', '쇼핑몰', '운영', '이나', '공', '방', '운영', '하다', '봉제', '도구', '재료', '미싱', '사', '용법', '익히다', '민소매', '티', '재단', '후드', '케이프', '제작', '하다', '주로', '다루다', '재봉틀', '이용', '홈', '패션', '기초', '작고', '만들기', '쉽다', '소품', '생활', '소품', '유행', '하다', '디자인', '인테리어', '소품', '까지', '제작', '하다', '있다', '디자인', '응용', '하다', '법', '과', '실무', '에서', '사용', '하다', '봉제', '기법', '습득', '하다', '있다', '지도', '하다', '강좌', '이다', '부업', '창업', '하다', '있다', '다양하다', '생활', '소품', '만들다', '기술', '익히다', '양식', '조리', '기능사', '자격증', '희망', '하다', '분', '양식', '조리', '관심', '있다', '분', '누구', '나', '가능하다', '양식', '조리', '가지', '를', '이론', '과', '실습', '통', '하다', '기', '본', '조리법', '쉬다', '이해', '시킴', '으로써', '조리', '자신감', '주다', '자격증', '취득', '과', '양식', '조리', '기술', '향상', '시키다', '체형', '교정', '요가', '골반', '과', '척추', '를', '중심', '으로', '체형', '교정', '위', '요가', '다', '허리', '디스크', '예방', '재활', '운동', '목', '디스크', '어깨', '통증', '골반', '과', '척추', '중심', '요가', '다', '요가', '필라테스', '추나', '요법', '근육', '운동학', '이론', '요가', '접목', '되다', '정악', '과', '민속', '악', '으로', '나뉘다', '있다', '정악', '아악', '당악', '향악', '포함', '양반', '음악', '민속', '악', '민요', '나', '산조', '시나위', '판소리', '말', '하다', '수업', '에서는', '주로', '민속', '악', '다루다', '예정', '이며', '이론', '과', '직접', '불다', '보다',  ...
# {'바쁘다': 22636, '일상': 37235, '속': 38322, '신체': 38126, '벨런스': 7957, '무너지다': 7958, '직장인': 12696, '위': 38318, '몸': 37409, '바르다': 37092, '정렬': 37824, '중시': 7964, '정확하다': 37466, '자세': 37403, '호흡': 37822, '법': 38169, '연결': 27354, '순서': 30869, '완성': 37684, '행위': 32098, '명상': 36961, '추구': 7975, '보조': 38141, '도구': 38025, '활동': 38127, '밴드': 31991, '를': 38327, '이용': 37752, '하다': 38383, '진행': 38138, '체조': 34972, '강사': 38142, '님': 35, '따르다': 37609, '로': 37883, '가하다': 37198, '힘': 33010, '의하다': 37728, '운동': 38134, '효과': 36448, '나타나다': 25489, '가해': 46, '지는': 27174, '모양': 37865, '이나': 37329, '형태': 38107, '달라지다': 32651, '어린이': 36017, '부터': 38049, '어르신': 33516, '까지': 34640, '모두': 37494, '함께': 38251, '있다': 38294, '간단하다': 38132, '다': 38320, '직사각형': 36784, '나무': 36785, '탁자': 36812, '네트': 36787, '걸다': 36789, '양': 38109, '사이드': 36791, '선수': 36792, '서서': 37187, '탁구': 36820, '채': 36795, '속이다': 36797, '빈': 36798, '작다': 36799, '플라스틱': 36800, '재질': 36801, '공': 36817, '치다': 36818, '넘기다': 36804, '이다': 38226, '얼핏': 36808, '보다': 37885, '사람': 38381, '둘이서': 36811, '하나': 37071, '놓다': 36814, '이리저리': 36815, '움직이다': 36816, '게': 36819, '번': 36823, '안': 37943, '해보다': 38163, '혹은': 36826, '눈': 36827, '앞': 36828, '에서만': 36829, '온': 36831, '에게는': 36833, '쉬다': 37736, '보이다': 36836, '실상': 36837, '뛰어나다': 36838, '반': 36839, '사': 38171, '신경': 36841, '과': 38373, '구질': 36843, '파악': 36844, '대응': 36846, '감각': 38341, '요구': 37536, '고도': 36851, '스포츠': 38184, '스마트폰': 36419, '갤러리': 36433, '사진': 36446, '으로': 38343, '나': 38114, '만의': 38115, '편집': 37959, '라인': 36881, '카메라': 36430, '시작': 37090, '콜라주': 36437, '꾸미다': 36442, '인물': 38346, '보정': 36444, '다양하다': 37610, '주기': 36449, '고요하다': 167, '감고': 169, '차분하다': 170, '마음': 37120, '깊이': 27452, '생각': 37615, '일체': 178, '잡': 179, '않다': 35693, '종종': 16676, '깨끗이': 186, '스트레스': 37473, '줄': 37173, '이며': 35857, '휴식': 192, '촉진': 24739, '시키다': 38351, '훈련': 38331, '데': 32629, '사용': 38026, '되다': 38155, '손': 37876, '그린': 36672, '그림': 36673, '문자': 37018, '라는': 38339, '뜻': 36683, '글씨': 37339, '아름답다': 37875, '쓰다': 37341, '기술': 36682, '아날로그': 36685, '적': 38342, '느낌': 36687, '밋밋하다': 36689, '글자': 37580, '가지': 37641, '고': 38092, '평범하다': 36694, '넘어서다': 36695, '독특하다': 36696, '창조': 36711, '인': 38301, '표현': 37674, '필기체': 36703, '누구': 37598, '글': 36709, '매력': 37679, '옷': 3858, '수선': 3855, '필요하다': 35205, '의복': 3848, '구성': 36212, '원리': 35718, '이해': 38382, '돕다': 38224, '헌': 17211, '유행': 29950, '트랜드': 34307, '맞다': 37267, '디자인': 38110, '리폼': 3842, '수선하다': 3843, '재료': 37649, '비': 25690, '월': 268, '만원': 269, '선택': 38112, '상이': 25407, '함': 37262, '개인': 37518, '별': 37863, '구입': 33950, '재': 17749, '봉기': 3845, '익히다': 38337, '바탕': 38013, '의류': 28361, '재생': 27598, '부업': 3862, '창업': 31761, '도움': 36628, '주다': 38031, '일반': 29594, '채색': 25272, '주로': 36964, '연필': 31670, '콩테': 310, '목판': 311, '파스텔': 312, '선': 35732, '또는': 37450, '회화': 37780, '말': 38165, '기본': 38300, '그라데이션': 327, '자유': 38216, '화': 37937, '그': 36467, '린다': 36468, '동영상': 35517, '전문': 38242, '프로그램': 38225, '영상': 35404, '희망': 31894, '분들': 30458, '들다': 32802, '미디어': 35538, '분할': 8718, '디자이너': 31878, '사운드': 8730, '학습': 37975, '컴퓨터': 37412, '기초': 38365, '인터넷': 35506, '앱': 35459, '미숙': 363, '분': 36496, '대상': 30217, '음악': 37963, '즐기다': 34474, '생활': 38289, '활용': 38158, '건강': 37278, '관련': 38353, '받다': 35474, '다루다': 37767, '여러': 37640, '지다': 37174, '동일하다': 37175, '동작': 37194, '댄스': 37179, '처럼': 37180, '파트너': 37181, '짝': 37182, '짓다': 37183, '아니다': 37184, '앞뒤': 37185, '양옆': 37186, '대열': 37188, '맞추다': 37468, '춤': 37200, '추다': 37191, '요즘': 37192, '에는': 37193, '코믹': 37195, '요소': 37196, '색다르다': 37199, '만들다': 37879, '경우': 37203, '많다': 37589, '전통무용': 421, '궁': 423, '중': 37492, '무용': 35714, '민속무용': 426, '가면': 30827, '의식': 36610, '창작': 37486, '장단': 23407, '가락': 37590, '박자': 37096, '온몸': 439, '퍼지다': 441, '사위': 443, '한국': 36662, '멋': 9173, '승화': 18068, '집약': 452, '애견': 3285, '소품': 37328, '봉제': 3288, '계절': 34967, '별로': 36511, '아이템': 3292, '제작': 38118, '가능하다': 37555, '전': 35596, '문': 38108, '인력': 3300, '성장하다': 32504, '쇼핑몰': 3303, '운영': 29602, '방': 2 ...
# Counter({'하다': 2088, '를': 1024, '있다': 782, '과': 724, '으로': 542, '적': 397, '로': 384, '대한': 256, '통해': 254, '하고': 253, '되다': 250, '다양하다': 238, '배우다': 237, '이해': 230, '에서': 219, '활용': 215, '기초': 212, '이다': 203, '인': 201, '학습': 200, '만들다': 188, '수업': 186, '과정': 162, '위': 159, '익히다': 157, '방법': 156, '만들기': 154, '나': 144, '이용': 141, '운동': 137, '보다': 134, '프로그램': 118, '활동': 117, '사용': 115, '댄스': 115, '생활': 112, '스마트폰': 111, '기본': 111, '력': 110, '간단하다': 108, '동작': 108, '표현': 106, '사진': 105, '쉬다': 103, '다': 86, '통한': 86, '영어': 85, '자세': 84, '대해': 84, '요가': 83, '키우다': 83, '교육': 83, '말': 82, '컴퓨터': 82, '진행': 81, '몸': 79, '편집': 79, '주다': 79, '문화': 79, '우리': 79, '앱': 78, '삶': 78, '관리': 78, '향상': 77, '자신': 77, '능력': 77, '법': 76, '체험': 76, '생각': 75, '시키다': 73, '고': 73, '춤': 73, '목표': 73, '신체': 71, '제작': 71, '속': 70, '아이': 69, '미술': 69, '건강': 68, '회화': 65, '기르다': 65, '알아보다': 65, '일상': 64, '따르다': 64, '스포츠': 64, '함께': 63, '강좌': 63, '직접': 63, '코딩': 63, '부터': 62, '도움': 62, '여행': 62, '사람': 59, '맞추다': 59, '기술': 58, '함': 58, '분': 57, '기능': 57, '해보다': 56, '관련': 56, '시간': 56, '건강하다': 56, '읽다': 56, '음악': 55, '역사': 55, '효과': 54, '만의': 54, '가지': 54, '집중': 54, '지능': 54, '아니다': 52, '에게': 52, '연습': 52, '자신감': 51, '문제': 51, '알': 51, '작품': 51, '인공': 51, '누구': 50, '일본어': 50, '필요하다': 49, '호흡': 48, '까지': 48, '설정': 48, '문장': 47, '책': 47, '사': 46, '맞다': 46, '자격증': 46, '중심': 46, '내': 46, '감': 46, '환경': 46, '영상': 45, '다루다': 45, '여러': 45, '통': 45, '정리': 45, '이미지': 45, '예술': 45, '정신': 45, '세계': 45, '스트레칭': 44, '해결': 44, '그림': 43, '놀이': 43, '급': 43, '공예': 43, '축구': 43, '수학': 43, '스스로': 43, '직업': 43, '되어다': 42, '시대': 42, '소통': 42, '공': 41, '싶다': 41, '설치': 41, '자기': 41, '갖다': 41, '주로': 40, '발달': 40, '성': 40, '중국어': 40, '증진': 40, '바르다': 39, '시작': 39, '기': 39, '으로써': 39, '알다': 39, '근력': 39, '시': 39, '유튜브': 39, '원리': 38, '그': 38, '인터넷': 38, '실생활': 38, '악기': 38, '노래': 38, '안정': 38, '경험': 38, '개념': 38, '마음': 37, '않다': 37, '줄': 37, '구성': 37, '실습': 37, '척추': 37, '이야기': 37, '느끼다': 37, '위해': 37, '영': 37, '얻다': 37, '전반': 37, '키': 37, '자연': 37, '과학': 37, '동영상': 36, '많다': 36, '성취': 36, '음식': 36, '별': 35, '화': 35, '기법': 35, '교정': 35, '주제': 35, '재미있다': 35, '높이다': 35, '체력': 35, '스트레스': 34, '즐기다': 34, '중': 34, '이론': 34, '한글': 34, '강화': 34, '관계': 34, '재료': 33, '여': 33, '공간': 33, '기회': 33, '살펴보다': 33, '탁구': 32, '안': 32, '가능하다': 32, '취득': 32, '볼': 32, '골프': 32, '창의': 32, '어린이': 31, '하나': 31, '체계': 31, '엑셀': 31, '인성': 31, '상황': 31, '화면': 31, '강사': 30, '근육': 30, '다른': 30, '새롭다': 30, '포토샵': 30, '완성': 29, '작다': 29, '그리고': 29, '지식': 29, '흥미': 29, '검색': 29, '올바르다': 29, '처럼': 28, '추다': 28, '용법': 28, '보고': 28, '한자': 28, '수영': 28, '사회': 28, '좋다': 28, '가족': 28, '강의': 28, '양': 27, '개인': 27, '에는': 27, '별로': 27, '창의력': 27, '준비': 27, '위주': 27, '내용': 27, '물': 27, '서': 27, '서서': 26, '치다': 26, '감각': 26, '디자인': 26, '지도': 26, '예방': 26, '초': 26, '대하': 26, '식물': 26, '학생': 26, '미래': 26, '자': 26, '그림책': 26, '모두': 25, '짓다': 25, '응용': 25, '작성': 25, '바로': 25, '중국': 25, '즐거움': 25, '바른': 25, '가다': 25, '심리': 25, '후': 25, '습관': 25, '앞': 24, '이며': 24, '요소': 24, '창작': 24, '문법': 24, '의미': 24, '감정': 24, '어떻다': 24, '형': 24, '연주': 24, '정보': 24, '소품': 23, '전': 23, '가지다': 23, '즐겁다': 23, '보기': 23, '또한': 23, '활': 23, '어렵다': 23, '행복하다': 23, '카드': 23, '설명': 23, '요리': 23, '짧다': 23, '진로': 23, '사고': 23, '변화': 23, '정확하다': 22, '아름답다': 22, '돕다': 22, '창업': 22, '대상': 22, '한국': 22, '습득': 22, '에서는': 22, '파워포인트': 22, '현대': 22, '크다': 22, '균형': 22, '제공': 22, '더': 22, '무엇': 22, '톡': 22, '접': 22, '심신': 22, '만': 22, '가장': 22, '각': 22, '이나': 21, '보정': 21, '손': 21, '관심': 21, '안무': 21, '문서': 21, '필수': 21, '실력': 21, '실전': 21, '다이어트': 21, '발표': 21, '때문': 21, '해소': 21, '대화': 21, '없다': 21, '분석': 21, '찾다': 21, '파일': 21, '친구': 21, '약초': 21, '논리': 21, '정렬': 20, '명상': 20, '어르신': 20, '탁자': 20, '움직이다': 20, '게': 20, '라인': 20, '지다': 20, '의식': 20, '필라테스': 20, '꼭': 20, '장구': 20, '주민': 20, '조절': 20, '사교': 20, '비교': 20, '트렌드': 20, '란': 20, '나아가다': 20, '카카오': 20, '블로그': 20, '정서': 20, '도구': 19, '글': 19, '받다': 19, '문': 19, '목적': 19, '구조': 19, '특징': 19, '꽃': 19, '며': 1 ...

# %%
# Sum all values in the prepro_configs dictionary
total_value = sum(word_counts.values())

# Set the 'vocab_size' key in prepro_configs to the total value
prepro_configs['vocab_size'] = total_value
prepro_configs['vocab_size']
# Out:
# 38383

# %%
model_name = 'cnn_classifier_kr'
BATCH_SIZE = 256
NUM_EPOCHS = 2
VALID_SPLIT = 0.1
MAX_LEN = 10 # 이거 대기
kargs = {'model_name' : model_name, 'vocab_size' : prepro_configs['vocab_size'],
         'embedding_size':64, 'num_filters':100, 'dropout_rate':0.5, 'hidden_dimension':250, 
         'output_dimension':1} # 이부분도 대기

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import json

from tqdm import tqdm
x_train, x_test, y_train, y_test = train_test_split(train_inputs, train_labels, test_size = 0.3, random_state = 777)
print("훈련용 데이터셋 크기: %s, 검증용 데이터셋 크기: %s" % (x_train.shape,  x_test.shape))
print("훈련용 레이블 크기: %s, 검증용 레이블 크기: %s" % (y_train.shape,  y_test.shape))
# Out:
# 훈련용 데이터셋 크기: (755, 30), 검증용 데이터셋 크기: (324, 30)
# 훈련용 레이블 크기: (755,), 검증용 레이블 크기: (324,)

# %%
class CNNClassifier(tf.keras.Model):
  def __init__(self, **kargs):
    super(CNNClassifier, self).__init__(name=kargs['model_name'])
    self.embedding = layers.Embedding(input_dim=prepro_configs['vocab_size'], 
                                      output_dim=kargs['embedding_size'])
    self.conv_list = [layers.Conv1D(filters=kargs["num_filters"], kernel_size=kernel_size,
                                    padding='valid', activation=tf.keras.activations.relu,
                                    kernel_constraint=tf.keras.constraints.MaxNorm(max_value=3.),
                                    )
                                    for kernel_size in [3,4,5]]
    self.pooling = layers.GlobalMaxPool1D()
    self.dropout = layers.Dropout(kargs['dropout_rate'])
    self.fc1 = layers.Dense(units=kargs['hidden_dimension'],
                            activation=tf.keras.activations.relu,
                            kernel_constraint=tf.keras.constraints.MaxNorm(max_value=3.))
    self.fc2 = layers.Dense(units=kargs['output_dimension'], 
                            activation=tf.keras.constraints.MaxNorm(max_value=3.))
    
  def call(self, x):
    x = self.embedding(x)
    x = self.dropout(x)
    x = tf.concat([self.pooling(conv(x)) for conv in self.conv_list], axis=1)
    x = self.fc1(x)
    x = self.fc2(x)

    return x

# %%
model = CNNClassifier(**kargs)

model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=[tf.keras.metrics.BinaryAccuracy(name='accuracy')])

# %%
earlystop_callback = EarlyStopping(monitor='val_accuary', min_delta=0.0001, patience=2)

checkpoint_path = model_name + '/weigths.h5'
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create path if exists
if os.path.exists(checkpoint_dir):
  print("{} -- Folder create complete \n".format(checkpoint_dir))
else:
  os.makedirs(checkpoint_dir, exist_ok=True)
  print("{} -- Folder create complete \n".format(checkpoint_dir))

cp_callback = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', verbose=1, save_best_only=True,
                              save_weights_only=True)
history = model.fit(train_inputs, train_labels, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS,
                    validation_split=VALID_SPLIT, callbacks=[earlystop_callback, cp_callback])
# Out:
# cnn_classifier_kr -- Folder create complete
#
# Epoch 1/2
# 4/4 [==============================] - ETA: 0s - loss: 1.0803 - accuracy: 0.5458WARNING:tensorflow:Early stopping conditioned on metric `val_accuary` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 1: val_accuracy improved from -inf to 0.55556, saving model to cnn_classifier_kr\weigths.h5
# 4/4 [==============================] - 2s 213ms/step - loss: 1.0803 - accuracy: 0.5458 - val_loss: 0.7392 - val_accuracy: 0.5556
# Epoch 2/2
# 4/4 [==============================] - ETA: 0s - loss: 0.8603 - accuracy: 0.5458WARNING:tensorflow:Early stopping conditioned on metric `val_accuary` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 2: val_accuracy did not improve from 0.55556
# 4/4 [==============================] - 0s 81ms/step - loss: 0.8603 - accuracy: 0.5458 - val_loss: 0.7348 - val_accuracy: 0.5556

# %%
earlystop_callback = EarlyStopping(monitor='val_accuary', min_delta=0.0001, patience=2)
cp_callback = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', verbose=1, save_best_only=True,
                              save_weights_only=True)
history = model.fit(train_inputs, train_labels, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS,
                    validation_split=VALID_SPLIT, callbacks=[earlystop_callback, cp_callback])
# Out:
# Epoch 1/2
# 4/4 [==============================] - ETA: 0s - loss: 0.8526 - accuracy: 0.5458WARNING:tensorflow:Early stopping conditioned on metric `val_accuary` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 1: val_accuracy improved from -inf to 0.55556, saving model to cnn_classifier_kr\weigths.h5
# 4/4 [==============================] - 0s 118ms/step - loss: 0.8526 - accuracy: 0.5458 - val_loss: 0.7290 - val_accuracy: 0.5556
# Epoch 2/2
# 4/4 [==============================] - ETA: 0s - loss: 0.8472 - accuracy: 0.5458WARNING:tensorflow:Early stopping conditioned on metric `val_accuary` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#
# Epoch 2: val_accuracy did not improve from 0.55556
# 4/4 [==============================] - 0s 93ms/step - loss: 0.8472 - accuracy: 0.5458 - val_loss: 0.7228 - val_accuracy: 0.5556

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, GRU
#모델 개발
model = Sequential()

# input_dim의 크기는 토큰 생성시 지정한 최대 단어수(vocab_size)와 동일하게 설정
# output_dim의 크기는 input_dim보다 작은 값 중에서 설정
model.add(Embedding(input_dim = total_value, output_dim = 32))
model.add(GRU(128))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, None, 32)          1228256
#
#  gru_2 (GRU)                 (None, 128)               62208
#
#  dense_8 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1290593 (4.92 MB)
# Trainable params: 1290593 (4.92 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, GRU
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
result = model.fit(x_train, y_train, batch_size = 10, epochs = 500, validation_data=(x_test, y_test), callbacks = [
    EarlyStopping(monitor = 'val_loss', patience=5, verbose = 1),
    ReduceLROnPlateau(monitor= "val_loss", patience=3, factor = 0.5, min_lr=0.0001, verbose=1)
])
# Out:
# Epoch 1/500
# 76/76 [==============================] - 5s 37ms/step - loss: 0.6829 - acc: 0.5642 - val_loss: 0.6684 - val_acc: 0.5494 - lr: 0.0010
# Epoch 2/500
# 76/76 [==============================] - 2s 27ms/step - loss: 0.3958 - acc: 0.8305 - val_loss: 0.4132 - val_acc: 0.7932 - lr: 0.0010
# Epoch 3/500
# 76/76 [==============================] - 2s 27ms/step - loss: 0.1607 - acc: 0.9417 - val_loss: 0.5005 - val_acc: 0.8086 - lr: 0.0010
# Epoch 4/500
# 76/76 [==============================] - 2s 27ms/step - loss: 0.1027 - acc: 0.9722 - val_loss: 0.5427 - val_acc: 0.8272 - lr: 0.0010
# Epoch 5/500
# 76/76 [==============================] - ETA: 0s - loss: 0.0923 - acc: 0.9762
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 76/76 [==============================] - 2s 26ms/step - loss: 0.0923 - acc: 0.9762 - val_loss: 0.7502 - val_acc: 0.8302 - lr: 0.0010
# Epoch 6/500
# 76/76 [==============================] - 2s 27ms/step - loss: 0.0633 - acc: 0.9735 - val_loss: 0.5169 - val_acc: 0.8302 - lr: 5.0000e-04
# Epoch 7/500
# 76/76 [==============================] - 2s 28ms/step - loss: 0.0481 - acc: 0.9788 - val_loss: 0.5310 - val_acc: 0.8241 - lr: 5.0000e-04
# Epoch 7: early stopping
